# %% [markdown]
# # SRA Query and XML Parsing
#
# Currently metadata was downloaded by hand using the web interface which generates a sample table. The goal of this notebook is to query the SRA database directly and generate this table without using the web interface. There is an R package `SRAdb` that allows easy querying of the SRA database, but it does not directly interact with the NCBI database. Instead `SRAdb` uses a pre-built SQLite database that is provided by the author. In my tests of this package the counts did not match what I was getting from the SRA web interface.

# %%
# Load useful extensions
# %reload_ext autoreload
# %autoreload 2

# %reload_ext ipycache

# %%
# Imports
import os
import sys
import re
from xml.etree import ElementTree as ET

import pandas as pd
from Bio import Entrez

from ipycache import CacheMagics
CacheMagics.cachedir = '../../output/cache'

# Import my libraries
sys.path.insert(0, '../../lib/python/')
import Sra

pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 999)
Entrez.email = 'justin.fear@nih.gov'

# %% [markdown]
# ## Query SRA

# %% [markdown]
# Using the Biopython implementation of E-utilities directly query SRA using the search term `"Drosophila melanogaster"[Orgn]`. Because there is a large number of entires use the web history feature of E-utilities.

# %%
# Query SRA
handle = Entrez.esearch(db='sra', term='"Drosophila melanogaster"[Orgn]', retmax=99999, usehistory='y')
records = Entrez.read(handle)
print('There were ',records['Count'], ' records return')

# Save history from eSearch, this will be used in eFetch
webenv = records['WebEnv']
query_key = records['QueryKey']
# Out:
# There were  22509  records return

# %% [markdown]
# ## Download Full XML Results

# %% [markdown]
# Download the XML records using the above query history. This process takes a long time and taxes the SRA system so only re-download if need.

# %%
# Check if I have already dumped the sra records. If 
# you want to update, simply delete the file and re-run.
fname = '../../output/sra_dump.xml'
if not os.path.exists(fname):
    Sra.downloadSRA(count=records['Count'], webenv=webenv, 
                query_key=query_key, fname=fname)

tree = ET.parse(fname)
root = tree.getroot()
ep = root.getchildren()
print('You have ', len(ep), ' XML records. This should match the number ofr results returned from your',
      'query. If they do not match then delete the file `../../ouput/sra_dump.xml`')
# Out:
# You have  22344  XML records. This should match the number ofr results returned from your query. If they do not match then delete the file `../../ouput/sra_dump.xml`

# %% [markdown]
# ## Parse XML Records

# %% [markdown]
# E-utilities only provides an XML version of the results. XML needs parsed to generate a results table. A description of the SRA XML schema can be found here:
#
# http://www.ncbi.nlm.nih.gov/viewvc/v1/trunk/sra/doc/SRA_1-6a/
#
# There is a large number of fields in the SRA XML, and a lot of the data is repeated in multiple places. I need to decide which pieces of information to use.

# %%
# Print out an example Tree and mark fields used
for experiment in ep:
    try:
        if experiment.find('RUN_SET/RUN/IDENTIFIERS/PRIMARY_ID').text == 'ERR358180':
            break
    except:
        pass
experiment = ep[802]
keep = ['<span class="burk"><span class="burk"><span class="burk"><span class="burk">EXPERIMENT</span></span></span></span>/IDENTIFIERS/PRIMARY_ID',
        'EXPERIMENT/STUDY_REF/IDENTIFIERS/PRIMARY_ID',
        'EXPERIMENT/STUDY_REF/IDENTIFIERS/EXTERNAL_ID',
        'EXPERIMENT/DESIGN/LIBRARY_DESCRIPTOR/LIBRARY_STRATEGY',
        'EXPERIMENT/DESIGN/LIBRARY_DESCRIPTOR/LIBRARY_SOURCE',
        'EXPERIMENT/DESIGN/LIBRARY_DESCRIPTOR/LIBRARY_SELECTION',
        'EXPERIMENT/DESIGN/LIBRARY_DESCRIPTOR/LIBRARY_LAYOUT/SINGLE',
        'EXPERIMENT/PLATFORM/ILLUMINA/INSTRUMENT_MODEL',
        'EXPERIMENT/PLATFORM/ILLUMINA',
        'SUBMISSION/IDENTIFIERS/PRIMARY_ID',
        'SUBMISSION/IDENTIFIERS/SUBMITTER_ID',
        'Organization/Address/Institution',
        'SAMPLE/TITLE',
        'SAMPLE/SAMPLE_NAME/TAXON_ID',
        'SAMPLE/SAMPLE_NAME/SCIENTIFIC_NAME',
        'SAMPLE/SAMPLE_NAME/COMMON_NAME',
        'SAMPLE/SAMPLE_ATTRIBUTES/SAMPLE_ATTRIBUTE/TAG',
        'SAMPLE/SAMPLE_ATTRIBUTES/SAMPLE_ATTRIBUTE/VALUE',
        'RUN_SET/RUN',
        'RUN_SET/RUN/Statistics/Read'
       ]

def print_tags(s, space='', path=''):
    if (s.tag != 'Quality') & (s.tag != 'Base'):
        print("{space}{tag} {attrib} {text}".format(tag=s.tag, attrib=s.attrib, text=s.text, space=space))

for i in experiment.getchildren():
    path1 = i.tag
    print_tags(i, path=path1)
    for j in i.getchildren():
        path2 = path1 + '/' + j.tag
        print_tags(j, '\t', path=path2)
        for k in j.getchildren():
            path3 = path2 + '/' + k.tag
            print_tags(k, '\t\t', path=path3)
            for l in k.getchildren():
                path4 = path3 + '/' + l.tag
                print_tags(l, '\t\t\t', path=path4)
                for m in l.getchildren():
                    path5 = path4 + '/' + m.tag
                    print_tags(m, '\t\t\t\t', path=path5)
# Out:
# EXPERIMENT {'alias': 'lnc25', 'accession': 'SRX1542556'} None
# 	IDENTIFIERS {} None
# 		PRIMARY_ID {} SRX1542556
# 		SUBMITTER_ID {'namespace': 'Tsinghua University'} lnc25
# 	TITLE {} CR45542 knockout
# 	STUDY_REF {'accession': 'SRP068880'} None
# 		IDENTIFIERS {} None
# 			PRIMARY_ID {} SRP068880
# 	DESIGN {} None
# 		DESIGN_DESCRIPTION {} None
# 		SAMPLE_DESCRIPTOR {'accession': 'SRS1231938'} None
# 			IDENTIFIERS {} None
# 				PRIMARY_ID {} SRS1231938
# 		LIBRARY_DESCRIPTOR {} None
# 			LIBRARY_NAME {} None
# 			LIBRARY_STRATEGY {} RNA-Seq
# 			LIBRARY_SOURCE {} TRANSCRIPTOMIC
# 			LIBRARY_SELECTION {} PolyA
# 			LIBRARY_LAYOUT {} None
# 				SINGLE {} None
# 		SPOT_DESCRIPTOR {} None
# 			SPOT_DECODE_SPEC {} None
# 				SPOT_LENGTH {} 49
# 				READ_SPEC {} None
# 	PLATFORM {} None
# 		ILLUMINA {} None
# 			INSTRUMENT_MODEL {} Illumina HiSeq 2000
# SUBMISSION {'alias': 'lnc1', 'lab_name': '', 'submission_comment': 'five fly mutants and one wild-type', 'center_name': 'Tsinghua University', 'accession': 'SRA325840'} None
# 	IDENTIFIERS {} None
# 		PRIMARY_ID {} SRA325840
# 		SUBMITTER_ID {'namespace': 'Tsinghua University'} lnc1
# Organization {'type': 'center'} None
# 	Name {'abbr': 'Tsinghua University'} Tsinghua University
# 	Contact {'email': 'lynhsiong@hotmail.com'} None
# 		Name {} None
# 			First {} Tuanlin
# 			Last {} Xiong
# 			Middle {} None
# STUDY {'alias': 'PRJNA309866', 'center_name': 'BioProject', 'accession': 'SRP068880'} None
# 	IDENTIFIERS {} None
# 		PRIMARY_ID {} SRP068880
# 		EXTERNAL_ID {'label': 'primary', 'namespace': 'BioProject'} PRJNA309866
# 	DESCRIPTOR {} None
# 		STUDY_TITLE {} Drosophila melanogaster transcriptome
# 		STUDY_TYPE {'existing_study_type': 'Transcriptome Analysis'} None
# 		STUDY_ABSTRACT {} The goal of this study is learn the possible function of lncRNAs in fly testis development. We constructed five lncRNAs KO mutants, and sequenced their transcriptome with an extra wild type strain.
# 		CENTER_PROJECT_NAME {} Drosophila melanogaster
# SAMPLE {'alias': 'lncRNA25-CR45542', 'accession': 'SRS1231938'} None
# 	IDENTIFIERS {} None
# 		PRIMARY_ID {} SRS1231938
# 		EXTERNAL_ID {'namespace': 'BioSample'} SAMN04381902
# 		SUBMITTER_ID {'label': 'Sample name', 'namespace': 'pda|bbxvxtl'} lncRNA25-CR45542
# 	SAMPLE_NAME {} None
# 		TAXON_ID {} 7227
# 		SCIENTIFIC_NAME {} Drosophila melanogaster
# 	SAMPLE_ATTRIBUTES {} None
# 		SAMPLE_ATTRIBUTE {} None
# 			TAG {} breed
# 			VALUE {} w1118
# 		SAMPLE_ATTRIBUTE {} None
# 			TAG {} isolation_source
# 			VALUE {} mutants-lncRNA25-CR45542
# 		SAMPLE_ATTRIBUTE {} None
# 			TAG {} collection_date
# 			VALUE {} not applicable
# 		SAMPLE_ATTRIBUTE {} None
# 			TAG {} geo_loc_name
# 			VALUE {} USA: Bloomington Stock Center
# 		SAMPLE_ATTRIBUTE {} None
# 			TAG {} tissue
# 			VALUE {} testes
# 		SAMPLE_ATTRIBUTE {} None
# 			TAG {} BioSampleModel
# 			VALUE {} Invertebrate
# Pool {} None
# 	Member {'tax_id': '7227', 'bases': '2598717352', 'organism': 'Drosophila melanogaster', 'member_name': '', 'spots': '53035048', 'accession': 'SRS1231938', 'sample_name': 'lncRNA25-CR45542'} None
# 		IDENTIFIERS {} None
# 			PRIMARY_ID {} SRS1231938
# 			EXTERNAL_ID {'namespace': 'BioSample'} SAMN04381902
# 			SUBMITTER_ID {'label': 'Sample name', 'namespace': 'pda|bbxvxtl'} lncRNA25-CR45542
# RUN_SET {} None
# 	RUN {'alias': 'lnc25', 'total_bases': '1147106807', 'cluster_name': 'public', 'published': '2016-01-26 21:41:30', 'load_done': 'true', 'size': '777224347', 'static_data_available': '1', 'accession': 'SRR3080522', 'is_public': 'true', 'total_spots': '23410343'} None
# 		IDENTIFIERS {} None
# 			PRIMARY_ID {} SRR3080522
# 			SUBMITTER_ID {'namespace': 'Tsinghua University'} lnc25
# 		EXPERIMENT_REF {'accession': 'SRX1542556'} None
# 		Pool {} None
# 			Member {'tax_id': '7227', 'bases': '1147106807', 'organism': 'Drosophila melanogaster', 'member_name': '', 'spots': '23410343', 'accession': 'SRS1231938', 'sample_name': 'lncRNA25-CR45542'} None
# 				IDENTIFIERS {} None
# 		QualityCount {} None
# 		Statistics {'nreads': '1', 'nspots': '23410343'} None
# 			Read {'stdev': '0', 'count': '23410343', 'index': '0', 'average': '49'} None
# 		Bases {'cs_native': 'false', 'count': '1147106807'} None
# 	RUN {'alias': 'CR45542_BioRep2', 'total_bases': '1451610545', 'cluster_name': 'public', 'published': '2016-01-28 00:00:00', 'load_done': 'true', 'size': '512585669', 'static_data_available': '1', 'accession': 'SRR3605533', 'is_public': 'true', 'total_spots': '29624705'} None
# 		IDENTIFIERS {} None
# 			PRIMARY_ID {} SRR3605533
# 			SUBMITTER_ID {'namespace': 'Tsinghua University'} CR45542_BioRep2
# 		EXPERIMENT_REF {'accession': 'SRX1542556'} None
# 		RUN_ATTRIBUTES {} None
# 			RUN_ATTRIBUTE {} None
# 				TAG {} loader
# 				VALUE {} latf-load
# 				UNITS {} None
# 		Pool {} None
# 			Member {'tax_id': '7227', 'bases': '1451610545', 'organism': 'Drosophila melanogaster', 'member_name': '', 'spots': '29624705', 'accession': 'SRS1231938', 'sample_name': 'lncRNA25-CR45542'} None
# 				IDENTIFIERS {} None
# 		QualityCount {} None
# 		Statistics {'nreads': '2', 'nspots': '29624705'} None
# 			Read {'stdev': '0', 'count': '29624705', 'index': '0', 'average': '49'} None
# 			Read {'stdev': '0', 'count': '0', 'index': '1', 'average': '0'} None
# 		Databases {} None
# 			Database {} None
# 				Table {'name': 'SEQUENCE'} None
# 		Bases {'cs_native': 'false', 'count': '1451610545'} None

# %% [markdown]
# I am assuming the redundant information is populated by SRA and should be identical, but it would probably be safest to compare data points and flag those that do not match. I could do this a number of ways, first I could be a set of classes for each piece of information I am interested and then parse each bit of XML to check, or I could build a class for each bit of XML and check. The first one is probably easier.
#
# Decided to just try to replicate the `Sra RunInfo` table as close as possible. I developed a class separately to do some error checking and parsing.

# %%
# Parse SRA XML
res = Sra.SraResultsTable(fname)

# Generate DataFrame representation of XML.
exper = res.build_rows()

exper.shape
# Out:
# (29691, 48)

# %% [markdown]
# ## Validate Parsed Table
#
# Now that I have a parsed table I need to make sure it is correct. There will be some iteration if there is something wrong with the table.
#
# The current table includes other types of samples besides RNA-seq data. I want to parse this out so that it matches the runinfo table. Note this does not account for samples that are not annotated correctly, this is just for verification of my XML parsing.

# %%
# List possible values of LibrarySource
exper['LibrarySource'].unique()
# Out:
# array(['GENOMIC', 'TRANSCRIPTOMIC', 'OTHER', 'SYNTHETIC', 'METAGENOMIC',
#        'METATRANSCRIPTOMIC'], dtype=object)

# %%
# Filter out only Transcriptomic data
ts = exper[(exper['LibrarySource'] == 'TRANSCRIPTOMIC') | (exper['LibrarySource'] == 'METATRANSCRIPTOMIC')]

print(ts.shape)
ts.head()
# Out:
# (14035, 48)
#             Run RunSecondary ReleaseDate LoadDate     spots       bases  \
# 315  SRR3476589               2016-05-06           39131961  1956598050
# 316  SRR3476587               2016-05-06           15895465   794773250
# 317  SRR3476579               2016-05-06           20659277  3098891550
# 318  SRR3476578               2016-05-06           14956121  2243418150
# 319  SRR3476577               2016-05-06            8894958  1334243700
#
#     spots_with_mates avgLength size_MB AssemblyName download_path  Experiment  \
# 315                0        50                                     SRX1743178
# 316                0        50                                     SRX1743176
# 317                0       150                                     SRX1743168
# 318                0       150                                     SRX1743167
# 319                0       150                                     SRX1743166
#
#     LibraryName LibraryStrategy LibrarySelection   LibrarySource  \
# 315   UNDEFINED           OTHER            other  TRANSCRIPTOMIC
# 316   UNDEFINED         RNA-Seq             cDNA  TRANSCRIPTOMIC
# 317   UNDEFINED         RNA-Seq             cDNA  TRANSCRIPTOMIC
# 318   UNDEFINED         RNA-Seq             cDNA  TRANSCRIPTOMIC
# 319   UNDEFINED         RNA-Seq             cDNA  TRANSCRIPTOMIC
#
#     LibraryLayout InsertSize InsertDev  Platform                Model  \
# 315        SINGLE          0         0  ILLUMINA  Illumina HiSeq 2500
# 316        SINGLE          0         0  ILLUMINA  Illumina HiSeq 2500
# 317        SINGLE          0         0  ILLUMINA  Illumina HiSeq 2500
# 318        SINGLE          0         0  ILLUMINA  Illumina HiSeq 2500
# 319        SINGLE          0         0  ILLUMINA  Illumina HiSeq 2500
#
#       SRAStudy   BioProject Study_Pubmed_id ProjectID      Sample  \
# 315  SRP074388  PRJNA320547                            SRS1422417
# 316  SRP074388  PRJNA320547                            SRS1422418
# 317  SRP074388  PRJNA320547                            SRS1422407
# 318  SRP074388  PRJNA320547                            SRS1422411
# 319  SRP074388  PRJNA320547                            SRS1422406
#
#         BioSample SampleType TaxID           ScientificName  SampleName  \
# 315  SAMN04942830             7227  Drosophila melanogaster  GSM2142680
# 316  SAMN04942828             7227  Drosophila melanogaster  GSM2142678
# 317  SAMN04942820             7227  Drosophila melanogaster  GSM2142670
# 318  SAMN04942819             7227  Drosophila melanogaster  GSM2142669
# 319  SAMN04942818             7227  Drosophila melanogaster  GSM2142668
#
#     g1k_pop_code source g1k_analysis_group Subject_ID Sex Disease Tumor  \
# 315                                                                  no
# 316                                                                  no
# 317                                                                  no
# 318                                                                  no
# 319                                                                  no
#
#     Affection_Status Analyte_Type Histological_Type Body_Site CenterName  \
# 315                                                                 None
# 316                                                                 None
# 317                                                                 None
# 318                                                                 None
# 319                                                                 None
#
#     Submission dbgap_study_accession Consent RunHash ReadHash
# 315  SRA423615                        public
# 316  SRA423615                        public
# 317  SRA423615                        public
# 318  SRA423615                        public
# 319  SRA423615                        public

# %%
# Create list of Run IDs from my parsed table
myRuns = set(ts.Run.tolist())

# %%
# Import the web downloaded table and create a list of Run IDs
web = pd.read_csv('../../output/SraRunInfo_example.csv')
webRuns = set(web.Run.tolist())

# %% [markdown]
# ### Compare Rows

# %% [markdown]
# There are <font color="#FF0000">{{ts.shape[0]}}</font> rows in the output, but the SRA RunInfo table has <font color="#FF0000">{{web.shape[0]}}</font> rows. I need to figure out the difference.

# %%
# Use Sets to determine the differences between the tow lists
myMissing = webRuns.difference(myRuns)
print(len(myMissing))
myMissing
# Out:
# 36
# {'SRR2194872',
#  'SRR2194895',
#  'SRR2194929',
#  'SRR2194944',
#  'SRR2194955',
#  'SRR2194957',
#  'SRR2195001',
#  'SRR2195002',
#  'SRR2195003',
#  'SRR2195004',
#  'SRR2195005',
#  'SRR2195006',
#  'SRR2422935',
#  'SRR2422936',
#  'SRR2422937',
#  'SRR2422938',
#  'SRR2422939',
#  'SRR2422940',
#  'SRR2660677',
#  'SRR2660678',
#  'SRR2660679',
#  'SRR2660680',
#  'SRR2660681',
#  'SRR2660682',
#  'SRR2660683',
#  'SRR2660684',
#  'SRR2660685',
#  'SRR2660686',
#  'SRR2660687',
#  'SRR2660688',
#  'SRR2660689',
#  'SRR2660690',
#  'SRR3575267',
#  'SRR3575268',
#  'SRR3575291',
#  'SRR3575298'}

# %% [markdown]
# It looks like these samples no longer exist because they have been updated. Looking at the XML, these values are now secondary IDs. I went back and add the `RunSecondary` IDs to my table output just to double check that this is the case.

# %%
# Create a list of secondary IDs
secondaryIDs = set(ts.RunSecondary.tolist())
secondaryIDs
# Out:
# {'',
#  'SRR2194872;SRR2194895',
#  'SRR2194929;SRR2194944',
#  'SRR2194955;SRR2194957',
#  'SRR2195001;SRR2195002',
#  'SRR2195003;SRR2195004',
#  'SRR2195005;SRR2195006',
#  'SRR3136809'}

# %%
# Expand out concatenated secondary IDs for easy comparison
IDs = []
for ID in secondaryIDs:
    if ID != '':
        IDs.extend(ID.split(';'))

IDs = set(IDs)
IDs
# Out:
# {'SRR2194872',
#  'SRR2194895',
#  'SRR2194929',
#  'SRR2194944',
#  'SRR2194955',
#  'SRR2194957',
#  'SRR2195001',
#  'SRR2195002',
#  'SRR2195003',
#  'SRR2195004',
#  'SRR2195005',
#  'SRR2195006',
#  'SRR3136809'}

# %% [markdown]
# Now that I have a list of secondary IDs I can compare this list to the values missing from the webversion of RunInfo.

# %%
# Compare secondary IDs with missing IDs and find the difference
IDs.difference(myMissing)
# Out:
# {'SRR3136809'}

# %%
ts[ts.RunSecondary == 'SRR3136809']
# Out:
#              Run RunSecondary ReleaseDate LoadDate  spots    bases  \
# 1162  SRR3114090   SRR3136809  2016-02-10           14025  2920418
#
#      spots_with_mates avgLength size_MB AssemblyName download_path  \
# 1162                0         0
#
#       Experiment          LibraryName LibraryStrategy LibrarySelection  \
# 1162  SRX1542109  MDR_RNAseq_map 91-C         RNA-Seq           RANDOM
#
#        LibrarySource LibraryLayout InsertSize InsertDev  Platform  \
# 1162  TRANSCRIPTOMIC     UNDEFINED          0         0  ILLUMINA
#
#                     Model   SRAStudy   BioProject Study_Pubmed_id ProjectID  \
# 1162  Illumina HiSeq 2500  SRP068789  PRJNA309447
#
#           Sample     BioSample SampleType TaxID           ScientificName  \
# 1162  SRS1258611  SAMN04433043             7227  Drosophila melanogaster
#
#             SampleName g1k_pop_code source g1k_analysis_group Subject_ID Sex  \
# 1162  Dmel_MDR_RNA_seq
#
#      Disease Tumor Affection_Status Analyte_Type Histological_Type Body_Site  \
# 1162            no
#
#      CenterName Submission dbgap_study_accession Consent RunHash ReadHash
# 1162       None  SRA338296                        public

# %% [markdown]
# OK, it looks like the all of the differences between my table and the SRA RunInfo table were do to secondary IDs caused by updating submissions. The majority of the updates were to fix the mistake of uploading each read of a paired end experiment as single ends. SRR3136809 is not in the web downloaded version of Sra RunInfo, so it is just an extra secondary ID in the databases. **The parsed table has all of the correct rows.**

# %% [markdown]
# ### Compare Columns and Values

# %% [markdown]
# Now I want to look at the columns and values to make sure they are similar to the Sra RunInfo Table.

# %%
# Test out column comparison
my = ts[['Run','ReleaseDate']]
w = web[['Run','ReleaseDate']]

# %%
my.head()
# Out:
#             Run ReleaseDate
# 315  SRR3476589  2016-05-06
# 316  SRR3476587  2016-05-06
# 317  SRR3476579  2016-05-06
# 318  SRR3476578  2016-05-06
# 319  SRR3476577  2016-05-06

# %%
w.head()
# Out:
#           Run ReleaseDate
# 0   ERR358180  2016-06-16
# 1   ERR358181  2016-06-16
# 2   ERR358182  2016-06-16
# 3   ERR358183  2016-06-16
# 4  SRR3663861  2016-06-20

# %%
# Merge two tables on Run
merged = my.merge(w, how='left', on='Run')
merged.head()
# Out:
#           Run ReleaseDate_x ReleaseDate_y
# 0  SRR3476589    2016-05-06    2016-05-06
# 1  SRR3476587    2016-05-06    2016-05-06
# 2  SRR3476579    2016-05-06    2016-05-06
# 3  SRR3476578    2016-05-06    2016-05-06
# 4  SRR3476577    2016-05-06    2016-05-06

# %%
# Check if any of the rows have a mismatch
any(merged.ReleaseDate_x != merged.ReleaseDate_y)
# Out:
# False

# %% [raw]
# OK!, this looks like the way to compare columns. I will now make a function and run all columns.

# %%
def diff(ts, web, header):
    """ Compare columns between two DataFrames
    
    This function takes two data frames and compares the column (header). It returns 
    a Boolean Series where True indicates the columns were different.
    
    
    """
    my = ts[['Run', header]]
    w = web[['Run', header]]
    merged = my.merge(w, how='left', on='Run')
    return merged[header + '_x'] != merged[header + '_y']

# %%
# Get a list of columns in the web version of SRA Run
web.columns
# Out:
# Index(['Run', 'ReleaseDate', 'LoadDate', 'spots', 'bases', 'spots_with_mates',
#        'avgLength', 'size_MB', 'AssemblyName', 'download_path', 'Experiment',
#        'LibraryName', 'LibraryStrategy', 'LibrarySelection', 'LibrarySource',
#        'LibraryLayout', 'InsertSize', 'InsertDev', 'Platform', 'Model',
#        'SRAStudy', 'BioProject', 'Study_Pubmed_id', 'ProjectID', 'Sample',
#        'BioSample', 'SampleType', 'TaxID', 'ScientificName', 'SampleName',
#        'g1k_pop_code', 'source', 'g1k_analysis_group', 'Subject_ID', 'Sex',
#        'Disease', 'Tumor', 'Affection_Status', 'Analyte_Type',
#        'Histological_Type', 'Body_Site', 'CenterName', 'Submission',
#        'dbgap_study_accession', 'Consent', 'RunHash', 'ReadHash'],
#       dtype='object')

# %% [markdown]
# The following columns have differences between the web SRA RunInfo and my parsed table.

# %%
# Iterate over all columns and get differences NOTE: Skip the Run column.
bad = []
for c in web.columns.tolist()[1:]:
    d = any(diff(ts, web, c))
    if d:
        bad.append(c)
bad
# Out:
# ['LoadDate',
#  'spots',
#  'bases',
#  'spots_with_mates',
#  'avgLength',
#  'size_MB',
#  'AssemblyName',
#  'download_path',
#  'LibraryName',
#  'LibraryLayout',
#  'InsertSize',
#  'InsertDev',
#  'BioProject',
#  'Study_Pubmed_id',
#  'ProjectID',
#  'Sample',
#  'BioSample',
#  'SampleType',
#  'TaxID',
#  'ScientificName',
#  'SampleName',
#  'g1k_pop_code',
#  'source',
#  'g1k_analysis_group',
#  'Subject_ID',
#  'Sex',
#  'Disease',
#  'Affection_Status',
#  'Analyte_Type',
#  'Histological_Type',
#  'Body_Site',
#  'CenterName',
#  'Submission',
#  'dbgap_study_accession',
#  'RunHash',
#  'ReadHash']

# %% [markdown]
# Some of the information found in the RunInfo table was not found in the XML. For now I am just outputing the columns as `''`. I want to focus on those columns that I actually tried to populate in the output table.

# %%
# Columns that I did not populate
ignore = [
    'LoadDate',
    'size_MB',
    'AssemblyName',
    'download_path',
    'Pubmed_id',
    'ProjectID',
    'SampleType',
    'g1k_pop_code',
    'source',
    'g1k_analysis_group',
    'Subject_ID',
    'Disease',
    'Affection_Status',
    'Analyte_Type',
    'Histological_type',
    'dbgap_study_accession',
    'RunHash',
    'ReadHash'
]

# %%
# Get list of columns to focus on
set(bad).difference(set(ignore))
# Out:
# {'BioProject',
#  'BioSample',
#  'Body_Site',
#  'CenterName',
#  'Histological_Type',
#  'InsertDev',
#  'InsertSize',
#  'LibraryLayout',
#  'LibraryName',
#  'Sample',
#  'SampleName',
#  'ScientificName',
#  'Sex',
#  'Study_Pubmed_id',
#  'Submission',
#  'TaxID',
#  'avgLength',
#  'bases',
#  'spots',
#  'spots_with_mates'}

# %%
merged = ts.merge(web, how='left', on='Run')
merged.set_index('Run', inplace=True)
merged.head()
# Out:
#            RunSecondary ReleaseDate_x LoadDate_x   spots_x     bases_x  \
# Run
# SRR3476589                 2016-05-06             39131961  1956598050
# SRR3476587                 2016-05-06             15895465   794773250
# SRR3476579                 2016-05-06             20659277  3098891550
# SRR3476578                 2016-05-06             14956121  2243418150
# SRR3476577                 2016-05-06              8894958  1334243700
#
#            spots_with_mates_x avgLength_x size_MB_x AssemblyName_x  \
# Run
# SRR3476589                  0          50
# SRR3476587                  0          50
# SRR3476579                  0         150
# SRR3476578                  0         150
# SRR3476577                  0         150
#
#            download_path_x Experiment_x LibraryName_x LibraryStrategy_x  \
# Run
# SRR3476589                   SRX1743178     UNDEFINED             OTHER
# SRR3476587                   SRX1743176     UNDEFINED           RNA-Seq
# SRR3476579                   SRX1743168     UNDEFINED           RNA-Seq
# SRR3476578                   SRX1743167     UNDEFINED           RNA-Seq
# SRR3476577                   SRX1743166     UNDEFINED           RNA-Seq
#
#            LibrarySelection_x LibrarySource_x LibraryLayout_x InsertSize_x  \
# Run
# SRR3476589              other  TRANSCRIPTOMIC          SINGLE            0
# SRR3476587               cDNA  TRANSCRIPTOMIC          SINGLE            0
# SRR3476579               cDNA  TRANSCRIPTOMIC          SINGLE            0
# SRR3476578               cDNA  TRANSCRIPTOMIC          SINGLE            0
# SRR3476577               cDNA  TRANSCRIPTOMIC          SINGLE            0
#
#            InsertDev_x Platform_x              Model_x SRAStudy_x  \
# Run
# SRR3476589           0   ILLUMINA  Illumina HiSeq 2500  SRP074388
# SRR3476587           0   ILLUMINA  Illumina HiSeq 2500  SRP074388
# SRR3476579           0   ILLUMINA  Illumina HiSeq 2500  SRP074388
# SRR3476578           0   ILLUMINA  Illumina HiSeq 2500  SRP074388
# SRR3476577           0   ILLUMINA  Illumina HiSeq 2500  SRP074388
#
#            BioProject_x Study_Pubmed_id_x ProjectID_x    Sample_x  \
# Run
# SRR3476589  PRJNA320547                                SRS1422417
# SRR3476587  PRJNA320547                                SRS1422418
# SRR3476579  PRJNA320547                                SRS1422407
# SRR3476578  PRJNA320547                                SRS1422411
# SRR3476577  PRJNA320547                                SRS1422406
#
#              BioSample_x SampleType_x TaxID_x         ScientificName_x  \
# Run
# SRR3476589  SAMN04942830                 7227  Drosophila melanogaster
# SRR3476587  SAMN04942828                 7227  Drosophila melanogaster
# SRR3476579  SAMN04942820                 7227  Drosophila melanogaster
# SRR3476578  SAMN04942819                 7227  Drosophila melanogaster
# SRR3476577  SAMN04942818                 7227  Drosophila melanogaster
#
#            SampleName_x g1k_pop_code_x source_x g1k_analysis_group_x  \
# Run
# SRR3476589   GSM2142680
# SRR3476587   GSM2142678
# SRR3476579   GSM2142670
# SRR3476578   GSM2142669
# SRR3476577   GSM2142668
#
#            Subject_ID_x Sex_x Disease_x Tumor_x Affection_Status_x  \
# Run
# SRR3476589                                   no
# SRR3476587                                   no
# SRR3476579                                   no
# SRR3476578                                   no
# SRR3476577                                   no
#
#            Analyte_Type_x Histological_Type_x Body_Site_x CenterName_x  \
# Run
# SRR3476589                                                        None
# SRR3476587                                                        None
# SRR3476579                                                        None
# SRR3476578                                                        None
# SRR3476577                                                        None
#
#            Submission_x dbgap_study_accession_x Consent_x RunHash_x  \
# Run
# SRR3476589    SRA423615                            public
# SRR3476587    SRA423615                            public
# SRR3476579    SRA423615                            public
# SRR3476578    SRA423615                            public
# SRR3476577    SRA423615                            public
#
#            ReadHash_x ReleaseDate_y  LoadDate_y   spots_y     bases_y  \
# Run
# SRR3476589               2016-05-06  2016-06-22  39131961  1956598050
# SRR3476587               2016-05-06  2016-06-22  15895465   794773250
# SRR3476579               2016-05-06  2016-06-22  20659277  3098891550
# SRR3476578               2016-05-06  2016-06-22  14956121  2243418150
# SRR3476577               2016-05-06  2016-06-22   8894958  1334243700
#
#             spots_with_mates_y  avgLength_y  size_MB_y AssemblyName_y  \
# Run
# SRR3476589                   0           50       1659            NaN
# SRR3476587                   0           50        742            NaN
# SRR3476579                   0          150       1912            NaN
# SRR3476578                   0          150       1376            NaN
# SRR3476577                   0          150        820            NaN
#
#                                               download_path_y Experiment_y  \
# Run
# SRR3476589  http://sra-download.ncbi.nlm.nih.gov/srapub/SR...   SRX1743178
# SRR3476587  http://sra-download.ncbi.nlm.nih.gov/srapub/SR...   SRX1743176
# SRR3476579  http://sra-download.ncbi.nlm.nih.gov/srapub/SR...   SRX1743168
# SRR3476578  http://sra-download.ncbi.nlm.nih.gov/srapub/SR...   SRX1743167
# SRR3476577  http://sra-download.ncbi.nlm.nih.gov/srapub/SR...   SRX1743166
#
#            LibraryName_y LibraryStrategy_y LibrarySelection_y LibrarySource_y  \
# Run
# SRR3476589           NaN             OTHER              other  TRANSCRIPTOMIC
# SRR3476587           NaN           RNA-Seq               cDNA  TRANSCRIPTOMIC
# SRR3476579           NaN           RNA-Seq               cDNA  TRANSCRIPTOMIC
# SRR3476578           NaN           RNA-Seq               cDNA  TRANSCRIPTOMIC
# SRR3476577           NaN           RNA-Seq               cDNA  TRANSCRIPTOMIC
#
#            LibraryLayout_y  InsertSize_y  InsertDev_y Platform_y  \
# Run
# SRR3476589          SINGLE             0            0   ILLUMINA
# SRR3476587          SINGLE             0            0   ILLUMINA
# SRR3476579          SINGLE             0            0   ILLUMINA
# SRR3476578          SINGLE             0            0   ILLUMINA
# SRR3476577          SINGLE             0            0   ILLUMINA
#
#                         Model_y SRAStudy_y BioProject_y  Study_Pubmed_id_y  \
# Run
# SRR3476589  Illumina HiSeq 2500  SRP074388  PRJNA320547                2.0
# SRR3476587  Illumina HiSeq 2500  SRP074388  PRJNA320547                2.0
# SRR3476579  Illumina HiSeq 2500  SRP074388  PRJNA320547                2.0
# SRR3476578  Illumina HiSeq 2500  SRP074388  PRJNA320547                2.0
# SRR3476577  Illumina HiSeq 2500  SRP074388  PRJNA320547                2.0
#
#             ProjectID_y    Sample_y   BioSample_y SampleType_y  TaxID_y  \
# Run
# SRR3476589       320547  SRS1422417  SAMN04942830       simple     7227
# SRR3476587       320547  SRS1422418  SAMN04942828       simple     7227
# SRR3476579       320547  SRS1422407  SAMN04942820       simple     7227
# SRR3476578       320547  SRS1422411  SAMN04942819       simple     7227
# SRR3476577       320547  SRS1422406  SAMN04942818       simple     7227
#
#                    ScientificName_y SampleName_y  g1k_pop_code_y  source_y  \
# Run
# SRR3476589  Drosophila melanogaster   GSM2142680             NaN       NaN
# SRR3476587  Drosophila melanogaster   GSM2142678             NaN       NaN
# SRR3476579  Drosophila melanogaster   GSM2142670             NaN       NaN
# SRR3476578  Drosophila melanogaster   GSM2142669             NaN       NaN
# SRR3476577  Drosophila melanogaster   GSM2142668             NaN       NaN
#
#             g1k_analysis_group_y  Subject_ID_y Sex_y  Disease_y Tumor_y  \
# Run
# SRR3476589                   NaN           NaN   NaN        NaN      no
# SRR3476587                   NaN           NaN   NaN        NaN      no
# SRR3476579                   NaN           NaN   NaN        NaN      no
# SRR3476578                   NaN           NaN   NaN        NaN      no
# SRR3476577                   NaN           NaN   NaN        NaN      no
#
#             Affection_Status_y  Analyte_Type_y  Histological_Type_y  \
# Run
# SRR3476589                 NaN             NaN                  NaN
# SRR3476587                 NaN             NaN                  NaN
# SRR3476579                 NaN             NaN                  NaN
# SRR3476578                 NaN             NaN                  NaN
# SRR3476577                 NaN             NaN                  NaN
#
#            Body_Site_y CenterName_y Submission_y  dbgap_study_accession_y  \
# Run
# SRR3476589         NaN          GEO    SRA423615                      NaN
# SRR3476587         NaN          GEO    SRA423615                      NaN
# SRR3476579         NaN          GEO    SRA423615                      NaN
# SRR3476578         NaN          GEO    SRA423615                      NaN
# SRR3476577         NaN          GEO    SRA423615                      NaN
#
#            Consent_y                         RunHash_y  \
# Run
# SRR3476589    public  9B89DD52F297F6C85E21B0E8BD4F1797
# SRR3476587    public  9CD9DE707C9D7E686B6164CB55DA0FC9
# SRR3476579    public  C5654DF66CE2C36A8A3C9C09DAB257F3
# SRR3476578    public  7E8F5A091954852B697A4EE0DA14B87E
# SRR3476577    public  439C3072EF48AC6BDEC8174C10E9DDA7
#
#                                   ReadHash_y
# Run
# SRR3476589  ACA8DAE5C4D016485896BCC5E1B0AD3B
# SRR3476587  3B01E7CCBBC1FFD2A1BAC53D2EF29018
# SRR3476579  7FBB1CFE8550969CA5BA637D4196885B
# SRR3476578  F409573941C51A038714C5F2D61BA98F
# SRR3476577  092CC13ACF609BE7D540DFE21C0F4BED

# %% [markdown]
# ### Check BioProject

# %%
merged.loc[merged['BioProject_x'] != merged['BioProject_y'],['BioProject_x', 'BioProject_y']].head(30)
# Out:
#           BioProject_x BioProject_y
# Run
# SRR070285    UNDEFINED   PRJNA75285
# SRR069030    UNDEFINED   PRJNA75285
# SRR068619    UNDEFINED   PRJNA75285
# SRR023779    UNDEFINED   PRJNA75285
# SRR023780    UNDEFINED   PRJNA75285
# SRR013492    UNDEFINED   PRJNA75285
# SRR013491    UNDEFINED   PRJNA75285
# SRR013489    UNDEFINED   PRJNA75285
# SRR013490    UNDEFINED   PRJNA75285
# SRR013488    UNDEFINED   PRJNA75285
# SRR953523    UNDEFINED          NaN
# SRR953524    UNDEFINED          NaN
# SRR953525    UNDEFINED          NaN
# SRR010960    UNDEFINED          NaN
# SRR010959    UNDEFINED          NaN
# SRR010958    UNDEFINED          NaN
# SRR010957    UNDEFINED          NaN
# SRR010956    UNDEFINED          NaN
# SRR010955    UNDEFINED          NaN
# SRR010954    UNDEFINED          NaN
# SRR010953    UNDEFINED          NaN
# SRR010952    UNDEFINED          NaN
# SRR010951    UNDEFINED          NaN
# SRR488371         None  PRJNA168994
# SRR489396         None  PRJNA168994
# SRR489395         None  PRJNA168994
# SRR489394         None  PRJNA168994
# SRR489393         None  PRJNA168994
# SRR489392         None  PRJNA168994
# SRR489391         None  PRJNA168994

# %% [markdown]
# The UNDEFINED values are what is given if the BioProject ID was not here, these should correspond to NaN. The None values are because the BioProject ID was there, but its value was None. This would indicate that the field I am grabbing BioProject ID is not always populated. Need to look at more detail.

# %% [markdown]
# ### BioSample

# %%
merged.loc[merged['BioSample_x'] != merged['BioSample_y'],['BioSample_x', 'BioSample_y']]
# Out:
#              BioSample_x   BioSample_y
# Run
# SRR3147695     UNDEFINED  SAMN04433043
# SRR3147698     UNDEFINED  SAMN04433043
# SRR3147700     UNDEFINED  SAMN04433043
# ERR562744   SAMEA2639703           NaN
# ERR562736   SAMEA2639694           NaN
# SRR1024049     UNDEFINED  SAMN02390696
# SRR1119148     UNDEFINED  SAMN02390696
# SRR1119250     UNDEFINED  SAMN02390696
# SRR073287   SAMN00120617     SRS121518
# SRR073286   SAMN00120617     SRS121518

# %% [markdown]
# There are only a handful of these. Strange that there is an NaN where I have a SAM ID number.

# %% [markdown]
# ## Available Sample Attributes:

# %% [markdown]
# Sample attributes are entered as free text. Here is a list of attributes currently in the SRA. Some of these can collapsed into single categories.

# %%
counts = {}
for i in root.findall('SAMPLE_ATTRIBUTE/TAG'):
    try:
        text = i.text.lower()
        if text in counts:
            counts[text] += 1
        else:
            counts[text] = 1
    except:
        pass

# %%
pd.Series(counts).to_csv('../../output/tmp.text', sep='\t')

# %%
s = bob.find('SAMPLE')

# %%
for i in s.iter():
    print(i.tag, i.attrib, i.text)
# Out:
# SAMPLE {'accession': 'SRS1532953', 'alias': 'FR198N'} None
# IDENTIFIERS {} None
# PRIMARY_ID {} SRS1532953
# EXTERNAL_ID {'namespace': 'BioSample'} SAMN05330489
# SUBMITTER_ID {'namespace': 'pda|justin.lack@nih.gov', 'label': 'Sample name'} FR198N
# TITLE {} FR198N
# SAMPLE_NAME {} None
# TAXON_ID {} 7227
# SCIENTIFIC_NAME {} Drosophila melanogaster
# COMMON_NAME {} fruit fly
# SAMPLE_LINKS {} None
# SAMPLE_LINK {} None
# XREF_LINK {} None
# DB {} bioproject
# ID {} 327349
# LABEL {} PRJNA327349
# SAMPLE_ATTRIBUTES {} None
# SAMPLE_ATTRIBUTE {} None
# TAG {} strain
# VALUE {} FR198N
# SAMPLE_ATTRIBUTE {} None
# TAG {} dev_stage
# VALUE {} adult
# SAMPLE_ATTRIBUTE {} None
# TAG {} sex
# VALUE {} female
# SAMPLE_ATTRIBUTE {} None
# TAG {} tissue
# VALUE {} Whole organism
# SAMPLE_ATTRIBUTE {} None
# TAG {} BioSampleModel
# VALUE {} Model organism or animal

# %%
for attrib in s.findall('SAMPLE_ATTRIBUTES/SAMPLE_ATTRIBUTE'):
    print(attrib.find('TAG').text)
# Out:
# strain
# dev_stage
# sex
# tissue
# BioSampleModel
