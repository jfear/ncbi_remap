# %% [markdown]
# # Developmental Time Course

# %%
import os
import sys
from pathlib import Path
from textwrap import dedent

from IPython.display import display, HTML, Markdown
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Project level imports
sys.path.insert(0, '../lib')
from ncbi_remap.notebook import Nb
from ncbi_remap.plotting import make_figs

# Setup notebook
nbconfig = Nb.setup_notebook()

# Connect to data store
store = pd.HDFStore('../sra.h5', mode='r')
# Out:
# Please check output/fbgn2chrom.tsv. If it does not exist, run bin/fbgn2chrom.py
# last updated: 2018-04-30
# Git hash: 69e627d87b83358b44de6959a32570f5edba2b8c

# %%
from pymongo import MongoClient
try:
    with open('../output/.mongodb_host', 'r') as fh:
        host = fh.read().strip()
except FileNotFoundError:
    host = 'localhost'

mongoClient = MongoClient(host=host, port=27022)
db = mongoClient['sra']
ncbi = db['ncbi']
biometa = db['biometa']

# %%
# Get list of completed srx
complete = store['aln/complete'].srx.unique().tolist()

# %%
rnaseq = [x['_id'] for x in ncbi.aggregate([
    {
        '$match': {
            '_id': {'$in': complete},
            'sra.experiment.library_strategy': 'RNA-Seq'
        }
    },
    {
        '$project': {
            '_id': 1
        }
    }
])]

# %%
names = set([x['name'] for x in biometa.aggregate([
    {
        '$unwind': {
            'path': '$sample_attributes'
        }
    },
    {
        '$match': {
            'sample_attributes.name': {'$exists': 1}
        }
    },
    {
        '$project': {
            '_id': 0,
            'name': '$sample_attributes.name'
        }
    }
])])

# %%
# List some possible names to use
"age"
"age_of_animals"
"age_of_flies"
"age_of_fly_in_days_post_eclosion"
"ages"
"biosamplemodel"
"biosourceprovider"
"biosourcetype"
"days_after_eclosion"
"developemntal_stage"
"developmentalstage"
"developmental_stage"
"developmental_temperature"
"developmental_time"
"developmental_time_point"
"development_point"
"development_stage"
"develpomental_stage"
"dev_stage"
"dev-stage"
"embryonic_stage"
"embryonic_stages"
"embryonic_temperature"
"embryos_hand-sorted_or_not"
"embryos_per_sample"
"gender/age"
"gestational_age"
"mating_status"
"mating_system"
"sex/age"
"tissue_age"
"tissue/development_stage"
"tissue_source"

# %%
dev_stage = [
    "developemntal_stage",
    "developmentalstage",
    "developmental_stage",
    "development_point",
    "development_stage",
    "develpomental_stage",
    "dev_stage",
    "dev-stage"
]

# %%
staged = list(set([x['_id'] for x in biometa.aggregate([
    {
        '$unwind': {
            'path': '$experiments'
        }
    },
    {
        '$match': {
            'experiments.srx': {'$in': rnaseq}
        }
    },
    {
        '$unwind': {
            'path': '$sample_attributes'
        }
    },
    {
        '$match': {
            'sample_attributes.name': {'$in': dev_stage}
        }
    },
    {
        '$group': {
            '_id': '$experiments.srx'
        }
    },
    {
        '$project': {
            '_id': 1,
        }
    }
    
])]))

# %%
len(staged)
# Out:
# 5602

# %%
ncbi.find_one({'_id': staged[0]})
# Out:
# {'_cls': 'Ncbi',
#  '_id': 'SRX1006753',
#  'bioproject': {'bioproject_accn': 'PRJNA281652',
#   'bioproject_id': '281652',
#   'description': 'Mating and transfer of male Sex Peptide causes a number of physiological changes in the female fly, including increased egg production, decreased immune function and shortened life span. A panel of wild-type- derived strains of Drosophila melanogaster was used to assay the transcriptional changes in response to mating. The data represents whole transcriptome profiling of female heads before (Virgin) and after mating (Mated). RNA-Seq data was generated for the F1-heterozygous progeny resulting from crosses between inbred wild-type- derived strains and a common tester strain w[1118]. Virgin females from naturally-derived strains were crossed to males of the w[1118] tester strain to generate hybrid virgin female progeny. Half of these hybrid females were assayed as virgins at age 10 days, whereas the other half were mated to w[1118] males at a ratio of 30 virgins to 10 males per vial for 24 hours at age 4 days, and then assayed at age 10 days. The analysis of RNA-Seq data revealed significant upregulation of hundreds of genes in response to mating across the various genotypes. Most of the upregulated genes are expressed in female fat body, indicating significant shifts in metabolic pathways of mated females. Interestingly, while the sets of differentially expressed genes were highly concordant across different populations and strains, considerable variation was observed in the average magnitudes of transcriptional changes. This dataset was also used to characterize natural genetic variation in selected transcriptional traits, including allele-specific expression, splicing patterns and RNA-editing.',
#   'external_id': [],
#   'last_update': datetime.datetime(2015, 4, 20, 0, 0),
#   'name': 'Drosophila melanogaster',
#   'publication': '25888292',
#   'submission_date': datetime.datetime(2015, 4, 20, 0, 0),
#   'submission_id': 'SUB920475',
#   'title': 'Genetic variation in mating-induced transcriptional responses in wild-type-derived strains of Drosophila melanogaster'},
#  'biosample': [{'access': 'public',
#    'attributes': [{'name': 'strain',
#      'value': 'Drosophila melanogaster Winters 80 Mated 2'},
#     {'name': 'dev_stage', 'value': 'adult'},
#     {'name': 'sex', 'value': 'female'},
#     {'name': 'tissue', 'value': 'head'}],
#    'biosample_accn': 'SAMN03493259',
#    'biosample_id': '3493259',
#    'biosample_primary': 'SAMN03493259',
#    'contacts': [{'email': 'peterlchang@gmail.com',
#      'first_name': 'Peter',
#      'last_name': 'Chang'}],
#    'description': 'Drosophila melanogaster Winters 80 Mated 2',
#    'institute': 'University of Southern California',
#    'last_update': '2015-04-23',
#    'models': ['Model organism or animal'],
#    'organism_name': 'Drosophila melanogaster',
#    'publication_date': '2015-04-20',
#    'sample_id': 'SRS919397',
#    'submission_date': '2015-04-20',
#    'tax_id': '7227',
#    'tax_name': 'Drosophila melanogaster',
#    'title': 'Drosophila melanogaster Winters 80 Mated 2'}],
#  'pubmed': [{'abstract': 'Regulatory variation in gene expression can be described by cis- and trans-genetic components. Here we used RNA-seq data from a population panel of Drosophila melanogaster test crosses to compare allelic imbalance (AI) in female head tissue between mated and virgin flies, an environmental change known to affect transcription. Indeed, 3048 exons (1610 genes) are differentially expressed in this study. A Bayesian model for AI, with an intersection test, controls type I error. There are ∼200 genes with AI exclusively in mated or virgin flies, indicating an environmental component of expression regulation. On average 34% of genes within a cross and 54% of all genes show evidence for genetic regulation of transcription. Nearly all differentially regulated genes are affected in cis, with an average of 63% of expression variation explained by the cis-effects. Trans-effects explain 8% of the variance in AI on average and the interaction between cis and trans explains an average of 11% of the total variance in AI. In both environments cis- and trans-effects are compensatory in their overall effect, with a negative association between cis- and trans-effects in 85% of the exons examined. We hypothesize that the gene expression level perturbed by cis-regulatory mutations is compensated through trans-regulatory mechanisms, e.g., trans and cis by trans-factors buffering cis-mutations. In addition, when AI is detected in both environments, cis-mated, cis-virgin, and trans-mated-trans-virgin estimates are highly concordant with 99% of all exons positively correlated with a median correlation of 0.83 for cis and 0.95 for trans We conclude that the gene regulatory networks (GRNs) are robust and that trans-buffering explains robustness.\nCopyright © 2016 by the Genetics Society of America.',
#    'authors': [{'affiliation': 'Molecular Genetics and Microbiology, University of Florida, Gainesville, Florida 32611 Genetics Institute, University of Florida, Gainesville, Florida 32611.',
#      'first_name': 'Justin M',
#      'last_name': 'Fear'},
#     {'affiliation': 'Department of Biostatistics, University of Texas Health Science Center at Houston-School of Public Health, Houston, Texas 77030.',
#      'first_name': 'Luis G',
#      'last_name': 'León-Novelo'},
#     {'affiliation': 'Molecular Genetics and Microbiology, University of Florida, Gainesville, Florida 32611 Genetics Institute, University of Florida, Gainesville, Florida 32611.',
#      'first_name': 'Alison M',
#      'last_name': 'Morse'},
#     {'affiliation': 'Molecular Genetics and Microbiology, University of Florida, Gainesville, Florida 32611 Genetics Institute, University of Florida, Gainesville, Florida 32611.',
#      'first_name': 'Alison R',
#      'last_name': 'Gerken'},
#     {'affiliation': 'Memorial Sloan Kettering Cancer Center, New York, New York 10065.',
#      'first_name': 'Kjong',
#      'last_name': 'Van Lehmann'},
#     {'affiliation': 'Molecular and Computational Biology Program, Dornsife College of Letters, Arts, and Sciences, University of Southern California, Los Angeles, California 90089.',
#      'first_name': 'John',
#      'last_name': 'Tower'},
#     {'affiliation': 'Molecular and Computational Biology Program, Dornsife College of Letters, Arts, and Sciences, University of Southern California, Los Angeles, California 90089 mcintyre@ufl.edu snuzhdin@usc.edu.',
#      'first_name': 'Sergey V',
#      'last_name': 'Nuzhdin'},
#     {'affiliation': 'Molecular Genetics and Microbiology, University of Florida, Gainesville, Florida 32611 Genetics Institute, University of Florida, Gainesville, Florida 32611 mcintyre@ufl.edu snuzhdin@usc.edu.',
#      'first_name': 'Lauren M',
#      'last_name': 'McIntyre'}],
#    'citation': '1943-2631 203 Genetics 2016',
#    'date_completed': datetime.datetime(2017, 5, 23, 0, 0),
#    'date_revised': datetime.datetime(2017, 12, 12, 0, 0),
#    'pubmed_id': '27194752',
#    'title': 'Buffering of Genetic Regulatory Networks in Drosophila melanogaster.'}],
#  'sra': {'db_flags': ['SE', 'RNASeq'],
#   'db_imported': datetime.datetime(2018, 2, 13, 15, 13, 33, 93000),
#   'experiment': {'attributes': [],
#    'ddbj_links': [],
#    'design': 'Run 1',
#    'ena_links': [],
#    'entrez_links': [],
#    'experiment_id': 'SRX1006753',
#    'external_id': [],
#    'instrument_model': 'Illumina HiSeq 2000',
#    'library_layout': 'SINGLE',
#    'library_name': 'Drosophila melanogaster Winters 80 Mated 2 Experiment 2',
#    'library_selection': 'RANDOM',
#    'library_source': 'TRANSCRIPTOMIC',
#    'library_strategy': 'RNA-Seq',
#    'platform': 'ILLUMINA',
#    'secondary_id': [],
#    'study_id': 'SRP057595',
#    'submitter_id': [{'db': 'USC',
#      'id': 'Drosophila melanogaster Winters 80 Mated 2 Experiment 2'}],
#    'title': 'Drosophila melanogaster Winters 80 Mated 2 Experiment 2',
#    'url_links': [],
#    'uuid': [],
#    'xref_links': []},
#   'organization': {'abbreviation': 'USC_CORE',
#    'name': 'USC GENOME CORE',
#    'organization_type': 'center'},
#   'pool': ['SRS919397'],
#   'run': [{'download_path': 'https://sra-download.ncbi.nlm.nih.gov/traces/sra28/SRR/001943/SRR1989705',
#     'experiment_id': 'SRX1006753',
#     'external_id': [],
#     'load_date': '2015-04-27 03:16:53',
#     'nbases': 1229205,
#     'nreads': 1,
#     'nspots': 12939,
#     'read_count_r1': 12939.0,
#     'read_len_r1': 95.0,
#     'release_date': '2015-05-01 00:00:00',
#     'run_flags': ['SE'],
#     'run_id': 'SRR1989705',
#     'samples': ['SRS919397'],
#     'secondary_id': [],
#     'size_MB': 0,
#     'submitter_id': [{'db': 'USC', 'id': 'w80_M2.2.1.txt'}],
#     'tax_analysis': {'mapped_spots': 2535,
#      'nspot_analyze': 12939,
#      'tax_counts': {'Unkown': [{'name': 'cellular organisms',
#         'self_count': 0,
#         'tax_id': '131567',
#         'total_count': 2535},
#        {'name': 'Opisthokonta',
#         'parent': 'Eukaryota',
#         'self_count': 0,
#         'tax_id': '33154',
#         'total_count': 1888},
#        {'name': 'Eumetazoa',
#         'parent': 'Metazoa',
#         'self_count': 0,
#         'tax_id': '6072',
#         'total_count': 1888},
#        {'name': 'Bilateria',
#         'parent': 'Eumetazoa',
#         'self_count': 0,
#         'tax_id': '33213',
#         'total_count': 1888},
#        {'name': 'Protostomia',
#         'parent': 'Bilateria',
#         'self_count': 0,
#         'tax_id': '33317',
#         'total_count': 1888},
#        {'name': 'Ecdysozoa',
#         'parent': 'Protostomia',
#         'self_count': 0,
#         'tax_id': '1206794',
#         'total_count': 1888},
#        {'name': 'Panarthropoda',
#         'parent': 'Ecdysozoa',
#         'self_count': 0,
#         'tax_id': '88770',
#         'total_count': 1888},
#        {'name': 'Mandibulata',
#         'parent': 'Arthropoda',
#         'self_count': 0,
#         'tax_id': '197563',
#         'total_count': 1883},
#        {'name': 'Pancrustacea',
#         'parent': 'Mandibulata',
#         'self_count': 0,
#         'tax_id': '197562',
#         'total_count': 1883},
#        {'name': 'Dicondylia',
#         'parent': 'Insecta',
#         'self_count': 0,
#         'tax_id': '85512',
#         'total_count': 1883},
#        {'name': 'Pterygota',
#         'parent': 'Dicondylia',
#         'self_count': 0,
#         'tax_id': '7496',
#         'total_count': 1883},
#        {'name': 'Eremoneura',
#         'parent': 'Muscomorpha',
#         'self_count': 0,
#         'tax_id': '480118',
#         'total_count': 1814},
#        {'name': 'Cyclorrhapha',
#         'parent': 'Eremoneura',
#         'self_count': 0,
#         'tax_id': '480117',
#         'total_count': 1814},
#        {'name': 'Schizophora',
#         'parent': 'Cyclorrhapha',
#         'self_count': 11,
#         'tax_id': '43738',
#         'total_count': 1814},
#        {'name': 'Acalyptratae',
#         'parent': 'Schizophora',
#         'self_count': 15,
#         'tax_id': '43741',
#         'total_count': 1803},
#        {'name': 'Streptophytina',
#         'parent': 'Streptophyta',
#         'self_count': 0,
#         'tax_id': '131221',
#         'total_count': 121},
#        {'name': 'Embryophyta',
#         'parent': 'Streptophytina',
#         'self_count': 0,
#         'tax_id': '3193',
#         'total_count': 121},
#        {'name': 'Tracheophyta',
#         'parent': 'Embryophyta',
#         'self_count': 0,
#         'tax_id': '58023',
#         'total_count': 121},
#        {'name': 'Euphyllophyta',
#         'parent': 'Tracheophyta',
#         'self_count': 0,
#         'tax_id': '78536',
#         'total_count': 121},
#        {'name': 'Spermatophyta',
#         'parent': 'Euphyllophyta',
#         'self_count': 0,
#         'tax_id': '58024',
#         'total_count': 121},
#        {'name': 'Magnoliophyta',
#         'parent': 'Spermatophyta',
#         'self_count': 0,
#         'tax_id': '3398',
#         'total_count': 121},
#        {'name': 'Mesangiospermae',
#         'parent': 'Magnoliophyta',
#         'self_count': 1,
#         'tax_id': '1437183',
#         'total_count': 121},
#        {'name': 'eudicotyledons',
#         'parent': 'Mesangiospermae',
#         'self_count': 0,
#         'tax_id': '71240',
#         'total_count': 120},
#        {'name': 'Gunneridae',
#         'parent': 'eudicotyledons',
#         'self_count': 0,
#         'tax_id': '91827',
#         'total_count': 120},
#        {'name': 'Pentapetalae',
#         'parent': 'Gunneridae',
#         'self_count': 0,
#         'tax_id': '1437201',
#         'total_count': 120},
#        {'name': 'malvids',
#         'parent': 'rosids',
#         'self_count': 0,
#         'tax_id': '91836',
#         'total_count': 120},
#        {'name': 'Terrabacteria group',
#         'parent': 'Bacteria',
#         'self_count': 0,
#         'tax_id': '1783272',
#         'total_count': 13},
#        {'name': 'Pediococcus acidilactici group',
#         'parent': 'Pediococcus',
#         'self_count': 0,
#         'tax_id': '1670797',
#         'total_count': 13},
#        {'name': 'Pediococcus acidilactici D3',
#         'parent': 'Pediococcus acidilactici',
#         'self_count': 13,
#         'tax_id': '1306952',
#         'total_count': 13},
#        {'name': 'Pseudomonas syringae pv_ coryli str_ NCPPB 4273',
#         'parent': 'Pseudomonas syringae pv. coryli',
#         'self_count': 25,
#         'tax_id': '1397690',
#         'total_count': 25},
#        {'name': 'Bordetella holmesii 04P3421',
#         'parent': 'Bordetella holmesii',
#         'self_count': 2,
#         'tax_id': '1458267',
#         'total_count': 2}],
#       'class': [{'name': 'Insecta',
#         'parent': 'Hexapoda',
#         'self_count': 0,
#         'tax_id': '50557',
#         'total_count': 1883},
#        {'name': 'Bacilli',
#         'parent': 'Firmicutes',
#         'self_count': 0,
#         'tax_id': '91061',
#         'total_count': 13},
#        {'name': 'Gammaproteobacteria',
#         'parent': 'Proteobacteria',
#         'self_count': 0,
#         'tax_id': '1236',
#         'total_count': 28},
#        {'name': 'Betaproteobacteria',
#         'parent': 'Proteobacteria',
#         'self_count': 0,
#         'tax_id': '28216',
#         'total_count': 2}],
#       'family': [{'name': 'Drosophilidae',
#         'parent': 'Ephydroidea',
#         'self_count': 0,
#         'tax_id': '7214',
#         'total_count': 1788},
#        {'name': 'Brassicaceae',
#         'parent': 'Brassicales',
#         'self_count': 0,
#         'tax_id': '3700',
#         'total_count': 120},
#        {'name': 'Lactobacillaceae',
#         'parent': 'Lactobacillales',
#         'self_count': 0,
#         'tax_id': '33958',
#         'total_count': 13},
#        {'name': 'Pseudomonadaceae',
#         'parent': 'Pseudomonadales',
#         'self_count': 0,
#         'tax_id': '135621',
#         'total_count': 25},
#        {'name': 'Enterobacteriaceae',
#         'parent': 'Enterobacteriales',
#         'self_count': 0,
#         'tax_id': '543',
#         'total_count': 3},
#        {'name': 'Alcaligenaceae',
#         'parent': 'Burkholderiales',
#         'self_count': 0,
#         'tax_id': '506',
#         'total_count': 2}],
#       'genus': [{'name': 'Drosophila',
#         'parent': 'Drosophilini',
#         'self_count': 66,
#         'tax_id': '7215',
#         'total_count': 1788},
#        {'name': 'Arabidopsis',
#         'parent': 'Camelineae',
#         'self_count': 15,
#         'tax_id': '3701',
#         'total_count': 120},
#        {'name': 'Pediococcus',
#         'parent': 'Lactobacillaceae',
#         'self_count': 0,
#         'tax_id': '1253',
#         'total_count': 13},
#        {'name': 'Pseudomonas',
#         'parent': 'Pseudomonadaceae',
#         'self_count': 0,
#         'tax_id': '286',
#         'total_count': 25},
#        {'name': 'Salmonella',
#         'parent': 'Enterobacteriaceae',
#         'self_count': 0,
#         'tax_id': '590',
#         'total_count': 3},
#        {'name': 'Bordetella',
#         'parent': 'Alcaligenaceae',
#         'self_count': 0,
#         'tax_id': '517',
#         'total_count': 2}],
#       'infraclass': [{'name': 'Endopterygota',
#         'parent': 'Neoptera',
#         'self_count': 60,
#         'tax_id': '33392',
#         'total_count': 1882}],
#       'infraorder': [{'name': 'Muscomorpha',
#         'parent': 'Brachycera',
#         'self_count': 0,
#         'tax_id': '43733',
#         'total_count': 1814}],
#       'kingdom': [{'name': 'Metazoa',
#         'parent': 'Opisthokonta',
#         'self_count': 0,
#         'tax_id': '33208',
#         'total_count': 1888},
#        {'name': 'Viridiplantae',
#         'parent': 'Eukaryota',
#         'self_count': 0,
#         'tax_id': '33090',
#         'total_count': 121}],
#       'order': [{'name': 'Diptera',
#         'parent': 'Endopterygota',
#         'self_count': 8,
#         'tax_id': '7147',
#         'total_count': 1822},
#        {'name': 'Brassicales',
#         'parent': 'malvids',
#         'self_count': 0,
#         'tax_id': '3699',
#         'total_count': 120},
#        {'name': 'Lactobacillales',
#         'parent': 'Bacilli',
#         'self_count': 0,
#         'tax_id': '186826',
#         'total_count': 13},
#        {'name': 'Pseudomonadales',
#         'parent': 'Gammaproteobacteria',
#         'self_count': 0,
#         'tax_id': '72274',
#         'total_count': 25},
#        {'name': 'Enterobacteriales',
#         'parent': 'Gammaproteobacteria',
#         'self_count': 0,
#         'tax_id': '91347',
#         'total_count': 3},
#        {'name': 'Burkholderiales',
#         'parent': 'Betaproteobacteria',
#         'self_count': 0,
#         'tax_id': '80840',
#         'total_count': 2}],
#       'phylum': [{'name': 'Arthropoda',
#         'parent': 'Panarthropoda',
#         'self_count': 5,
#         'tax_id': '6656',
#         'total_count': 1888},
#        {'name': 'Streptophyta',
#         'parent': 'Viridiplantae',
#         'self_count': 0,
#         'tax_id': '35493',
#         'total_count': 121},
#        {'name': 'Firmicutes',
#         'parent': 'Terrabacteria group',
#         'self_count': 0,
#         'tax_id': '1239',
#         'total_count': 13},
#        {'name': 'Proteobacteria',
#         'parent': 'Bacteria',
#         'self_count': 45,
#         'tax_id': '1224',
#         'total_count': 75}],
#       'species': [{'name': 'Drosophila persimilis',
#         'parent': 'pseudoobscura subgroup',
#         'self_count': 14,
#         'tax_id': '7234',
#         'total_count': 14},
#        {'name': 'Drosophila sechellia',
#         'parent': 'melanogaster subgroup',
#         'self_count': 86,
#         'tax_id': '7238',
#         'total_count': 86},
#        {'name': 'Arabidopsis thaliana',
#         'parent': 'Arabidopsis',
#         'self_count': 105,
#         'tax_id': '3702',
#         'total_count': 105},
#        {'name': 'Pediococcus acidilactici',
#         'parent': 'Pediococcus acidilactici group',
#         'self_count': 0,
#         'tax_id': '1254',
#         'total_count': 13},
#        {'name': 'Pseudomonas syringae pv_ coryli',
#         'parent': 'Pseudomonas syringae group genomosp. 2',
#         'self_count': 0,
#         'tax_id': '317659',
#         'total_count': 25},
#        {'name': 'Salmonella enterica',
#         'parent': 'Salmonella',
#         'self_count': 3,
#         'tax_id': '28901',
#         'total_count': 3},
#        {'name': 'Bordetella holmesii',
#         'parent': 'Bordetella',
#         'self_count': 0,
#         'tax_id': '35814',
#         'total_count': 2}],
#       'species group': [{'name': 'obscura group',
#         'parent': 'Sophophora',
#         'self_count': 0,
#         'tax_id': '32355',
#         'total_count': 221},
#        {'name': 'melanogaster group',
#         'parent': 'Sophophora',
#         'self_count': 0,
#         'tax_id': '32346',
#         'total_count': 1451},
#        {'name': 'Pseudomonas syringae group',
#         'parent': 'Pseudomonas',
#         'self_count': 0,
#         'tax_id': '136849',
#         'total_count': 25}],
#       'species subgroup': [{'name': 'pseudoobscura subgroup',
#         'parent': 'obscura group',
#         'self_count': 207,
#         'tax_id': '32358',
#         'total_count': 221},
#        {'name': 'melanogaster subgroup',
#         'parent': 'melanogaster group',
#         'self_count': 1365,
#         'tax_id': '32351',
#         'total_count': 1451},
#        {'name': 'Pseudomonas syringae group genomosp_ 2',
#         'parent': 'Pseudomonas syringae group',
#         'self_count': 0,
#         'tax_id': '251698',
#         'total_count': 25}],
#       'subclass': [{'name': 'Neoptera',
#         'parent': 'Pterygota',
#         'self_count': 1,
#         'tax_id': '33340',
#         'total_count': 1883},
#        {'name': 'rosids',
#         'parent': 'Pentapetalae',
#         'self_count': 0,
#         'tax_id': '71275',
#         'total_count': 120}],
#       'subfamily': [{'name': 'Drosophilinae',
#         'parent': 'Drosophilidae',
#         'self_count': 0,
#         'tax_id': '43845',
#         'total_count': 1788}],
#       'subgenus': [{'name': 'Sophophora',
#         'parent': 'Drosophila',
#         'self_count': 50,
#         'tax_id': '32341',
#         'total_count': 1722}],
#       'suborder': [{'name': 'Brachycera',
#         'parent': 'Diptera',
#         'self_count': 0,
#         'tax_id': '7203',
#         'total_count': 1814}],
#       'superclass': [{'name': 'Hexapoda',
#         'parent': 'Pancrustacea',
#         'self_count': 0,
#         'tax_id': '6960',
#         'total_count': 1883}],
#       'superfamily': [{'name': 'Ephydroidea',
#         'parent': 'Acalyptratae',
#         'self_count': 0,
#         'tax_id': '43746',
#         'total_count': 1788}],
#       'superkingdom': [{'name': 'Eukaryota',
#         'parent': 'cellular organisms',
#         'self_count': 68,
#         'tax_id': '2759',
#         'total_count': 2077},
#        {'name': 'Bacteria',
#         'parent': 'cellular organisms',
#         'self_count': 370,
#         'tax_id': '2',
#         'total_count': 458}],
#       'tribe': [{'name': 'Drosophilini',
#         'parent': 'Drosophilinae',
#         'self_count': 0,
#         'tax_id': '46877',
#         'total_count': 1788},
#        {'name': 'Camelineae',
#         'parent': 'Brassicaceae',
#         'self_count': 0,
#         'tax_id': '980083',
#         'total_count': 120}]},
#      'total_spots': 12939},
#     'uuid': []},
#    {'download_path': 'https://sra-download.ncbi.nlm.nih.gov/traces/sra28/SRR/001943/SRR1990623',
#     'experiment_id': 'SRX1006753',
#     'external_id': [],
#     'load_date': '2015-04-27 03:16:51',
#     'nbases': 1051175,
#     'nreads': 1,
#     'nspots': 11065,
#     'read_count_r1': 11065.0,
#     'read_len_r1': 95.0,
#     'release_date': '2015-05-01 00:00:00',
#     'run_flags': ['SE'],
#     'run_id': 'SRR1990623',
#     'samples': ['SRS919397'],
#     'secondary_id': [],
#     'size_MB': 0,
#     'submitter_id': [{'db': 'USC', 'id': 'w80_M2.4.1.txt'}],
#     'tax_analysis': {'mapped_spots': 1910,
#      'nspot_analyze': 11065,
#      'tax_counts': {'Unkown': [{'name': 'cellular organisms',
#         'self_count': 0,
#         'tax_id': '131567',
#         'total_count': 1910},
#        {'name': 'Opisthokonta',
#         'parent': 'Eukaryota',
#         'self_count': 0,
#         'tax_id': '33154',
#         'total_count': 1415},
#        {'name': 'Eumetazoa',
#         'parent': 'Metazoa',
#         'self_count': 0,
#         'tax_id': '6072',
#         'total_count': 1415},
#        {'name': 'Bilateria',
#         'parent': 'Eumetazoa',
#         'self_count': 0,
#         'tax_id': '33213',
#         'total_count': 1415},
#        {'name': 'Protostomia',
#         'parent': 'Bilateria',
#         'self_count': 1,
#         'tax_id': '33317',
#         'total_count': 1415},
#        {'name': 'Ecdysozoa',
#         'parent': 'Protostomia',
#         'self_count': 0,
#         'tax_id': '1206794',
#         'total_count': 1414},
#        {'name': 'Panarthropoda',
#         'parent': 'Ecdysozoa',
#         'self_count': 0,
#         'tax_id': '88770',
#         'total_count': 1414},
#        {'name': 'Mandibulata',
#         'parent': 'Arthropoda',
#         'self_count': 0,
#         'tax_id': '197563',
#         'total_count': 1406},
#        {'name': 'Pancrustacea',
#         'parent': 'Mandibulata',
#         'self_count': 0,
#         'tax_id': '197562',
#         'total_count': 1406},
#        {'name': 'Dicondylia',
#         'parent': 'Insecta',
#         'self_count': 0,
#         'tax_id': '85512',
#         'total_count': 1406},
#        {'name': 'Pterygota',
#         'parent': 'Dicondylia',
#         'self_count': 0,
#         'tax_id': '7496',
#         'total_count': 1406},
#        {'name': 'Eremoneura',
#         'parent': 'Muscomorpha',
#         'self_count': 0,
#         'tax_id': '480118',
#         'total_count': 1370},
#        {'name': 'Cyclorrhapha',
#         'parent': 'Eremoneura',
#         'self_count': 0,
#         'tax_id': '480117',
#         'total_count': 1370},
#        {'name': 'Schizophora',
#         'parent': 'Cyclorrhapha',
#         'self_count': 10,
#         'tax_id': '43738',
#         'total_count': 1370},
#        {'name': 'Acalyptratae',
#         'parent': 'Schizophora',
#         'self_count': 11,
#         'tax_id': '43741',
#         'total_count': 1360},
#        {'name': 'Streptophytina',
#         'parent': 'Streptophyta',
#         'self_count': 0,
#         'tax_id': '131221',
#         'total_count': 9},
#        {'name': 'Embryophyta',
#         'parent': 'Streptophytina',
#         'self_count': 0,
#         'tax_id': '3193',
#         'total_count': 9},
#        {'name': 'Tracheophyta',
#         'parent': 'Embryophyta',
#         'self_count': 0,
#         'tax_id': '58023',
#         'total_count': 9},
#        {'name': 'Euphyllophyta',
#         'parent': 'Tracheophyta',
#         'self_count': 0,
#         'tax_id': '78536',
#         'total_count': 9},
#        {'name': 'Spermatophyta',
#         'parent': 'Euphyllophyta',
#         'self_count': 0,
#         'tax_id': '58024',
#         'total_count': 9},
#        {'name': 'Magnoliophyta',
#         'parent': 'Spermatophyta',
#         'self_count': 0,
#         'tax_id': '3398',
#         'total_count': 9},
#        {'name': 'Mesangiospermae',
#         'parent': 'Magnoliophyta',
#         'self_count': 0,
#         'tax_id': '1437183',
#         'total_count': 9},
#        {'name': 'eudicotyledons',
#         'parent': 'Mesangiospermae',
#         'self_count': 0,
#         'tax_id': '71240',
#         'total_count': 9},
#        {'name': 'Gunneridae',
#         'parent': 'eudicotyledons',
#         'self_count': 0,
#         'tax_id': '91827',
#         'total_count': 9},
#        {'name': 'Pentapetalae',
#         'parent': 'Gunneridae',
#         'self_count': 0,
#         'tax_id': '1437201',
#         'total_count': 9},
#        {'name': 'malvids',
#         'parent': 'rosids',
#         'self_count': 0,
#         'tax_id': '91836',
#         'total_count': 9},
#        {'name': 'Bordetella bronchiseptica E013',
#         'parent': 'Bordetella bronchiseptica',
#         'self_count': 41,
#         'tax_id': '1458266',
#         'total_count': 41},
#        {'name': 'Bordetella holmesii 04P3421',
#         'parent': 'Bordetella holmesii',
#         'self_count': 2,
#         'tax_id': '1458267',
#         'total_count': 2},
#        {'name': 'Pseudomonas syringae pv_ coryli str_ NCPPB 4273',
#         'parent': 'Pseudomonas syringae pv. coryli',
#         'self_count': 21,
#         'tax_id': '1397690',
#         'total_count': 21},
#        {'name': 'Balneola vulgaris DSM 17893',
#         'parent': 'Balneola vulgaris',
#         'self_count': 1,
#         'tax_id': '1121104',
#         'total_count': 1},
#        {'name': 'Terrabacteria group',
#         'parent': 'Bacteria',
#         'self_count': 0,
#         'tax_id': '1783272',
#         'total_count': 7},
#        {'name': 'Pediococcus acidilactici group',
#         'parent': 'Pediococcus',
#         'self_count': 0,
#         'tax_id': '1670797',
#         'total_count': 7},
#        {'name': 'Pediococcus acidilactici D3',
#         'parent': 'Pediococcus acidilactici',
#         'self_count': 7,
#         'tax_id': '1306952',
#         'total_count': 7}],
#       'class': [{'name': 'Insecta',
#         'parent': 'Hexapoda',
#         'self_count': 0,
#         'tax_id': '50557',
#         'total_count': 1406},
#        {'name': 'Betaproteobacteria',
#         'parent': 'Proteobacteria',
#         'self_count': 0,
#         'tax_id': '28216',
#         'total_count': 51},
#        {'name': 'Gammaproteobacteria',
#         'parent': 'Proteobacteria',
#         'self_count': 0,
#         'tax_id': '1236',
#         'total_count': 21},
#        {'name': 'Balneolia',
#         'parent': 'Rhodothermaeota',
#         'self_count': 0,
#         'tax_id': '1853221',
#         'total_count': 1},
#        {'name': 'Bacilli',
#         'parent': 'Firmicutes',
#         'self_count': 0,
#         'tax_id': '91061',
#         'total_count': 7}],
#       'family': [{'name': 'Drosophilidae',
#         'parent': 'Ephydroidea',
#         'self_count': 0,
#         'tax_id': '7214',
#         'total_count': 1349},
#        {'name': 'Brassicaceae',
#         'parent': 'Brassicales',
#         'self_count': 7,
#         'tax_id': '3700',
#         'total_count': 7},
#        {'name': 'Burkholderiaceae',
#         'parent': 'Burkholderiales',
#         'self_count': 8,
#         'tax_id': '119060',
#         'total_count': 8},
#        {'name': 'Alcaligenaceae',
#         'parent': 'Burkholderiales',
#         'self_count': 0,
#         'tax_id': '506',
#         'total_count': 43},
#        {'name': 'Pseudomonadaceae',
#         'parent': 'Pseudomonadales',
#         'self_count': 0,
#         'tax_id': '135621',
#         'total_count': 21},
#        {'name': 'Balneolaceae',
#         'parent': 'Balneolales',
#         'self_count': 0,
#         'tax_id': '1813606',
#         'total_count': 1},
#        {'name': 'Lactobacillaceae',
#         'parent': 'Lactobacillales',
#         'self_count': 0,
#         'tax_id': '33958',
#         'total_count': 7}],
#       'genus': [{'name': 'Drosophila',
#         'parent': 'Drosophilini',
#         'self_count': 39,
#         'tax_id': '7215',
#         'total_count': 1349},
#        {'name': 'Bordetella',
#         'parent': 'Alcaligenaceae',
#         'self_count': 0,
#         'tax_id': '517',
#         'total_count': 43},
#        {'name': 'Pseudomonas',
#         'parent': 'Pseudomonadaceae',
#         'self_count': 0,
#         'tax_id': '286',
#         'total_count': 21},
#        {'name': 'Balneola',
#         'parent': 'Balneolaceae',
#         'self_count': 0,
#         'tax_id': '455358',
#         'total_count': 1},
#        {'name': 'Pediococcus',
#         'parent': 'Lactobacillaceae',
#         'self_count': 0,
#         'tax_id': '1253',
#         'total_count': 7}],
#       'infraclass': [{'name': 'Endopterygota',
#         'parent': 'Neoptera',
#         'self_count': 31,
#         'tax_id': '33392',
#         'total_count': 1406}],
#       'infraorder': [{'name': 'Muscomorpha',
#         'parent': 'Brachycera',
#         'self_count': 0,
#         'tax_id': '43733',
#         'total_count': 1370}],
#       'kingdom': [{'name': 'Metazoa',
#         'parent': 'Opisthokonta',
#         'self_count': 0,
#         'tax_id': '33208',
#         'total_count': 1415},
#        {'name': 'Viridiplantae',
#         'parent': 'Eukaryota',
#         'self_count': 0,
#         'tax_id': '33090',
#         'total_count': 9}],
#       'order': [{'name': 'Diptera',
#         'parent': 'Endopterygota',
#         'self_count': 5,
#         'tax_id': '7147',
#         'total_count': 1375},
#        {'name': 'Brassicales',
#         'parent': 'malvids',
#         'self_count': 2,
#         'tax_id': '3699',
#         'total_count': 9},
#        {'name': 'Burkholderiales',
#         'parent': 'Betaproteobacteria',
#         'self_count': 0,
#         'tax_id': '80840',
#         'total_count': 51},
#        {'name': 'Pseudomonadales',
#         'parent': 'Gammaproteobacteria',
#         'self_count': 0,
#         'tax_id': '72274',
#         'total_count': 21},
#        {'name': 'Balneolales',
#         'parent': 'Balneolia',
#         'self_count': 0,
#         'tax_id': '1853223',
#         'total_count': 1},
#        {'name': 'Lactobacillales',
#         'parent': 'Bacilli',
#         'self_count': 0,
#         'tax_id': '186826',
#         'total_count': 7}],
#       'phylum': [{'name': 'Arthropoda',
#         'parent': 'Panarthropoda',
#         'self_count': 8,
#         'tax_id': '6656',
#         'total_count': 1414},
#        {'name': 'Streptophyta',
#         'parent': 'Viridiplantae',
#         'self_count': 0,
#         'tax_id': '35493',
#         'total_count': 9},
#        {'name': 'Proteobacteria',
#         'parent': 'Bacteria',
#         'self_count': 37,
#         'tax_id': '1224',
#         'total_count': 109},
#        {'name': 'Rhodothermaeota',
#         'parent': 'Bacteria',
#         'self_count': 0,
#         'tax_id': '1853220',
#         'total_count': 1},
#        {'name': 'Firmicutes',
#         'parent': 'Terrabacteria group',
#         'self_count': 0,
#         'tax_id': '1239',
#         'total_count': 7}],
#       'species': [{'name': 'Drosophila pseudoobscura',
#         'parent': 'pseudoobscura subgroup',
#         'self_count': 0,
#         'tax_id': '7237',
#         'total_count': 47},
#        {'name': 'Drosophila simulans',
#         'parent': 'melanogaster subgroup',
#         'self_count': 100,
#         'tax_id': '7240',
#         'total_count': 100},
#        {'name': 'Bordetella bronchiseptica',
#         'parent': 'Bordetella',
#         'self_count': 0,
#         'tax_id': '518',
#         'total_count': 41},
#        {'name': 'Bordetella holmesii',
#         'parent': 'Bordetella',
#         'self_count': 0,
#         'tax_id': '35814',
#         'total_count': 2},
#        {'name': 'Pseudomonas syringae pv_ coryli',
#         'parent': 'Pseudomonas syringae group genomosp. 2',
#         'self_count': 0,
#         'tax_id': '317659',
#         'total_count': 21},
#        {'name': 'Balneola vulgaris',
#         'parent': 'Balneola',
#         'self_count': 0,
#         'tax_id': '287535',
#         'total_count': 1},
#        {'name': 'Pediococcus acidilactici',
#         'parent': 'Pediococcus acidilactici group',
#         'self_count': 0,
#         'tax_id': '1254',
#         'total_count': 7}],
#       'species group': [{'name': 'obscura group',
#         'parent': 'Sophophora',
#         'self_count': 0,
#         'tax_id': '32355',
#         'total_count': 256},
#        {'name': 'melanogaster group',
#         'parent': 'Sophophora',
#         'self_count': 0,
#         'tax_id': '32346',
#         'total_count': 1054},
#        {'name': 'Pseudomonas syringae group',
#         'parent': 'Pseudomonas',
#         'self_count': 0,
#         'tax_id': '136849',
#         'total_count': 21}],
#       'species subgroup': [{'name': 'pseudoobscura subgroup',
#         'parent': 'obscura group',
#         'self_count': 209,
#         'tax_id': '32358',
#         'total_count': 256},
#        {'name': 'melanogaster subgroup',
#         'parent': 'melanogaster group',
#         'self_count': 954,
#         'tax_id': '32351',
#         'total_count': 1054},
#        {'name': 'Pseudomonas syringae group genomosp_ 2',
#         'parent': 'Pseudomonas syringae group',
#         'self_count': 0,
#         'tax_id': '251698',
#         'total_count': 21}],
#       'subclass': [{'name': 'Neoptera',
#         'parent': 'Pterygota',
#         'self_count': 0,
#         'tax_id': '33340',
#         'total_count': 1406},
#        {'name': 'rosids',
#         'parent': 'Pentapetalae',
#         'self_count': 0,
#         'tax_id': '71275',
#         'total_count': 9}],
#       'subfamily': [{'name': 'Drosophilinae',
#         'parent': 'Drosophilidae',
#         'self_count': 0,
#         'tax_id': '43845',
#         'total_count': 1349}],
#       'subgenus': [{'name': 'Sophophora',
#         'parent': 'Drosophila',
#         'self_count': 0,
#         'tax_id': '32341',
#         'total_count': 1310}],
#       'suborder': [{'name': 'Brachycera',
#         'parent': 'Diptera',
#         'self_count': 0,
#         'tax_id': '7203',
#         'total_count': 1370}],
#       'subspecies': [{'name': 'Drosophila pseudoobscura pseudoobscura',
#         'parent': 'Drosophila pseudoobscura',
#         'self_count': 47,
#         'tax_id': '46245',
#         'total_count': 47}],
#       'superclass': [{'name': 'Hexapoda',
#         'parent': 'Pancrustacea',
#         'self_count': 0,
#         'tax_id': '6960',
#         'total_count': 1406}],
#       'superfamily': [{'name': 'Ephydroidea',
#         'parent': 'Acalyptratae',
#         'self_count': 0,
#         'tax_id': '43746',
#         'total_count': 1349}],
#       'superkingdom': [{'name': 'Eukaryota',
#         'parent': 'cellular organisms',
#         'self_count': 47,
#         'tax_id': '2759',
#         'total_count': 1471},
#        {'name': 'Bacteria',
#         'parent': 'cellular organisms',
#         'self_count': 322,
#         'tax_id': '2',
#         'total_count': 439}],
#       'tribe': [{'name': 'Drosophilini',
#         'parent': 'Drosophilinae',
#         'self_count': 0,
#         'tax_id': '46877',
#         'total_count': 1349}]},
#      'total_spots': 11065},
#     'uuid': []},
#    {'download_path': 'https://sra-download.ncbi.nlm.nih.gov/traces/sra28/SRR/001944/SRR1991247',
#     'experiment_id': 'SRX1006753',
#     'external_id': [],
#     'load_date': '2015-04-27 03:16:49',
#     'nbases': 803225,
#     'nreads': 1,
#     'nspots': 8455,
#     'read_count_r1': 8455.0,
#     'read_len_r1': 95.0,
#     'release_date': '2015-05-01 00:00:00',
#     'run_flags': ['SE'],
#     'run_id': 'SRR1991247',
#     'samples': ['SRS919397'],
#     'secondary_id': [],
#     'size_MB': 0,
#     'submitter_id': [{'db': 'USC', 'id': 'w80_M2.6.1.txt'}],
#     'tax_analysis': {'mapped_spots': 1493,
#      'nspot_analyze': 8455,
#      'tax_counts': {'Unkown': [{'name': 'cellular organisms',
#         'self_count': 0,
#         'tax_id': '131567',
#         'total_count': 1493},
#        {'name': 'Opisthokonta',
#         'parent': 'Eukaryota',
#         'self_count': 0,
#         'tax_id': '33154',
#         'total_count': 977},
#        {'name': 'Eumetazoa',
#         'parent': 'Metazoa',
#         'self_count': 0,
#         'tax_id': '6072',
#         'total_count': 977},
#        {'name': 'Bilateria',
#         'parent': 'Eumetazoa',
#         'self_count': 0,
#         'tax_id': '33213',
#         'total_count': 977},
#        {'name': 'Protostomia',
#         'parent': 'Bilateria',
#         'self_count': 1,
#         'tax_id': '33317',
#         'total_count': 977},
#        {'name': 'Ecdysozoa',
#         'parent': 'Protostomia',
#         'self_count': 0,
#         'tax_id': '1206794',
#         'total_count': 976},
#        {'name': 'Panarthropoda',
#         'parent': 'Ecdysozoa',
#         'self_count': 0,
#         'tax_id': '88770',
#         'total_count': 976},
#        {'name': 'Mandibulata',
#         'parent': 'Arthropoda',
#         'self_count': 0,
#         'tax_id': '197563',
#         'total_count': 974},
#        {'name': 'Pancrustacea',
#         'parent': 'Mandibulata',
#         'self_count': 0,
#         'tax_id': '197562',
#         'total_count': 974},
#        {'name': 'Dicondylia',
#         'parent': 'Insecta',
#         'self_count': 0,
#         'tax_id': '85512',
#         'total_count': 974},
#        {'name': 'Pterygota',
#         'parent': 'Dicondylia',
#         'self_count': 0,
#         'tax_id': '7496',
#         'total_count': 974},
#        {'name': 'Eremoneura',
#         'parent': 'Muscomorpha',
#         'self_count': 0,
#         'tax_id': '480118',
#         'total_count': 940},
#        {'name': 'Cyclorrhapha',
#         'parent': 'Eremoneura',
#         'self_count': 0,
#         'tax_id': '480117',
#         'total_count': 940},
#        {'name': 'Schizophora',
#         'parent': 'Cyclorrhapha',
#         'self_count': 4,
#         'tax_id': '43738',
#         'total_count': 940},
#        {'name': 'Acalyptratae',
#         'parent': 'Schizophora',
#         'self_count': 4,
#         'tax_id': '43741',
#         'total_count': 936},
#        {'name': 'Streptophytina',
#         'parent': 'Streptophyta',
#         'self_count': 0,
#         'tax_id': '131221',
#         'total_count': 27},
#        {'name': 'Embryophyta',
#         'parent': 'Streptophytina',
#         'self_count': 0,
#         'tax_id': '3193',
#         'total_count': 27},
#        {'name': 'Tracheophyta',
#         'parent': 'Embryophyta',
#         'self_count': 0,
#         'tax_id': '58023',
#         'total_count': 27},
#        {'name': 'Euphyllophyta',
#         'parent': 'Tracheophyta',
#         'self_count': 0,
#         'tax_id': '78536',
#         'total_count': 27},
#        {'name': 'Spermatophyta',
#         'parent': 'Euphyllophyta',
#         'self_count': 0,
#         'tax_id': '58024',
#         'total_count': 27},
#        {'name': 'Magnoliophyta',
#         'parent': 'Spermatophyta',
#         'self_count': 0,
#         'tax_id': '3398',
#         'total_count': 27},
#        {'name': 'Mesangiospermae',
#         'parent': 'Magnoliophyta',
#         'self_count': 0,
#         'tax_id': '1437183',
#         'total_count': 27},
#        {'name': 'eudicotyledons',
#         'parent': 'Mesangiospermae',
#         'self_count': 0,
#         'tax_id': '71240',
#         'total_count': 27},
#        {'name': 'Gunneridae',
#         'parent': 'eudicotyledons',
#         'self_count': 0,
#         'tax_id': '91827',
#         'total_count': 27},
#        {'name': 'Pentapetalae',
#         'parent': 'Gunneridae',
#         'self_count': 0,
#         'tax_id': '1437201',
#         'total_count': 27},
#        {'name': 'malvids',
#         'parent': 'rosids',
#         'self_count': 0,
#         'tax_id': '91836',
#         'total_count': 27},
#        {'name': 'Bordetella bronchiseptica E013',
#         'parent': 'Bordetella bronchiseptica',
#         'self_count': 40,
#         'tax_id': '1458266',
#         'total_count': 40},
#        {'name': 'Pseudomonas syringae pv_ coryli str_ NCPPB 4273',
#         'parent': 'Pseudomonas syringae pv. coryli',
#         'self_count': 22,
#         'tax_id': '1397690',
#         'total_count': 22},
#        {'name': 'Terrabacteria group',
#         'parent': 'Bacteria',
#         'self_count': 0,
#         'tax_id': '1783272',
#         'total_count': 11},
#        {'name': 'Pediococcus acidilactici group',
#         'parent': 'Pediococcus',
#         'self_count': 0,
#         'tax_id': '1670797',
#         'total_count': 10},
#        {'name': 'Pediococcus acidilactici D3',
#         'parent': 'Pediococcus acidilactici',
#         'self_count': 10,
#         'tax_id': '1306952',
#         'total_count': 10},
#        {'name': 'Mycobacterium bovis BCG',
#         'parent': 'Mycobacterium bovis',
#         'self_count': 1,
#         'tax_id': '33892',
#         'total_count': 1}],
#       'class': [{'name': 'Insecta',
#         'parent': 'Hexapoda',
#         'self_count': 0,
#         'tax_id': '50557',
#         'total_count': 974},
#        {'name': 'Betaproteobacteria',
#         'parent': 'Proteobacteria',
#         'self_count': 0,
#         'tax_id': '28216',
#         'total_count': 43},
#        {'name': 'Gammaproteobacteria',
#         'parent': 'Proteobacteria',
#         'self_count': 0,
#         'tax_id': '1236',
#         'total_count': 29},
#        {'name': 'Bacilli',
#         'parent': 'Firmicutes',
#         'self_count': 0,
#         'tax_id': '91061',
#         'total_count': 10},
#        {'name': 'Actinobacteria',
#         'parent': 'Actinobacteria',
#         'self_count': 0,
#         'tax_id': '1760',
#         'total_count': 1}],
#       'family': [{'name': 'Drosophilidae',
#         'parent': 'Ephydroidea',
#         'self_count': 0,
#         'tax_id': '7214',
#         'total_count': 932},
#        {'name': 'Brassicaceae',
#         'parent': 'Brassicales',
#         'self_count': 0,
#         'tax_id': '3700',
#         'total_count': 27},
#        {'name': 'Burkholderiaceae',
#         'parent': 'Burkholderiales',
#         'self_count': 3,
#         'tax_id': '119060',
#         'total_count': 3},
#        {'name': 'Alcaligenaceae',
#         'parent': 'Burkholderiales',
#         'self_count': 0,
#         'tax_id': '506',
#         'total_count': 40},
#        {'name': 'Pseudomonadaceae',
#         'parent': 'Pseudomonadales',
#         'self_count': 0,
#         'tax_id': '135621',
#         'total_count': 22},
#        {'name': 'Enterobacteriaceae',
#         'parent': 'Enterobacteriales',
#         'self_count': 0,
#         'tax_id': '543',
#         'total_count': 7},
#        {'name': 'Lactobacillaceae',
#         'parent': 'Lactobacillales',
#         'self_count': 0,
#         'tax_id': '33958',
#         'total_count': 10},
#        {'name': 'Mycobacteriaceae',
#         'parent': 'Corynebacteriales',
#         'self_count': 0,
#         'tax_id': '1762',
#         'total_count': 1}],
#       'genus': [{'name': 'Drosophila',
#         'parent': 'Drosophilini',
#         'self_count': 29,
#         'tax_id': '7215',
#         'total_count': 932},
#        {'name': 'Bordetella',
#         'parent': 'Alcaligenaceae',
#         'self_count': 0,
#         'tax_id': '517',
#         'total_count': 40},
#        {'name': 'Pseudomonas',
#         'parent': 'Pseudomonadaceae',
#         'self_count': 0,
#         'tax_id': '286',
#         'total_count': 22},
#        {'name': 'Salmonella',
#         'parent': 'Enterobacteriaceae',
#         'self_count': 0,
#         'tax_id': '590',
#         'total_count': 7},
#        {'name': 'Pediococcus',
#         'parent': 'Lactobacillaceae',
#         'self_count': 0,
#         'tax_id': '1253',
#         'total_count': 10},
#        {'name': 'Mycobacterium',
#         'parent': 'Mycobacteriaceae',
#         'self_count': 0,
#         'tax_id': '1763',
#         'total_count': 1}],
#       'infraclass': [{'name': 'Endopterygota',
#         'parent': 'Neoptera',
#         'self_count': 30,
#         'tax_id': '33392',
#         'total_count': 973}],
#       'infraorder': [{'name': 'Muscomorpha',
#         'parent': 'Brachycera',
#         'self_count': 0,
#         'tax_id': '43733',
#         'total_count': 940}],
#       'kingdom': [{'name': 'Metazoa',
#         'parent': 'Opisthokonta',
#         'self_count': 0,
#         'tax_id': '33208',
#         'total_count': 977},
#        {'name': 'Viridiplantae',
#         'parent': 'Eukaryota',
#         'self_count': 0,
#         'tax_id': '33090',
#         'total_count': 27}],
#       'order': [{'name': 'Diptera',
#         'parent': 'Endopterygota',
#         'self_count': 3,
#         'tax_id': '7147',
#         'total_count': 943},
#        {'name': 'Brassicales',
#         'parent': 'malvids',
#         'self_count': 0,
#         'tax_id': '3699',
#         'total_count': 27},
#        {'name': 'Burkholderiales',
#         'parent': 'Betaproteobacteria',
#         'self_count': 0,
#         'tax_id': '80840',
#         'total_count': 43},
#        {'name': 'Pseudomonadales',
#         'parent': 'Gammaproteobacteria',
#         'self_count': 0,
#         'tax_id': '72274',
#         'total_count': 22},
#        {'name': 'Enterobacteriales',
#         'parent': 'Gammaproteobacteria',
#         'self_count': 0,
#         'tax_id': '91347',
#         'total_count': 7},
#        {'name': 'Lactobacillales',
#         'parent': 'Bacilli',
#         'self_count': 0,
#         'tax_id': '186826',
#         'total_count': 10},
#        {'name': 'Corynebacteriales',
#         'parent': 'Actinobacteria',
#         'self_count': 0,
#         'tax_id': '85007',
#         'total_count': 1}],
#       'phylum': [{'name': 'Arthropoda',
#         'parent': 'Panarthropoda',
#         'self_count': 2,
#         'tax_id': '6656',
#         'total_count': 976},
#        {'name': 'Streptophyta',
#         'parent': 'Viridiplantae',
#         'self_count': 0,
#         'tax_id': '35493',
#         'total_count': 27},
#        {'name': 'Proteobacteria',
#         'parent': 'Bacteria',
#         'self_count': 28,
#         'tax_id': '1224',
#         'total_count': 100},
#        {'name': 'Firmicutes',
#         'parent': 'Terrabacteria group',
#         'self_count': 0,
#         'tax_id': '1239',
#         'total_count': 10},
#        {'name': 'Actinobacteria',
#         'parent': 'Terrabacteria group',
#         'self_count': 0,
#         'tax_id': '201174',
#         'total_count': 1}],
#       'species': [{'name': 'Drosophila pseudoobscura',
#         'parent': 'pseudoobscura subgroup',
#         'self_count': 0,
#         'tax_id': '7237',
#         'total_count': 27},
#        {'name': 'Drosophila erecta',
#         'parent': 'melanogaster subgroup',
#         'self_count': 27,
#         'tax_id': '7220',
#         'total_count': 27},
#        {'name': 'Drosophila sechellia',
#         'parent': 'melanogaster subgroup',
#         'self_count': 48,
#         'tax_id': '7238',
#         'total_count': 48},
#        {'name': 'Drosophila simulans',
#         'parent': 'melanogaster subgroup',
#         'self_count': 53,
#         'tax_id': '7240',
#         'total_count': 53},
#        {'name': 'Bordetella bronchiseptica',
#         'parent': 'Bordetella',
#         'self_count': 0,
#         'tax_id': '518',
#         'total_count': 40},
#        {'name': 'Pseudomonas syringae pv_ coryli',
#         'parent': 'Pseudomonas syringae group genomosp. 2',
#         'self_count': 0,
#         'tax_id': '317659',
#         'total_count': 22},
#        {'name': 'Salmonella enterica',
#         'parent': 'Salmonella',
#         'self_count': 7,
#         'tax_id': '28901',
#         'total_count': 7},
# ...
#         'total_count': 117},
#        {'name': 'Euphyllophyta',
#         'parent': 'Tracheophyta',
#         'self_count': 0,
#         'tax_id': '78536',
#         'total_count': 117},
#        {'name': 'Spermatophyta',
#         'parent': 'Euphyllophyta',
#         'self_count': 0,
#         'tax_id': '58024',
#         'total_count': 117},
#        {'name': 'Magnoliophyta',
#         'parent': 'Spermatophyta',
#         'self_count': 0,
#         'tax_id': '3398',
#         'total_count': 117},
#        {'name': 'Mesangiospermae',
#         'parent': 'Magnoliophyta',
#         'self_count': 0,
#         'tax_id': '1437183',
#         'total_count': 117},
#        {'name': 'eudicotyledons',
#         'parent': 'Mesangiospermae',
#         'self_count': 0,
#         'tax_id': '71240',
#         'total_count': 117},
#        {'name': 'Gunneridae',
#         'parent': 'eudicotyledons',
#         'self_count': 0,
#         'tax_id': '91827',
#         'total_count': 117},
#        {'name': 'Pentapetalae',
#         'parent': 'Gunneridae',
#         'self_count': 0,
#         'tax_id': '1437201',
#         'total_count': 117},
#        {'name': 'malvids',
#         'parent': 'rosids',
#         'self_count': 0,
#         'tax_id': '91836',
#         'total_count': 117},
#        {'name': 'Terrabacteria group',
#         'parent': 'Bacteria',
#         'self_count': 0,
#         'tax_id': '1783272',
#         'total_count': 6},
#        {'name': 'Pediococcus acidilactici group',
#         'parent': 'Pediococcus',
#         'self_count': 0,
#         'tax_id': '1670797',
#         'total_count': 3},
#        {'name': 'Pediococcus acidilactici D3',
#         'parent': 'Pediococcus acidilactici',
#         'self_count': 3,
#         'tax_id': '1306952',
#         'total_count': 3},
#        {'name': 'Mycobacterium bovis BCG',
#         'parent': 'Mycobacterium bovis',
#         'self_count': 1,
#         'tax_id': '33892',
#         'total_count': 1},
#        {'name': 'Pseudomonas syringae pv_ coryli str_ NCPPB 4273',
#         'parent': 'Pseudomonas syringae pv. coryli',
#         'self_count': 9,
#         'tax_id': '1397690',
#         'total_count': 9}],
#       'class': [{'name': 'Insecta',
#         'parent': 'Hexapoda',
#         'self_count': 0,
#         'tax_id': '50557',
#         'total_count': 1058},
#        {'name': 'Bacilli',
#         'parent': 'Firmicutes',
#         'self_count': 2,
#         'tax_id': '91061',
#         'total_count': 5},
#        {'name': 'Actinobacteria',
#         'parent': 'Actinobacteria',
#         'self_count': 0,
#         'tax_id': '1760',
#         'total_count': 1},
#        {'name': 'Alphaproteobacteria',
#         'parent': 'Proteobacteria',
#         'self_count': 0,
#         'tax_id': '28211',
#         'total_count': 1},
#        {'name': 'Gammaproteobacteria',
#         'parent': 'Proteobacteria',
#         'self_count': 0,
#         'tax_id': '1236',
#         'total_count': 12}],
#       'family': [{'name': 'Drosophilidae',
#         'parent': 'Ephydroidea',
#         'self_count': 0,
#         'tax_id': '7214',
#         'total_count': 1015},
#        {'name': 'Brassicaceae',
#         'parent': 'Brassicales',
#         'self_count': 0,
#         'tax_id': '3700',
#         'total_count': 116},
#        {'name': 'Lactobacillaceae',
#         'parent': 'Lactobacillales',
#         'self_count': 0,
#         'tax_id': '33958',
#         'total_count': 3},
#        {'name': 'Mycobacteriaceae',
#         'parent': 'Corynebacteriales',
#         'self_count': 0,
#         'tax_id': '1762',
#         'total_count': 1},
#        {'name': 'Anaplasmataceae',
#         'parent': 'Rickettsiales',
#         'self_count': 0,
#         'tax_id': '942',
#         'total_count': 1},
#        {'name': 'Pseudomonadaceae',
#         'parent': 'Pseudomonadales',
#         'self_count': 0,
#         'tax_id': '135621',
#         'total_count': 9},
#        {'name': 'Enterobacteriaceae',
#         'parent': 'Enterobacteriales',
#         'self_count': 0,
#         'tax_id': '543',
#         'total_count': 3}],
#       'genus': [{'name': 'Drosophila',
#         'parent': 'Drosophilini',
#         'self_count': 17,
#         'tax_id': '7215',
#         'total_count': 1015},
#        {'name': 'Arabidopsis',
#         'parent': 'Camelineae',
#         'self_count': 0,
#         'tax_id': '3701',
#         'total_count': 116},
#        {'name': 'Pediococcus',
#         'parent': 'Lactobacillaceae',
#         'self_count': 0,
#         'tax_id': '1253',
#         'total_count': 3},
#        {'name': 'Mycobacterium',
#         'parent': 'Mycobacteriaceae',
#         'self_count': 0,
#         'tax_id': '1763',
#         'total_count': 1},
#        {'name': 'Wolbachia',
#         'parent': 'Wolbachieae',
#         'self_count': 1,
#         'tax_id': '953',
#         'total_count': 1},
#        {'name': 'Pseudomonas',
#         'parent': 'Pseudomonadaceae',
#         'self_count': 0,
#         'tax_id': '286',
#         'total_count': 9},
#        {'name': 'Salmonella',
#         'parent': 'Enterobacteriaceae',
#         'self_count': 0,
#         'tax_id': '590',
#         'total_count': 3}],
#       'infraclass': [{'name': 'Endopterygota',
#         'parent': 'Neoptera',
#         'self_count': 27,
#         'tax_id': '33392',
#         'total_count': 1058}],
#       'infraorder': [{'name': 'Muscomorpha',
#         'parent': 'Brachycera',
#         'self_count': 0,
#         'tax_id': '43733',
#         'total_count': 1024}],
#       'kingdom': [{'name': 'Metazoa',
#         'parent': 'Opisthokonta',
#         'self_count': 0,
#         'tax_id': '33208',
#         'total_count': 1074},
#        {'name': 'Viridiplantae',
#         'parent': 'Eukaryota',
#         'self_count': 0,
#         'tax_id': '33090',
#         'total_count': 117}],
#       'order': [{'name': 'Diptera',
#         'parent': 'Endopterygota',
#         'self_count': 7,
#         'tax_id': '7147',
#         'total_count': 1031},
#        {'name': 'Brassicales',
#         'parent': 'malvids',
#         'self_count': 1,
#         'tax_id': '3699',
#         'total_count': 117},
#        {'name': 'Lactobacillales',
#         'parent': 'Bacilli',
#         'self_count': 0,
#         'tax_id': '186826',
#         'total_count': 3},
#        {'name': 'Corynebacteriales',
#         'parent': 'Actinobacteria',
#         'self_count': 0,
#         'tax_id': '85007',
#         'total_count': 1},
#        {'name': 'Rickettsiales',
#         'parent': 'Alphaproteobacteria',
#         'self_count': 0,
#         'tax_id': '766',
#         'total_count': 1},
#        {'name': 'Pseudomonadales',
#         'parent': 'Gammaproteobacteria',
#         'self_count': 0,
#         'tax_id': '72274',
#         'total_count': 9},
#        {'name': 'Enterobacteriales',
#         'parent': 'Gammaproteobacteria',
#         'self_count': 0,
#         'tax_id': '91347',
#         'total_count': 3}],
#       'phylum': [{'name': 'Arthropoda',
#         'parent': 'Panarthropoda',
#         'self_count': 8,
#         'tax_id': '6656',
#         'total_count': 1066},
#        {'name': 'Streptophyta',
#         'parent': 'Viridiplantae',
#         'self_count': 0,
#         'tax_id': '35493',
#         'total_count': 117},
#        {'name': 'Firmicutes',
#         'parent': 'Terrabacteria group',
#         'self_count': 0,
#         'tax_id': '1239',
#         'total_count': 5},
#        {'name': 'Actinobacteria',
#         'parent': 'Terrabacteria group',
#         'self_count': 0,
#         'tax_id': '201174',
#         'total_count': 1},
#        {'name': 'Proteobacteria',
#         'parent': 'Bacteria',
#         'self_count': 49,
#         'tax_id': '1224',
#         'total_count': 62}],
#       'species': [{'name': 'Drosophila simulans',
#         'parent': 'melanogaster subgroup',
#         'self_count': 62,
#         'tax_id': '7240',
#         'total_count': 62},
#        {'name': 'Drosophila sechellia',
#         'parent': 'melanogaster subgroup',
#         'self_count': 48,
#         'tax_id': '7238',
#         'total_count': 48},
#        {'name': 'Drosophila pseudoobscura',
#         'parent': 'pseudoobscura subgroup',
#         'self_count': 0,
#         'tax_id': '7237',
#         'total_count': 30},
#        {'name': 'Arabidopsis thaliana',
#         'parent': 'Arabidopsis',
#         'self_count': 116,
#         'tax_id': '3702',
#         'total_count': 116},
#        {'name': 'Pediococcus acidilactici',
#         'parent': 'Pediococcus acidilactici group',
#         'self_count': 0,
#         'tax_id': '1254',
#         'total_count': 3},
#        {'name': 'Mycobacterium bovis',
#         'parent': 'Mycobacterium tuberculosis complex',
#         'self_count': 0,
#         'tax_id': '1765',
#         'total_count': 1},
#        {'name': 'Pseudomonas syringae pv_ coryli',
#         'parent': 'Pseudomonas syringae group genomosp. 2',
#         'self_count': 0,
#         'tax_id': '317659',
#         'total_count': 9},
#        {'name': 'Salmonella enterica',
#         'parent': 'Salmonella',
#         'self_count': 3,
#         'tax_id': '28901',
#         'total_count': 3}],
#       'species group': [{'name': 'melanogaster group',
#         'parent': 'Sophophora',
#         'self_count': 25,
#         'tax_id': '32346',
#         'total_count': 781},
#        {'name': 'obscura group',
#         'parent': 'Sophophora',
#         'self_count': 0,
#         'tax_id': '32355',
#         'total_count': 217},
#        {'name': 'Mycobacterium tuberculosis complex',
#         'parent': 'Mycobacterium',
#         'self_count': 0,
#         'tax_id': '77643',
#         'total_count': 1},
#        {'name': 'Pseudomonas syringae group',
#         'parent': 'Pseudomonas',
#         'self_count': 0,
#         'tax_id': '136849',
#         'total_count': 9}],
#       'species subgroup': [{'name': 'melanogaster subgroup',
#         'parent': 'melanogaster group',
#         'self_count': 646,
#         'tax_id': '32351',
#         'total_count': 756},
#        {'name': 'pseudoobscura subgroup',
#         'parent': 'obscura group',
#         'self_count': 187,
#         'tax_id': '32358',
#         'total_count': 217},
#        {'name': 'Pseudomonas syringae group genomosp_ 2',
#         'parent': 'Pseudomonas syringae group',
#         'self_count': 0,
#         'tax_id': '251698',
#         'total_count': 9}],
#       'subclass': [{'name': 'Neoptera',
#         'parent': 'Pterygota',
#         'self_count': 0,
#         'tax_id': '33340',
#         'total_count': 1058},
#        {'name': 'rosids',
#         'parent': 'Pentapetalae',
#         'self_count': 0,
#         'tax_id': '71275',
#         'total_count': 117}],
#       'subfamily': [{'name': 'Drosophilinae',
#         'parent': 'Drosophilidae',
#         'self_count': 0,
#         'tax_id': '43845',
#         'total_count': 1015}],
#       'subgenus': [{'name': 'Sophophora',
#         'parent': 'Drosophila',
#         'self_count': 0,
#         'tax_id': '32341',
#         'total_count': 998}],
#       'suborder': [{'name': 'Brachycera',
#         'parent': 'Diptera',
#         'self_count': 0,
#         'tax_id': '7203',
#         'total_count': 1024}],
#       'subspecies': [{'name': 'Drosophila pseudoobscura pseudoobscura',
#         'parent': 'Drosophila pseudoobscura',
#         'self_count': 30,
#         'tax_id': '46245',
#         'total_count': 30}],
#       'superclass': [{'name': 'Hexapoda',
#         'parent': 'Pancrustacea',
#         'self_count': 0,
#         'tax_id': '6960',
#         'total_count': 1058}],
#       'superfamily': [{'name': 'Ephydroidea',
#         'parent': 'Acalyptratae',
#         'self_count': 0,
#         'tax_id': '43746',
#         'total_count': 1015}],
#       'superkingdom': [{'name': 'Eukaryota',
#         'parent': 'cellular organisms',
#         'self_count': 13,
#         'tax_id': '2759',
#         'total_count': 1204},
#        {'name': 'Bacteria',
#         'parent': 'cellular organisms',
#         'self_count': 100,
#         'tax_id': '2',
#         'total_count': 168}],
#       'tribe': [{'name': 'Drosophilini',
#         'parent': 'Drosophilinae',
#         'self_count': 0,
#         'tax_id': '46877',
#         'total_count': 1015},
#        {'name': 'Camelineae',
#         'parent': 'Brassicaceae',
#         'self_count': 0,
#         'tax_id': '980083',
#         'total_count': 116},
#        {'name': 'Wolbachieae',
#         'parent': 'Anaplasmataceae',
#         'self_count': 0,
#         'tax_id': '952',
#         'total_count': 1}]},
#      'total_spots': 7634},
#     'uuid': []}],
#   'sample': {'BioProject': '281652',
#    'BioSample': 'SAMN03493259',
#    'attributes': [{'name': 'strain',
#      'value': 'Drosophila melanogaster Winters 80 Mated 2'},
#     {'name': 'dev_stage', 'value': 'adult'},
#     {'name': 'sex', 'value': 'female'},
#     {'name': 'tissue', 'value': 'head'},
#     {'name': 'BioSampleModel', 'value': 'Model organism or animal'}],
#    'ddbj_links': [],
#    'ena_links': [],
#    'entrez_links': [],
#    'external_id': [],
#    'sample_id': 'SRS919397',
#    'scientific_name': 'Drosophila melanogaster',
#    'secondary_id': [],
#    'submitter_id': [{'db': 'USC_Core',
#      'id': 'Drosophila melanogaster Winters 80 Mated 2'}],
#    'taxon_id': '7227',
#    'title': 'Drosophila melanogaster Winters 80 Mated 2',
#    'url_links': [],
#    'uuid': [],
#    'xref_links': []},
#   'study': {'BioProject': 'PRJNA281652',
#    'abstract': 'Association analyses in Drosophila melanogaster have become common due to the availability of genome-wide polymorphism data for panels of reference strains. These experiments have so far been performed using homozygotes - a condition rare in nature. Using Raleigh DGRP strains and additional genotypes originating from the West Coast, we assayed several metabolism-related phenotypes and conducted whole-genome RNA-seq in F1 heterozygotes generated by crossing to a reference strain w[1118]. In past studies, large-effect but recessive alleles might have been expected to primarily account for the associations. The present design targets genes with more additive contributions, those largely responsible for heritability of complex traits in nature. A mixed-model analysis of genetic variation in whole-organism metabolic and gene expression phenotypes was employed to account for relatedness and population structure. Kinship accounted for a large amount of the observed phenotypic variance. To compare inferences between different environments the assays were conducted in both virgin and mated flies and effects were mostly consistent between the two groups. An analysis of rare variants identified several genes associated with phenotypes. A contribution from moderate frequency or common alleles was identified only for triglyceride content. In contrast, many common polymorphisms exhibited association with expression phenotypes. These polymorphisms were typically upstream, close to transcription start sites. Furthermore, many of the variants were in known gene-regulatory regions, especially transcription factor binding sites. The identification of regulatory alleles specific to an environment indicates environment-specific regulatory mechanisms. This study demonstrates the potential of combining RNA-seq and genome wide association studies (GWAS) of heterozygous genotypes to identify targets of selection in natural populations and provides new genomic data resources for future in-depth studies. The results of analysis of heterozygotes are more consistent with human studies and classical quantitative genetics inferences, and are supported by high-powered human GWAS. The consistent effects between mated and virgin flies contradict previous studies showing strong environmental sensitivity of natural alleles. The overall pattern of genetic associations is consistent with a mutation-selection balance scenario in the maintenance of phenotypic variation.',
#    'center_name': 'BioProject',
#    'center_project_name': 'Drosophila melanogaster',
#    'ddbj_links': [],
#    'ena_links': [],
#    'entrez_links': [],
#    'external_id': [],
#    'pubmed': '27194752',
#    'related_studies': [],
#    'secondary_id': [],
#    'study_id': 'SRP057595',
#    'study_type': 'Transcriptome Analysis',
#    'submitter_id': [],
#    'title': 'Genome-Wide Association of Metabolism and Gene Expression in a Panel of Heterozygote Drosophila melanogaster',
#    'url_links': [],
#    'uuid': [],
#    'xref_links': []},
#   'submission': {'external_id': [],
#    'secondary_id': [],
#    'submission_id': 'SRA260961',
#    'submitter_id': [{'db': 'USC_Core',
#      'id': 'Drosophila melanogaster WTS CEGS F1'}],
#    'uuid': []}}}

# %%
df = pd.DataFrame(list(ncbi.aggregate([
    {
        '$match': {
            '_id': {'$in': staged},
        }
    },
    {
        '$unwind': {
            'path': '$biosample'
        }
    },
    {
        '$unwind': {
            'path': '$biosample.attributes'
        }
    },
    {
        '$match': {
            'biosample.attributes.name': {'$in': dev_stage}
        }
    },
    {
        '$project': {
            '_id': 0,
            'srx': '$_id',
            'attribute_value': '$biosample.attributes.value',
            'title': {'$arrayElemAt': ['$pubmed.title', 0]},
            'abstract': {'$arrayElemAt': ['$pubmed.abstract', 0]},
            'pmid': {'$arrayElemAt': ['$pubmed.pubmed_id', 0]},
        }
    }
])))

# %%
with open('../data/dev_stage_corpus.yaml', 'w') as fh:
    for x in sorted(df.attribute_value.unique().tolist()):
        fh.write(dedent(
            f"""\
            MAP:
                id: 
                synonym: {x}
            """))

# %%
df.sort_values('attribute_value').to_csv('../data/dev_stage.')

# %%
df = pd.DataFrame(list(ncbi.aggregate([
    {
        '$match': {
            '_id': {'$in': staged},
            'pubmed': {'$exists': 1}
        }
    },
    {
        '$unwind': {
            'path': '$biosample'
        }
    },
    {
        '$unwind': {
            'path': '$biosample.attributes'
        }
    },
    {
        '$project': {
            '_id': 0,
            'srx': '$_id',
            'attribute_name': '$biosample.attributes.name',
            'attribute_value': '$biosample.attributes.value',
            'title': {'$arrayElemAt': ['$pubmed.title', 0]},
            'abstract': {'$arrayElemAt': ['$pubmed.abstract', 0]},
            'pmid': {'$arrayElemAt': ['$pubmed.pubmed_id', 0]},
        }
    }
])))

# %%
with open('/tmp/names', 'w') as fh:
    for i, gd in df.groupby('attribute_name'):
        fh.write(i + '\n')
        for x in sorted(gd.attribute_value.unique().tolist()):
            fh.write('\t' + x + '\n')
