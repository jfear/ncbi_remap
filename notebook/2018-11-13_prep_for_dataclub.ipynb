# %%
import os
import sys
from pathlib import Path

from IPython.display import display, HTML, Markdown
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Project level imports
from ncbi_remap.notebook import Nb
from ncbi_remap.plotting import make_figs

# %%
# Setup notebook
nbconfig = Nb.setup_notebook()
# Out:
# Please check output/fbgn2chrom.tsv. If it does not exist, run bin/fbgn2chrom.py
# last updated: 2018-11-13
# Git hash: 380c44c9892694561da6930f52ca7cd96ec7a37e

# %%
pd.options.display.max_rows = 100

# %%
# Connect to data store
store = pd.HDFStore('../sra.h5', mode='r')

# %%
library_strategy = pd.read_parquet('../output/metadata-wf/select_library_strategy.parquet').Fear_et_al_library_strategy

# %%
library_strategy[library_strategy.str.contains('\|')] = 'Ambiguous'

# %%
library_strategy.value_counts().map(lambda x: f'{x:,}').to_frame()
# Out:
#                                     Fear_et_al_library_strategy
# RNA-Seq                                                  14,471
# EST                                                       4,546
# ChIP-Seq                                                  2,943
# WGS                                                       1,867
# RNA-Seq|OTHER                                             1,005
# 4C-Seq                                                      737
# ChIP-Seq|OTHER                                              164
# ChIP-Seq|WGS                                                121
# miRNA-Seq                                                   115
# DNA-Seq                                                     108
# Targeted-Capture                                             93
# AMPLICON                                                     81
# WGS|OTHER                                                    63
# STARR-Seq                                                    56
# ...

# %%
biometa = pd.read_csv('/home/fearjm/Promise_Pegasus/fearjm/ncbi_remap/geo-wf/output/rnaseq_metadata.tsv', sep='\t', index_col=0)

# %%
with open('../output/notebook/2018-11-13_prep_for_dataclub_ovary_rnaseq.txt', 'w') as fh:
    _dat = biometa[biometa.tissue == 'ovary'].index.tolist()
    fh.write('\n'.join(_dat))
    print(len(_dat))
# Out:
# 480

# %%
with open('../output/notebook/2018-11-13_prep_for_dataclub_testis_rnaseq.txt', 'w') as fh:
    _dat = biometa[biometa.tissue == 'testis'].index.tolist()
    fh.write('\n'.join(_dat))
    print(len(_dat))
# Out:
# 109
