# %%
import pandas as pd

# %%
rnaseq = pd.read_csv('/home/fearjm/Promise_Pegasus/fearjm/ncbi_remap/geo-wf/output/rnaseq_metadata.tsv', sep='\t', index_col=0)

# %%
srxs = rnaseq.index.tolist()

# %%
dat = pd.read_parquet('../output/aln-wf/gene_counts_wide.parquet', columns=srxs)

# %%
dat.head()
# Out:
# srx          DRX013093  DRX013094  DRX014765  DRX014766  DRX014767  DRX014768  \
# FBgn
# FBgn0000003          3          6          3          7          1          0
# FBgn0000008          0          3         42         43         38         25
# FBgn0000014          2          2        766        566        563        397
# FBgn0000015          0          1        213        144        151        119
# FBgn0000017          0          0        368        248        331        136
#
# srx          DRX014769  DRX014770  DRX014771  DRX014772    ...      SRX986409  \
# FBgn                                                       ...
# FBgn0000003          0          1          1          1    ...              3
# FBgn0000008        370        375        326        339    ...            172
# FBgn0000014       1138        926        904        826    ...              0
# FBgn0000015        275        236        348        330    ...              0
# ...

# %%
dat.to_csv('../output/notebook/2018-11-08_rnaseq_data.tsv', sep='\t')
