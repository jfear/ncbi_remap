# %%
# %load ../start.py
# Load useful extensions

# Activate the autoreload extension for easy reloading of external packages
# %reload_ext autoreload
# %autoreload 2

# Trun on the water mark
# %reload_ext watermark
# %watermark -u -d -g

# Load ipycache extension
# %reload_ext ipycache
from ipycache import CacheMagics
CacheMagics.cachedir = '../cachedir'

# Add project library to path
import sys
sys.path.insert(0, '../../lib/python')

# The usual suspects
import os
import numpy as np
import pandas as pd

# plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_context('poster')

# Turn off scientific notation
np.set_printoptions(precision=5, suppress=True)
# Out:
# last updated: 2017-10-09
# Git hash: 6981e4093c2e6b3d7a4e4ca51337c4f0c41a767e

# %%
# %load ../../bin/load.py
from pymongo import MongoClient
with open('/home/fearjm/Projects/ncbi_remap/output/.mongodb_host', 'r') as fh:
    host = fh.read().strip()
client = MongoClient(host=host, port=27022)
db = client['sra2']
remap = db['remap']
ncbi = db['ncbi']

# %%
srxs = [x['_id'] for x in ncbi.find({'sra.experiment.library_strategy': 'WGS'}, {'_id': 1})]

# %%
list(remap.find({'_id': {'$in': srxs}, 'runs.aln_flags': 'complete'}, {'_id': 1, 'runs.srr': 1}))
# Out:
# [{'_id': 'DRX000998', 'runs': [{'srr': 'DRR001444'}]},
#  {'_id': 'DRX000999', 'runs': [{'srr': 'DRR001445'}]},
#  {'_id': 'DRX001000', 'runs': [{'srr': 'DRR001446'}]},
#  {'_id': 'DRX001001', 'runs': [{'srr': 'DRR001447'}]},
#  {'_id': 'DRX015073', 'runs': [{'srr': 'DRR016720'}]},
#  {'_id': 'DRX015074', 'runs': [{'srr': 'DRR016721'}]},
#  {'_id': 'DRX015075', 'runs': [{'srr': 'DRR016722'}]},
#  {'_id': 'DRX015076', 'runs': [{'srr': 'DRR016723'}]},
#  {'_id': 'DRX042143', 'runs': [{'srr': 'DRR046855'}]},
#  {'_id': 'DRX042144', 'runs': [{'srr': 'DRR046856'}]},
#  {'_id': 'DRX042145', 'runs': [{'srr': 'DRR046857'}]},
#  {'_id': 'DRX042146', 'runs': [{'srr': 'DRR046858'}]},
#  {'_id': 'DRX042147', 'runs': [{'srr': 'DRR046859'}]},
#  {'_id': 'DRX042148', 'runs': [{'srr': 'DRR046860'}]},
#  {'_id': 'DRX042149', 'runs': [{'srr': 'DRR046861'}]},
#  {'_id': 'DRX042150', 'runs': [{'srr': 'DRR046862'}]},
#  {'_id': 'DRX042151', 'runs': [{'srr': 'DRR046863'}]},
#  {'_id': 'DRX042152', 'runs': [{'srr': 'DRR046864'}]},
#  {'_id': 'DRX042153', 'runs': [{'srr': 'DRR046865'}]},
#  {'_id': 'DRX042154', 'runs': [{'srr': 'DRR046866'}]},
#  {'_id': 'DRX042155', 'runs': [{'srr': 'DRR046867'}]},
#  {'_id': 'ERX004310', 'runs': [{'srr': 'ERR011354'}]},
#  {'_id': 'ERX004311', 'runs': [{'srr': 'ERR011351'}]},
#  {'_id': 'ERX004312', 'runs': [{'srr': 'ERR011355'}]},
#  {'_id': 'ERX1104349', 'runs': [{'srr': 'ERR1025479'}]},
#  {'_id': 'ERX1104351', 'runs': [{'srr': 'ERR1025481'}]},
#  {'_id': 'ERX1104352', 'runs': [{'srr': 'ERR1025482'}]},
#  {'_id': 'ERX1104353', 'runs': [{'srr': 'ERR1025483'}]},
#  {'_id': 'ERX1104355', 'runs': [{'srr': 'ERR1025485'}]},
#  {'_id': 'ERX1104356', 'runs': [{'srr': 'ERR1025486'}]},
#  {'_id': 'ERX1104357', 'runs': [{'srr': 'ERR1025487'}]},
#  {'_id': 'ERX1172343',
#   'runs': [{'srr': 'ERR1092789'},
#    {'srr': 'ERR1092790'},
#    {'srr': 'ERR1092791'},
#    {'srr': 'ERR1092792'},
#    {'srr': 'ERR1092793'},
#    {'srr': 'ERR1092794'}]},
#  {'_id': 'ERX1172344',
#   'runs': [{'srr': 'ERR1092795'},
#    {'srr': 'ERR1092796'},
#    {'srr': 'ERR1092797'},
#    {'srr': 'ERR1092798'},
#    {'srr': 'ERR1092799'},
#    {'srr': 'ERR1092800'}]},
#  {'_id': 'ERX1172345',
#   'runs': [{'srr': 'ERR1092801'},
#    {'srr': 'ERR1092802'},
#    {'srr': 'ERR1092803'},
#    {'srr': 'ERR1092804'},
#    {'srr': 'ERR1092805'},
#    {'srr': 'ERR1092806'}]},
#  {'_id': 'ERX1172346',
#   'runs': [{'srr': 'ERR1092807'},
#    {'srr': 'ERR1092808'},
#    {'srr': 'ERR1092809'},
#    {'srr': 'ERR1092810'},
#    {'srr': 'ERR1092811'},
#    {'srr': 'ERR1092812'}]},
#  {'_id': 'ERX1172347',
#   'runs': [{'srr': 'ERR1092813'},
#    {'srr': 'ERR1092814'},
#    {'srr': 'ERR1092815'},
#    {'srr': 'ERR1092816'},
#    {'srr': 'ERR1092817'},
#    {'srr': 'ERR1092818'}]},
#  {'_id': 'ERX1172348',
#   'runs': [{'srr': 'ERR1092819'},
#    {'srr': 'ERR1092820'},
#    {'srr': 'ERR1092821'},
#    {'srr': 'ERR1092822'},
#    {'srr': 'ERR1092823'},
#    {'srr': 'ERR1092824'}]},
#  {'_id': 'ERX1172349',
#   'runs': [{'srr': 'ERR1092825'},
#    {'srr': 'ERR1092826'},
#    {'srr': 'ERR1092827'},
#    {'srr': 'ERR1092828'},
#    {'srr': 'ERR1092829'},
#    {'srr': 'ERR1092830'}]},
#  {'_id': 'ERX1172350',
#   'runs': [{'srr': 'ERR1092831'},
#    {'srr': 'ERR1092832'},
#    {'srr': 'ERR1092833'},
#    {'srr': 'ERR1092834'},
#    {'srr': 'ERR1092835'},
#    {'srr': 'ERR1092836'}]},
#  {'_id': 'ERX1172351', 'runs': [{'srr': 'ERR1092837'}, {'srr': 'ERR1092838'}]},
#  {'_id': 'ERX1172352', 'runs': [{'srr': 'ERR1092839'}, {'srr': 'ERR1092840'}]},
#  {'_id': 'ERX1172353', 'runs': [{'srr': 'ERR1092841'}, {'srr': 'ERR1092842'}]},
#  {'_id': 'ERX1172354', 'runs': [{'srr': 'ERR1092843'}, {'srr': 'ERR1092844'}]},
#  {'_id': 'ERX1172355',
#   'runs': [{'srr': 'ERR1092845'},
#    {'srr': 'ERR1092846'},
#    {'srr': 'ERR1092847'},
#    {'srr': 'ERR1092848'}]},
#  {'_id': 'ERX1172356',
#   'runs': [{'srr': 'ERR1092849'},
#    {'srr': 'ERR1092850'},
#    {'srr': 'ERR1092851'},
#    {'srr': 'ERR1092852'}]},
#  {'_id': 'ERX1172357',
#   'runs': [{'srr': 'ERR1092853'},
#    {'srr': 'ERR1092854'},
#    {'srr': 'ERR1092855'},
#    {'srr': 'ERR1092856'}]},
#  {'_id': 'ERX1365922', 'runs': [{'srr': 'ERR1294576'}]},
#  {'_id': 'ERX1432621', 'runs': [{'srr': 'ERR1361150'}]},
#  {'_id': 'ERX1668460', 'runs': [{'srr': 'ERR1597893'}]},
#  {'_id': 'ERX1668461', 'runs': [{'srr': 'ERR1597894'}]},
#  {'_id': 'ERX1668464', 'runs': [{'srr': 'ERR1597897'}]},
#  {'_id': 'ERX1668465', 'runs': [{'srr': 'ERR1597898'}]},
#  {'_id': 'ERX177417',
#   'runs': [{'srr': 'ERR202732'},
#    {'srr': 'ERR202733'},
#    {'srr': 'ERR202734'},
#    {'srr': 'ERR202735'},
#    {'srr': 'ERR202736'}]},
#  {'_id': 'ERX177422', 'runs': [{'srr': 'ERR202737'}]},
#  {'_id': 'ERX177423', 'runs': [{'srr': 'ERR202738'}]},
#  {'_id': 'ERX249585', 'runs': [{'srr': 'ERR275263'}]},
#  {'_id': 'ERX249586', 'runs': [{'srr': 'ERR275264'}]},
#  {'_id': 'ERX249587', 'runs': [{'srr': 'ERR275265'}]},
#  {'_id': 'ERX249588', 'runs': [{'srr': 'ERR275266'}]},
#  {'_id': 'ERX249589', 'runs': [{'srr': 'ERR275267'}]},
#  {'_id': 'ERX249590', 'runs': [{'srr': 'ERR275268'}]},
#  {'_id': 'ERX249592', 'runs': [{'srr': 'ERR275270'}]},
#  {'_id': 'ERX249593', 'runs': [{'srr': 'ERR275271'}]},
#  {'_id': 'ERX332485', 'runs': [{'srr': 'ERR359713'}]},
#  {'_id': 'ERX332486', 'runs': [{'srr': 'ERR359714'}]},
#  {'_id': 'ERX332487', 'runs': [{'srr': 'ERR359715'}]},
#  {'_id': 'ERX332488', 'runs': [{'srr': 'ERR359716'}]},
#  {'_id': 'ERX332489', 'runs': [{'srr': 'ERR359717'}]},
#  {'_id': 'ERX332490', 'runs': [{'srr': 'ERR359718'}]},
#  {'_id': 'ERX332491', 'runs': [{'srr': 'ERR359719'}]},
#  {'_id': 'ERX332492', 'runs': [{'srr': 'ERR359720'}]},
#  {'_id': 'ERX332493', 'runs': [{'srr': 'ERR359721'}]},
#  {'_id': 'ERX332494', 'runs': [{'srr': 'ERR359722'}]},
#  {'_id': 'ERX332495', 'runs': [{'srr': 'ERR359723'}]},
#  {'_id': 'ERX332496', 'runs': [{'srr': 'ERR359724'}]},
#  {'_id': 'ERX332497', 'runs': [{'srr': 'ERR359725'}]},
#  {'_id': 'ERX332498', 'runs': [{'srr': 'ERR359726'}]},
#  {'_id': 'ERX332499', 'runs': [{'srr': 'ERR359727'}]},
#  {'_id': 'ERX332500', 'runs': [{'srr': 'ERR359728'}]},
#  {'_id': 'ERX332501', 'runs': [{'srr': 'ERR359729'}]},
#  {'_id': 'ERX332502', 'runs': [{'srr': 'ERR359730'}]},
#  {'_id': 'ERX332503', 'runs': [{'srr': 'ERR359731'}]},
#  {'_id': 'ERX332504', 'runs': [{'srr': 'ERR359732'}]},
#  {'_id': 'ERX332505', 'runs': [{'srr': 'ERR359733'}]},
#  {'_id': 'ERX332506', 'runs': [{'srr': 'ERR359734'}]},
#  {'_id': 'ERX332507', 'runs': [{'srr': 'ERR359735'}]},
#  {'_id': 'ERX332508', 'runs': [{'srr': 'ERR359736'}]},
#  {'_id': 'ERX332509', 'runs': [{'srr': 'ERR359737'}]},
#  {'_id': 'ERX332510', 'runs': [{'srr': 'ERR359738'}]},
#  {'_id': 'ERX332511', 'runs': [{'srr': 'ERR359739'}]},
#  {'_id': 'ERX332512', 'runs': [{'srr': 'ERR359740'}]},
#  {'_id': 'ERX341504', 'runs': [{'srr': 'ERR368828'}]},
#  {'_id': 'ERX341505', 'runs': [{'srr': 'ERR368829'}]},
#  {'_id': 'ERX341506', 'runs': [{'srr': 'ERR368830'}]},
#  {'_id': 'ERX341507', 'runs': [{'srr': 'ERR368831'}]},
#  {'_id': 'ERX341508', 'runs': [{'srr': 'ERR368832'}]},
#  {'_id': 'ERX341509', 'runs': [{'srr': 'ERR368833'}]},
#  {'_id': 'ERX341510', 'runs': [{'srr': 'ERR368834'}]},
#  {'_id': 'ERX341511', 'runs': [{'srr': 'ERR368835'}]},
#  {'_id': 'ERX341513', 'runs': [{'srr': 'ERR368837'}]},
#  {'_id': 'ERX341514', 'runs': [{'srr': 'ERR368838'}]},
#  {'_id': 'ERX341515', 'runs': [{'srr': 'ERR368839'}]},
#  {'_id': 'ERX341516', 'runs': [{'srr': 'ERR368840'}]},
#  {'_id': 'ERX341517', 'runs': [{'srr': 'ERR368841'}]},
#  {'_id': 'ERX341518', 'runs': [{'srr': 'ERR368842'}]},
#  {'_id': 'ERX341519', 'runs': [{'srr': 'ERR368843'}]},
#  {'_id': 'ERX409654', 'runs': [{'srr': 'ERR442890'}]},
#  {'_id': 'ERX409655', 'runs': [{'srr': 'ERR442891'}]},
#  {'_id': 'ERX409656', 'runs': [{'srr': 'ERR442892'}]},
#  {'_id': 'ERX409657', 'runs': [{'srr': 'ERR442893'}]},
#  {'_id': 'ERX409658', 'runs': [{'srr': 'ERR442894'}]},
#  {'_id': 'ERX409659', 'runs': [{'srr': 'ERR442895'}]},
#  {'_id': 'ERX409660', 'runs': [{'srr': 'ERR442896'}]},
#  {'_id': 'ERX409661', 'runs': [{'srr': 'ERR442897'}]},
#  {'_id': 'ERX409662', 'runs': [{'srr': 'ERR442898'}]},
#  {'_id': 'ERX409663', 'runs': [{'srr': 'ERR442899'}]},
#  {'_id': 'ERX409664', 'runs': [{'srr': 'ERR442900'}]},
#  {'_id': 'ERX409665', 'runs': [{'srr': 'ERR442901'}]},
#  {'_id': 'ERX447119', 'runs': [{'srr': 'ERR481287'}]},
#  {'_id': 'ERX447120', 'runs': [{'srr': 'ERR481288'}]},
#  {'_id': 'ERX447121', 'runs': [{'srr': 'ERR481289'}]},
#  {'_id': 'ERX447122', 'runs': [{'srr': 'ERR481290'}]},
#  {'_id': 'ERX447123', 'runs': [{'srr': 'ERR481291'}]},
#  {'_id': 'ERX447124', 'runs': [{'srr': 'ERR481292'}]},
#  {'_id': 'ERX472121', 'runs': [{'srr': 'ERR506764'}]},
#  {'_id': 'ERX472122', 'runs': [{'srr': 'ERR506765'}]},
#  {'_id': 'ERX472123', 'runs': [{'srr': 'ERR506766'}]},
#  {'_id': 'ERX472124', 'runs': [{'srr': 'ERR506767'}]},
#  {'_id': 'ERX472125', 'runs': [{'srr': 'ERR506768'}]},
#  {'_id': 'ERX472126', 'runs': [{'srr': 'ERR506769'}]},
#  {'_id': 'ERX472127', 'runs': [{'srr': 'ERR506770'}]},
#  {'_id': 'ERX472128', 'runs': [{'srr': 'ERR506771'}]},
#  {'_id': 'ERX472129', 'runs': [{'srr': 'ERR506772'}]},
#  {'_id': 'ERX472130', 'runs': [{'srr': 'ERR506773'}]},
#  {'_id': 'ERX472131', 'runs': [{'srr': 'ERR506774'}]},
#  {'_id': 'ERX472132', 'runs': [{'srr': 'ERR506775'}]},
#  {'_id': 'ERX472133', 'runs': [{'srr': 'ERR506776'}]},
#  {'_id': 'ERX472134', 'runs': [{'srr': 'ERR506777'}]},
#  {'_id': 'ERX472135', 'runs': [{'srr': 'ERR506778'}]},
#  {'_id': 'ERX472136', 'runs': [{'srr': 'ERR506779'}]},
#  {'_id': 'ERX472137', 'runs': [{'srr': 'ERR506780'}]},
#  {'_id': 'ERX472138', 'runs': [{'srr': 'ERR506781'}]},
#  {'_id': 'ERX472139', 'runs': [{'srr': 'ERR506782'}]},
#  {'_id': 'ERX472140', 'runs': [{'srr': 'ERR506783'}]},
#  {'_id': 'ERX472141', 'runs': [{'srr': 'ERR506784'}]},
#  {'_id': 'ERX472142', 'runs': [{'srr': 'ERR506785'}]},
#  {'_id': 'ERX472143', 'runs': [{'srr': 'ERR506786'}]},
#  {'_id': 'ERX472144', 'runs': [{'srr': 'ERR506787'}]},
#  {'_id': 'ERX472145', 'runs': [{'srr': 'ERR506788'}]},
#  {'_id': 'ERX472146', 'runs': [{'srr': 'ERR506789'}]},
#  {'_id': 'ERX472147', 'runs': [{'srr': 'ERR506790'}]},
#  {'_id': 'ERX472148', 'runs': [{'srr': 'ERR506791'}]},
#  {'_id': 'ERX472149', 'runs': [{'srr': 'ERR506792'}]},
#  {'_id': 'ERX472150', 'runs': [{'srr': 'ERR506793'}]},
#  {'_id': 'ERX472151', 'runs': [{'srr': 'ERR506794'}]},
#  {'_id': 'ERX472152', 'runs': [{'srr': 'ERR506795'}]},
#  {'_id': 'ERX472153', 'runs': [{'srr': 'ERR506796'}]},
#  {'_id': 'ERX472154', 'runs': [{'srr': 'ERR506797'}]},
#  {'_id': 'ERX472155', 'runs': [{'srr': 'ERR506798'}]},
#  {'_id': 'ERX472156', 'runs': [{'srr': 'ERR506799'}]},
#  {'_id': 'ERX472157', 'runs': [{'srr': 'ERR506800'}]},
#  {'_id': 'ERX472159', 'runs': [{'srr': 'ERR506802'}]},
#  {'_id': 'ERX472160', 'runs': [{'srr': 'ERR506803'}]},
#  {'_id': 'ERX472161', 'runs': [{'srr': 'ERR506804'}]},
#  {'_id': 'ERX472162', 'runs': [{'srr': 'ERR506805'}]},
#  {'_id': 'ERX472163', 'runs': [{'srr': 'ERR506806'}]},
#  {'_id': 'ERX472164', 'runs': [{'srr': 'ERR506807'}]},
#  {'_id': 'ERX472165', 'runs': [{'srr': 'ERR506808'}]},
#  {'_id': 'ERX472166', 'runs': [{'srr': 'ERR506809'}]},
#  {'_id': 'ERX472167', 'runs': [{'srr': 'ERR506810'}]},
#  {'_id': 'ERX472168', 'runs': [{'srr': 'ERR506811'}]},
#  {'_id': 'ERX472169', 'runs': [{'srr': 'ERR506812'}]},
#  {'_id': 'ERX472170', 'runs': [{'srr': 'ERR506813'}]},
#  {'_id': 'ERX472171', 'runs': [{'srr': 'ERR506814'}]},
#  {'_id': 'ERX472172', 'runs': [{'srr': 'ERR506815'}]},
#  {'_id': 'ERX472173', 'runs': [{'srr': 'ERR506816'}]},
#  {'_id': 'ERX472174', 'runs': [{'srr': 'ERR506817'}]},
#  {'_id': 'ERX472175', 'runs': [{'srr': 'ERR506818'}]},
#  {'_id': 'ERX472176', 'runs': [{'srr': 'ERR506819'}]},
#  {'_id': 'ERX472177', 'runs': [{'srr': 'ERR506820'}]},
#  {'_id': 'ERX472178', 'runs': [{'srr': 'ERR506821'}]},
#  {'_id': 'ERX645969',
#   'runs': [{'srr': 'ERR701709'},
#    {'srr': 'ERR701707'},
#    {'srr': 'ERR701711'},
#    {'srr': 'ERR701706'},
#    {'srr': 'ERR701708'},
#    {'srr': 'ERR701710'}]},
#  {'_id': 'ERX645975', 'runs': [{'srr': 'ERR701712'}, {'srr': 'ERR701713'}]},
#  {'_id': 'ERX650203', 'runs': [{'srr': 'ERR705945'}]},
#  {'_id': 'ERX650204', 'runs': [{'srr': 'ERR705946'}]},
#  {'_id': 'ERX650205', 'runs': [{'srr': 'ERR705947'}]},
#  {'_id': 'ERX650206', 'runs': [{'srr': 'ERR705948'}]},
#  {'_id': 'ERX650207', 'runs': [{'srr': 'ERR705949'}]},
#  {'_id': 'ERX650208', 'runs': [{'srr': 'ERR705950'}]},
#  {'_id': 'ERX650209', 'runs': [{'srr': 'ERR705951'}]},
#  {'_id': 'ERX650210', 'runs': [{'srr': 'ERR705952'}]},
#  {'_id': 'ERX650211', 'runs': [{'srr': 'ERR705953'}]},
#  {'_id': 'ERX650212', 'runs': [{'srr': 'ERR705954'}]},
#  {'_id': 'ERX650213', 'runs': [{'srr': 'ERR705955'}]},
#  {'_id': 'ERX650214', 'runs': [{'srr': 'ERR705956'}]},
#  {'_id': 'ERX650215', 'runs': [{'srr': 'ERR705957'}]},
#  {'_id': 'ERX650216', 'runs': [{'srr': 'ERR705958'}]},
#  {'_id': 'ERX650217', 'runs': [{'srr': 'ERR705959'}]},
#  {'_id': 'ERX650218', 'runs': [{'srr': 'ERR705960'}]},
#  {'_id': 'ERX650219', 'runs': [{'srr': 'ERR705961'}]},
#  {'_id': 'ERX650220', 'runs': [{'srr': 'ERR705962'}]},
#  {'_id': 'ERX650221', 'runs': [{'srr': 'ERR705963'}]},
#  {'_id': 'ERX650222', 'runs': [{'srr': 'ERR705964'}]},
#  {'_id': 'ERX650224', 'runs': [{'srr': 'ERR705966'}]},
#  {'_id': 'ERX650225', 'runs': [{'srr': 'ERR705967'}]},
#  {'_id': 'ERX650227', 'runs': [{'srr': 'ERR705969'}]},
#  {'_id': 'ERX650228', 'runs': [{'srr': 'ERR705970'}]},
#  {'_id': 'ERX650229', 'runs': [{'srr': 'ERR705971'}]},
#  {'_id': 'ERX650230', 'runs': [{'srr': 'ERR705972'}]},
#  {'_id': 'ERX650231', 'runs': [{'srr': 'ERR705973'}]},
#  {'_id': 'ERX650232', 'runs': [{'srr': 'ERR705975'}, {'srr': 'ERR705974'}]},
#  {'_id': 'ERX650234', 'runs': [{'srr': 'ERR705976'}]},
#  {'_id': 'ERX650235', 'runs': [{'srr': 'ERR705977'}]},
#  {'_id': 'ERX650236', 'runs': [{'srr': 'ERR705978'}]},
#  {'_id': 'ERX650237', 'runs': [{'srr': 'ERR705979'}]},
#  {'_id': 'ERX650238', 'runs': [{'srr': 'ERR705980'}]},
#  {'_id': 'ERX650239', 'runs': [{'srr': 'ERR705981'}]},
#  {'_id': 'ERX650240', 'runs': [{'srr': 'ERR705982'}]},
#  {'_id': 'ERX650241', 'runs': [{'srr': 'ERR705984'}, {'srr': 'ERR705983'}]},
#  {'_id': 'ERX650243', 'runs': [{'srr': 'ERR705985'}, {'srr': 'ERR705986'}]},
#  {'_id': 'ERX650245', 'runs': [{'srr': 'ERR705987'}, {'srr': 'ERR705988'}]},
#  {'_id': 'ERX650247', 'runs': [{'srr': 'ERR705989'}, {'srr': 'ERR705990'}]},
#  {'_id': 'ERX650249', 'runs': [{'srr': 'ERR705991'}, {'srr': 'ERR705992'}]},
#  {'_id': 'ERX650251', 'runs': [{'srr': 'ERR705993'}, {'srr': 'ERR705994'}]},
#  {'_id': 'ERX650253', 'runs': [{'srr': 'ERR705995'}, {'srr': 'ERR705996'}]},
#  {'_id': 'ERX650255', 'runs': [{'srr': 'ERR705997'}, {'srr': 'ERR705998'}]},
#  {'_id': 'ERX650257', 'runs': [{'srr': 'ERR706000'}, {'srr': 'ERR705999'}]},
#  {'_id': 'ERX650259', 'runs': [{'srr': 'ERR706001'}, {'srr': 'ERR706002'}]},
#  {'_id': 'ERX650261', 'runs': [{'srr': 'ERR706003'}, {'srr': 'ERR706004'}]},
#  {'_id': 'ERX650263', 'runs': [{'srr': 'ERR706005'}, {'srr': 'ERR706006'}]},
#  {'_id': 'ERX650265', 'runs': [{'srr': 'ERR706007'}, {'srr': 'ERR706008'}]},
#  {'_id': 'ERX650267', 'runs': [{'srr': 'ERR706009'}, {'srr': 'ERR706010'}]},
#  {'_id': 'ERX650269', 'runs': [{'srr': 'ERR706011'}]},
#  {'_id': 'ERX650270', 'runs': [{'srr': 'ERR706012'}]},
#  {'_id': 'ERX650271', 'runs': [{'srr': 'ERR706013'}]},
#  {'_id': 'ERX650272', 'runs': [{'srr': 'ERR706014'}]},
#  {'_id': 'ERX650273', 'runs': [{'srr': 'ERR706015'}]},
#  {'_id': 'ERX688215',
#   'runs': [{'srr': 'ERR744534'},
#    {'srr': 'ERR744535'},
#    {'srr': 'ERR744536'},
#    {'srr': 'ERR744533'}]},
#  {'_id': 'ERX688219',
#   'runs': [{'srr': 'ERR744538'},
#    {'srr': 'ERR744539'},
#    {'srr': 'ERR744540'},
#    {'srr': 'ERR744537'}]},
#  {'_id': 'ERX688223',
#   'runs': [{'srr': 'ERR744541'},
#    {'srr': 'ERR744542'},
#    {'srr': 'ERR744543'},
#    {'srr': 'ERR744544'}]},
#  {'_id': 'ERX688227',
#   'runs': [{'srr': 'ERR744545'},
#    {'srr': 'ERR744547'},
#    {'srr': 'ERR744548'},
#    {'srr': 'ERR744546'}]},
#  {'_id': 'ERX688231',
#   'runs': [{'srr': 'ERR744549'},
#    {'srr': 'ERR744550'},
#    {'srr': 'ERR744552'},
#    {'srr': 'ERR744551'}]},
#  {'_id': 'ERX779649', 'runs': [{'srr': 'ERR789486'}]},
#  {'_id': 'ERX779650', 'runs': [{'srr': 'ERR789487'}]},
#  {'_id': 'ERX779651', 'runs': [{'srr': 'ERR789488'}]},
#  {'_id': 'ERX779652', 'runs': [{'srr': 'ERR789489'}]},
#  {'_id': 'ERX779653', 'runs': [{'srr': 'ERR789490'}]},
#  {'_id': 'ERX779654', 'runs': [{'srr': 'ERR789491'}]},
#  {'_id': 'ERX779655', 'runs': [{'srr': 'ERR789492'}]},
#  {'_id': 'ERX779656', 'runs': [{'srr': 'ERR789493'}]},
#  {'_id': 'ERX779657', 'runs': [{'srr': 'ERR789494'}]},
#  {'_id': 'ERX779658', 'runs': [{'srr': 'ERR789495'}]},
#  {'_id': 'ERX779659', 'runs': [{'srr': 'ERR789496'}]},
#  {'_id': 'ERX779660', 'runs': [{'srr': 'ERR789497'}]},
#  {'_id': 'SRX000191', 'runs': [{'srr': 'SRR000917'}, {'srr': 'SRR000918'}]},
#  {'_id': 'SRX000440',
#   'runs': [{'srr': 'SRR001820'},
#    {'srr': 'SRR001821'},
#    {'srr': 'SRR001822'},
#    {'srr': 'SRR001823'},
#    {'srr': 'SRR001824'}]},
#  {'_id': 'SRX000531',
#   'runs': [{'srr': 'SRR001935'}, {'srr': 'SRR001936'}, {'srr': 'SRR001937'}]},
#  {'_id': 'SRX000532',
#   'runs': [{'srr': 'SRR001938'}, {'srr': 'SRR001939'}, {'srr': 'SRR001940'}]},
#  {'_id': 'SRX000533',
#   'runs': [{'srr': 'SRR001941'},
#    {'srr': 'SRR001942'},
#    {'srr': 'SRR001943'},
#    {'srr': 'SRR001944'},
#    {'srr': 'SRR001945'}]},
#  {'_id': 'SRX000534',
#   'runs': [{'srr': 'SRR001946'},
#    {'srr': 'SRR001947'},
#    {'srr': 'SRR001948'},
#    {'srr': 'SRR001949'},
#    {'srr': 'SRR001950'}]},
#  {'_id': 'SRX000538',
#   'runs': [{'srr': 'SRR001960'},
#    {'srr': 'SRR001961'},
#    {'srr': 'SRR001962'},
#    {'srr': 'SRR001963'},
#    {'srr': 'SRR001964'}]},
#  {'_id': 'SRX000556',
#   'runs': [{'srr': 'SRR001970'},
#    {'srr': 'SRR001971'},
#    {'srr': 'SRR001972'},
#    {'srr': 'SRR001973'},
#    {'srr': 'SRR001974'}]},
#  {'_id': 'SRX000558',
#   'runs': [{'srr': 'SRR001980'},
#    {'srr': 'SRR001981'},
#    {'srr': 'SRR001982'},
#    {'srr': 'SRR001983'},
#    {'srr': 'SRR001984'}]},
#  {'_id': 'SRX003311', 'runs': [{'srr': 'SRR014532'}]},
#  {'_id': 'SRX003312', 'runs': [{'srr': 'SRR014533'}]},
#  {'_id': 'SRX006151', 'runs': [{'srr': 'SRR018292'}, {'srr': 'SRR018293'}]},
#  {'_id': 'SRX006152', 'runs': [{'srr': 'SRR018294'}]},
#  {'_id': 'SRX006158', 'runs': [{'srr': 'SRR018305'}, {'srr': 'SRR018306'}]},
#  {'_id': 'SRX006275', 'runs': [{'srr': 'SRR018517'}]},
#  {'_id': 'SRX006276', 'runs': [{'srr': 'SRR018518'}]},
#  {'_id': 'SRX006277', 'runs': [{'srr': 'SRR018519'}]},
#  {'_id': 'SRX006278', 'runs': [{'srr': 'SRR018521'}]},
#  {'_id': 'SRX006279', 'runs': [{'srr': 'SRR018522'}]},
#  {'_id': 'SRX006280', 'runs': [{'srr': 'SRR018523'}]},
#  {'_id': 'SRX006282', 'runs': [{'srr': 'SRR018574'}]},
#  {'_id': 'SRX006283', 'runs': [{'srr': 'SRR018575'}, {'srr': 'SRR029943'}]},
#  {'_id': 'SRX006290', 'runs': [{'srr': 'SRR018580'}]},
#  {'_id': 'SRX006291', 'runs': [{'srr': 'SRR018581'}]},
#  {'_id': 'SRX006292', 'runs': [{'srr': 'SRR018582'}]},
#  {'_id': 'SRX006293', 'runs': [{'srr': 'SRR018583'}, {'srr': 'SRR018584'}]},
#  {'_id': 'SRX006300',
#   'runs': [{'srr': 'SRR018591'}, {'srr': 'SRR018592'}, {'srr': 'SRR018593'}]},
#  {'_id': 'SRX006301', 'runs': [{'srr': 'SRR018594'}]},
#  {'_id': 'SRX006302', 'runs': [{'srr': 'SRR018595'}]},
#  {'_id': 'SRX006303', 'runs': [{'srr': 'SRR018596'}, {'srr': 'SRR018597'}]},
#  {'_id': 'SRX006305', 'runs': [{'srr': 'SRR018603'}]},
#  {'_id': 'SRX010898', 'runs': [{'srr': 'SRR026674'}]},
#  {'_id': 'SRX010899', 'runs': [{'srr': 'SRR026675'}]},
#  {'_id': 'SRX010900', 'runs': [{'srr': 'SRR026676'}]},
#  {'_id': 'SRX010901', 'runs': [{'srr': 'SRR027010'}]},
#  {'_id': 'SRX010902', 'runs': [{'srr': 'SRR027011'}]},
#  {'_id': 'SRX010903', 'runs': [{'srr': 'SRR027012'}]},
#  {'_id': 'SRX010904', 'runs': [{'srr': 'SRR027005'}]},
#  {'_id': 'SRX010905', 'runs': [{'srr': 'SRR027004'}]},
#  {'_id': 'SRX010906', 'runs': [{'srr': 'SRR027006'}]},
#  {'_id': 'SRX010907', 'runs': [{'srr': 'SRR027007'}]},
#  {'_id': 'SRX010908', 'runs': [{'srr': 'SRR027008'}]},
#  {'_id': 'SRX010909', 'runs': [{'srr': 'SRR027009'}]},
#  {'_id': 'SRX010956',
#   'runs': [{'srr': 'SRR026817'},
#    {'srr': 'SRR026887'},
#    {'srr': 'SRR026888'},
#    {'srr': 'SRR026891'},
#    {'srr': 'SRR026892'},
#    {'srr': 'SRR026918'},
#    {'srr': 'SRR026944'},
#    {'srr': 'SRR026945'},
#    {'srr': 'SRR026965'},
#    {'srr': 'SRR026966'}]}]

# %%
remap.find_one({'_id': 'SRX010956'}, {'runs.srr': 1, 'runs.libsize.R1': 1})
# Out:
# {'_id': 'SRX010956',
#  'runs': [{'libsize': {'R1': 6871689}, 'srr': 'SRR026817'},
#   {'libsize': {'R1': 4765078}, 'srr': 'SRR026887'},
#   {'libsize': {'R1': 6938289}, 'srr': 'SRR026888'},
#   {'libsize': {'R1': 9818048}, 'srr': 'SRR026891'},
#   {'libsize': {'R1': 9740412}, 'srr': 'SRR026892'},
#   {'libsize': {'R1': 9666667}, 'srr': 'SRR026918'},
#   {'libsize': {'R1': 8313954}, 'srr': 'SRR026944'},
#   {'libsize': {'R1': 8158990}, 'srr': 'SRR026945'},
#   {'libsize': {'R1': 6115223}, 'srr': 'SRR026965'},
#   {'libsize': {'R1': 5994191}, 'srr': 'SRR026966'}]}

# %%
df = pd.DataFrame(list(remap.aggregate([
    {
        '$match': {
            '_id': {'$in': srxs}
        }
    },
    {'$unwind': '$runs'},
    {
        '$match': {
            'runs.pre_aln_flags': 'complete'
        }
    },
    {
        '$project': {
            '_id': 0,
            'srx': '$_id',
            'srr': '$runs.srr',
            'libsize': '$runs.libsize.R1',
            'readLen': '$runs.avgReadLen.R1'
        }
    }
])))

# %%
'{:,}'.format(df.libsize.sum())
# Out:
# '13,707,559,102'

# %%
df.readLen.describe()
# Out:
# count    561.000000
# mean      84.721801
# std       35.780052
# min        4.000000
# 25%       45.000000
# 50%       98.439799
# 75%      101.000000
# max      151.000000
# Name: readLen, dtype: float64

# %%
df[['srx', 'srr']].to_csv('../../output/wgs_samples.tsv', sep='\t', index=False)
