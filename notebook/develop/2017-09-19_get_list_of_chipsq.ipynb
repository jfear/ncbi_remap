# %% [markdown]
# For the s2RNAi project I need a list of ChIP-seq samples. I am doing it here because this is related to SRA project.

# %%
# %load ../start.py
# Load useful extensions

# Activate the autoreload extension for easy reloading of external packages
# %reload_ext autoreload
# %autoreload 2

# Trun on the water mark
# %reload_ext watermark
# %watermark -u -d -g

# Load ipycache extension
# %reload_ext ipycache
from ipycache import CacheMagics
CacheMagics.cachedir = '../cachedir'

# Add project library to path
import sys
sys.path.insert(0, '../../lib/python')

# The usual suspects
import os
import numpy as np
import pandas as pd

# plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_context('poster')

# Turn off scientific notation
np.set_printoptions(precision=5, suppress=True)
# Out:
# last updated: 2017-09-20
# Git hash: 4bc9218af8c49c09524cdcb0c0e81f7e74f4da46

# %%
# %load ../../bin/load.py
from pymongo import MongoClient
with open('/home/fearjm/Projects/ncbi_remap/output/.mongodb_host', 'r') as fh:
    host = fh.read().strip()
client = MongoClient(host=host, port=27022)
db = client['sra2']
ncbi = db['ncbi']
remap = db['remap']

# %%
df = pd.DataFrame(list(ncbi.aggregate([
    {'$unwind': '$biosample'},
    {'$unwind': '$biosample.attributes'},
    {
        '$match': {
            'biosample.attributes.value': {'$regex': '(S2[\sr\+\-]+|.*Schneider.*)', '$options': 'i'},
        }
    },
    {
        '$project': {
            '_id': 0,
            'srx': '$_id',
            'biosample': '$biosample.biosample_accn',
            'name': '$biosample.attributes.name',
            'value': '$biosample.attributes.value',
            'sra_strategy': '$sra.experiment.library_strategy',
            'sra_source': '$sra.experiment.library_source',
            'sra_selection': '$sra.experiment.library_selection',
        }
    },
])))

# %%
print(df.shape)
# Out:
# (3877, 7)
# (3877, 7)

# %%
df[df.srx.duplicated()]
# Out:
#          biosample       name sra_selection      sra_source sra_strategy  \
# 16    SAMN05710807  cell_line          ChIP         GENOMIC     ChIP-Seq
# 18    SAMN05710808  cell_line          ChIP         GENOMIC     ChIP-Seq
# 20    SAMN05710809  cell_line          ChIP         GENOMIC     ChIP-Seq
# 22    SAMN05710810  cell_line          ChIP         GENOMIC     ChIP-Seq
# 24    SAMN05710811  cell_line          ChIP         GENOMIC     ChIP-Seq
# 26    SAMN05710812  cell_line          ChIP         GENOMIC     ChIP-Seq
# 28    SAMN05710813  cell_line          ChIP         GENOMIC     ChIP-Seq
# 30    SAMN05710814  cell_line          ChIP         GENOMIC     ChIP-Seq
# 32    SAMN05710815  cell_line          ChIP         GENOMIC     ChIP-Seq
# 34    SAMN05710816  cell_line          ChIP         GENOMIC     ChIP-Seq
# 36    SAMN05710818  cell_line          ChIP         GENOMIC     ChIP-Seq
# 38    SAMN05710819  cell_line          ChIP         GENOMIC     ChIP-Seq
# 40    SAMN05710820  cell_line          ChIP         GENOMIC     ChIP-Seq
# 42    SAMN05710821  cell_line          ChIP         GENOMIC     ChIP-Seq
# 44    SAMN05710822  cell_line          ChIP         GENOMIC     ChIP-Seq
# 46    SAMN05710817  cell_line          ChIP         GENOMIC     ChIP-Seq
# 48    SAMN05710823  cell_line          ChIP         GENOMIC     ChIP-Seq
# 50    SAMN05710824  cell_line          ChIP         GENOMIC     ChIP-Seq
# 52    SAMN05710804  cell_line          ChIP         GENOMIC     ChIP-Seq
# 54    SAMN05710829  cell_line          ChIP         GENOMIC     ChIP-Seq
# 56    SAMN05710828  cell_line          ChIP         GENOMIC     ChIP-Seq
# 58    SAMN05710826  cell_line          ChIP         GENOMIC     ChIP-Seq
# 60    SAMN05710825  cell_line          ChIP         GENOMIC     ChIP-Seq
# 62    SAMN05710805  cell_line          ChIP         GENOMIC     ChIP-Seq
# 64    SAMN05710806  cell_line          ChIP         GENOMIC     ChIP-Seq
# 70    SAMN05509059  cell_line         other  TRANSCRIPTOMIC        OTHER
# 72    SAMN05509057  cell_line         other  TRANSCRIPTOMIC        OTHER
# 74    SAMN05509058  cell_line         other  TRANSCRIPTOMIC        OTHER
# 76    SAMN05509060  cell_line         other  TRANSCRIPTOMIC        OTHER
# 78    SAMN05464811  cell_type         other  TRANSCRIPTOMIC        OTHER
# ...            ...        ...           ...             ...          ...
# 3715  SAMN04503041  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3717  SAMN04503040  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3719  SAMN04503039  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3721  SAMN04503038  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3723  SAMN04503037  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3725  SAMN04503036  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3727  SAMN04503035  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3729  SAMN04503034  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3731  SAMN04503033  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3733  SAMN04503032  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3735  SAMN04503031  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3737  SAMN04503030  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3739  SAMN04503029  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3741  SAMN04503028  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3743  SAMN04503027  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3745  SAMN04503026  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3747  SAMN04503025  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3749  SAMN04503024  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3751  SAMN04503023  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3753  SAMN04503022  cell_type          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3776  SAMN04351215  cell_line          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3778  SAMN04351214  cell_line          cDNA  TRANSCRIPTOMIC      RNA-Seq
# 3862  SAMEA2629803     strain        RANDOM  TRANSCRIPTOMIC      RNA-Seq
# 3864  SAMEA2629800     strain        RANDOM  TRANSCRIPTOMIC      RNA-Seq
# 3866  SAMEA2629798     strain        RANDOM  TRANSCRIPTOMIC      RNA-Seq
# 3868  SAMEA2629797     strain        RANDOM  TRANSCRIPTOMIC      RNA-Seq
# 3870  SAMEA2629795     strain        RANDOM  TRANSCRIPTOMIC      RNA-Seq
# 3872  SAMEA2629794     strain        RANDOM  TRANSCRIPTOMIC      RNA-Seq
# 3874  SAMEA2629793     strain        RANDOM  TRANSCRIPTOMIC      RNA-Seq
# 3876  SAMEA2629792     strain        RANDOM  TRANSCRIPTOMIC      RNA-Seq
#
#              srx                     value
# 16    SRX2055967                   S2-DRSC
# 18    SRX2055966                   S2-DRSC
# 20    SRX2055965                   S2-DRSC
# 22    SRX2055964                   S2-DRSC
# 24    SRX2055963                   S2-DRSC
# 26    SRX2055962                   S2-DRSC
# 28    SRX2055961                   S2-DRSC
# 30    SRX2055960                   S2-DRSC
# 32    SRX2055959                   S2-DRSC
# 34    SRX2055958                   S2-DRSC
# 36    SRX2055957                   S2-DRSC
# 38    SRX2055956                   S2-DRSC
# 40    SRX2055955                   S2-DRSC
# 42    SRX2055954                   S2-DRSC
# 44    SRX2055953                   S2-DRSC
# 46    SRX2055952                   S2-DRSC
# 48    SRX2055951                   S2-DRSC
# 50    SRX2055950                   S2-DRSC
# 52    SRX2055949                   S2-DRSC
# 54    SRX2055948                   S2-DRSC
# 56    SRX2055947                   S2-DRSC
# 58    SRX2055946                   S2-DRSC
# 60    SRX2055945                   S2-DRSC
# 62    SRX2055944                   S2-DRSC
# 64    SRX2055943                   S2-DRSC
# 70    SRX1997361              S2 cell line
# 72    SRX1997360              S2 cell line
# 74    SRX1997359              S2 cell line
# 76    SRX1997358              S2 cell line
# 78    SRX1989900                  S2 cells
# ...          ...                       ...
# 3715  SRX1592050                   s2 cell
# 3717  SRX1592049                   s2 cell
# 3719  SRX1592048                   s2 cell
# 3721  SRX1592047                   s2 cell
# 3723  SRX1592046                   s2 cell
# 3725  SRX1592045                   s2 cell
# 3727  SRX1592044                   s2 cell
# 3729  SRX1592043                   s2 cell
# 3731  SRX1592042                   s2 cell
# 3733  SRX1592041                   s2 cell
# 3735  SRX1592040                   s2 cell
# 3737  SRX1592039                   s2 cell
# 3739  SRX1592038                   s2 cell
# 3741  SRX1592037                   s2 cell
# 3743  SRX1592036                   s2 cell
# 3745  SRX1592035                   s2 cell
# 3747  SRX1592034                   s2 cell
# 3749  SRX1592033                   s2 cell
# 3751  SRX1592032                   s2 cell
# 3753  SRX1592031                   s2 cell
# 3776  SRX1492036  S2R+ embryonic cell line
# 3778  SRX1492035  S2R+ embryonic cell line
# 3862   ERX517283                      S2R+
# 3864   ERX517280                      S2R+
# 3866   ERX517278                      S2R+
# 3868   ERX517277                      S2R+
# 3870   ERX517275                      S2R+
# 3872   ERX517274                      S2R+
# 3874   ERX517273                      S2R+
# 3876   ERX517272                      S2R+
#
# [661 rows x 7 columns]

# %%
df.srx.shape
# Out:
# (3877,)

# %%
flip = df.pivot(values='value', columns='name')

# %%
flip.head()
# Out:
# name breed cell_line cell_type dev_stage genotype growth_protocol isolate  \
# 0     None      None      None      None     None            None    None
# 1     None      None      None      None     None            None    None
# 2     None      None      None      None     None            None    None
# 3     None      None      None      None     None            None    None
# 4     None      None      None      None     None            None    None
#
# name library source sample group sample_name sample_type source  \
# 0              None         None        None        None   None
# 1              None         None        None        None   None
# 2              None         None        None        None   None
# 3              None         None        None        None   None
# 4              None         None        None        None   None
#
# name                    source_name strain tissue treatment
# 0     Drosophila S2 cells, dnaj1 KD   None   None      None
# 1     Drosophila S2 cells, dnaj1 KD   None   None      None
# 2       Drosophila S2 cells, mlf KD   None   None      None
# 3       Drosophila S2 cells, mlf KD   None   None      None
# 4      Drosophila S2 cells, lacZ KD   None   None      None

# %%
merged = df.loc[:, ['srx', 'biosample', 'sra_selection', 'sra_source', 'sra_strategy']].join(flip)

# %%
merged.head()
# Out:
#           srx     biosample sra_selection      sra_source sra_strategy breed  \
# 0  SRX2172438  SAMN05784497          cDNA  TRANSCRIPTOMIC      RNA-Seq  None
# 1  SRX2172437  SAMN05784495          cDNA  TRANSCRIPTOMIC      RNA-Seq  None
# 2  SRX2172436  SAMN05784496          cDNA  TRANSCRIPTOMIC      RNA-Seq  None
# 3  SRX2172435  SAMN05784491          cDNA  TRANSCRIPTOMIC      RNA-Seq  None
# 4  SRX2172434  SAMN05784492          cDNA  TRANSCRIPTOMIC      RNA-Seq  None
#
#   cell_line cell_type dev_stage genotype    ...    isolate library source  \
# 0      None      None      None     None    ...       None           None
# 1      None      None      None     None    ...       None           None
# 2      None      None      None     None    ...       None           None
# 3      None      None      None     None    ...       None           None
# 4      None      None      None     None    ...       None           None
#
#   sample group sample_name sample_type source                    source_name  \
# 0         None        None        None   None  Drosophila S2 cells, dnaj1 KD
# 1         None        None        None   None  Drosophila S2 cells, dnaj1 KD
# 2         None        None        None   None    Drosophila S2 cells, mlf KD
# 3         None        None        None   None    Drosophila S2 cells, mlf KD
# 4         None        None        None   None   Drosophila S2 cells, lacZ KD
#
#   strain tissue treatment
# 0   None   None      None
# 1   None   None      None
# 2   None   None      None
# 3   None   None      None
# 4   None   None      None
#
# [5 rows x 21 columns]

# %%
isa = ['modENCODE_2626', 'modENCODE_2627', 'modENCODE_2629', 'modENCODE_2630',
'modENCODE_2633', 'modENCODE_2634', 'modENCODE_2636', 'modENCODE_2638',
'modENCODE_2639', 'modENCODE_2641', 'modENCODE_2642', 'modENCODE_3229',
'modENCODE_3230', 'modENCODE_3232', 'modENCODE_3234', 'modENCODE_3237',
'modENCODE_3238', 'modENCODE_3239', 'modENCODE_3240', 'modENCODE_3241',
'modENCODE_3242', 'modENCODE_3243', 'modENCODE_3245', 'modENCODE_3390',
'modENCODE_3391', 'modENCODE_3392', 'modENCODE_3393', 'modENCODE_3394',
'modENCODE_3395', 'modENCODE_3396', 'modENCODE_3398', 'modENCODE_3399',
'modENCODE_3400', 'modENCODE_3401', 'modENCODE_3402', 'modENCODE_3403',
'modENCODE_3830', 'modENCODE_3956', 'modENCODE_3957', 'modENCODE_3958',
'modENCODE_3959', 'modENCODE_3960', 'modENCODE_4069', 'modENCODE_4070',
'modENCODE_4071', 'modENCODE_4074', 'modENCODE_4078', 'modENCODE_4080',
'modENCODE_4081', 'modENCODE_4082', 'modENCODE_4089', 'modENCODE_4091',
'modENCODE_4094', 'modENCODE_4095', 'modENCODE_4096', 'modENCODE_4098',
'modENCODE_4099', 'modENCODE_4103', 'modENCODE_4104', 'modENCODE_4105',
'modENCODE_4107', 'modENCODE_4113', 'modENCODE_4114', 'modENCODE_4119',
'modENCODE_4352', 'modENCODE_4936', 'modENCODE_4943', 'modENCODE_4944',
'modENCODE_4974', 'modENCODE_4976', 'modENCODE_4981', 'modENCODE_4982',
'modENCODE_4998', 'modENCODE_5004', 'modENCODE_5005', 'modENCODE_5008',
'modENCODE_5014', 'modENCODE_5017', 'modENCODE_5023', 'modENCODE_5024',
'modENCODE_5025', 'modENCODE_5028', 'modENCODE_5029', 'modENCODE_5068',
'modENCODE_5069', 'modENCODE_5070', 'modENCODE_5071', 'modENCODE_5072',
'modENCODE_5110', 'modENCODE_5111', 'modENCODE_5112', 'modENCODE_5113',
'modENCODE_5114', 'modENCODE_5115', 'modENCODE_5116', 'modENCODE_5117',
'modENCODE_5118', 'modENCODE_5119', 'modENCODE_5120', 'modENCODE_5121',
'modENCODE_5122', 'modENCODE_5123', 'modENCODE_5124', 'modENCODE_5125',
'modENCODE_5126', 'modENCODE_5127', 'modENCODE_5128', 'modENCODE_5129',
'modENCODE_5257', 'modENCODE_5264', 'modENCODE_5568', 'modENCODE_5569',
'modENCODE_5570', 'modENCODE_5571', 'modENCODE_5574', 'modENCODE_5575',
'modENCODE_5576', 'modENCODE_5577', 'modENCODE_5579', 'modENCODE_5580',
'modENCODE_5587', 'modENCODE_5590', 'modENCODE_5591', 'modENCODE_5592',
'modENCODE_5593', 'modENCODE_5594', 'modENCODE_5597', 'modENCODE_5598',
'modENCODE_5599', 'modENCODE_5606', 'modENCODE_846', 'modENCODE_847',
'modENCODE_848', 'modENCODE_849', 'modENCODE_850', 'modENCODE_851',
'modENCODE_852', 'modENCODE_853', 'modENCODE_854', 'modENCODE_855',
'modENCODE_856', 'modENCODE_857', 'modENCODE_858', 'modENCODE_859',
'modENCODE_860', 'modENCODE_861', 'modENCODE_862', 'modENCODE_863',
'modENCODE_984', 'modENCODE_985']
print(len(isa))
# Out:
# 150

# %%
modencode = pd.read_table('../../output/modENCODE_sampletable.tsv')
modencode.drop('sra_strategy', axis=1, inplace=True)
modencode['modencode'] = True

# %%
print(len(modencode.modENCODE_id.unique()))
modencode.head()
# Out:
# 805
#          srx        srr    modENCODE_id modENCODE_assay modENCODE_type  \
# 0  SRX002599  SRR013488  modENCODE_1040             UTR           RACE
# 1  SRX002600  SRR013489  modENCODE_1040             UTR           RACE
# 2  SRX002600  SRR013490  modENCODE_1040             UTR           RACE
# 3  SRX002601  SRR013491  modENCODE_1040             UTR           RACE
# 4  SRX002602  SRR013492  modENCODE_1040             UTR           RACE
#
#   modencode
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True

# %%
merged2 = merged.merge(modencode, left_on='srx', right_on='srx', how='left')
merged2.modencode = merged2.modencode.fillna(False)

# %%
print(merged2.shape)
merged2.head()
# Out:
# (4102, 27)
#           srx     biosample sra_selection      sra_source sra_strategy breed  \
# 0  SRX2172438  SAMN05784497          cDNA  TRANSCRIPTOMIC      RNA-Seq  None
# 1  SRX2172437  SAMN05784495          cDNA  TRANSCRIPTOMIC      RNA-Seq  None
# 2  SRX2172436  SAMN05784496          cDNA  TRANSCRIPTOMIC      RNA-Seq  None
# 3  SRX2172435  SAMN05784491          cDNA  TRANSCRIPTOMIC      RNA-Seq  None
# 4  SRX2172434  SAMN05784492          cDNA  TRANSCRIPTOMIC      RNA-Seq  None
#
#   cell_line cell_type dev_stage genotype ...                     source_name  \
# 0      None      None      None     None ...   Drosophila S2 cells, dnaj1 KD
# 1      None      None      None     None ...   Drosophila S2 cells, dnaj1 KD
# 2      None      None      None     None ...     Drosophila S2 cells, mlf KD
# 3      None      None      None     None ...     Drosophila S2 cells, mlf KD
# 4      None      None      None     None ...    Drosophila S2 cells, lacZ KD
#
#   strain tissue treatment  srr modENCODE_id modENCODE_assay modENCODE_type  \
# 0   None   None      None  NaN          NaN             NaN            NaN
# 1   None   None      None  NaN          NaN             NaN            NaN
# 2   None   None      None  NaN          NaN             NaN            NaN
# 3   None   None      None  NaN          NaN             NaN            NaN
# 4   None   None      None  NaN          NaN             NaN            NaN
#
#   modencode  isa
# 0     False  NaN
# 1     False  NaN
# 2     False  NaN
# 3     False  NaN
# 4     False  NaN
#
# [5 rows x 27 columns]

# %%
len(merged2.srx.unique())
# Out:
# 3216

# %%
pd.crosstab(merged2.sra_strategy, merged2.modencode, margins=True)
# Out:
# modencode               False  True   All
# sra_strategy
# ChIP-Seq                  568    62   630
# DNase-Hypersensitivity     14     0    14
# EST                         0    11    11
# MNase-Seq                 104     0   104
# OTHER                     298   149   447
# POOLCLONE                  12     0    12
# RIP-Seq                    82     0    82
# RNA-Seq                  2384   349  2733
# WGS                         4     2     6
# miRNA-Seq                  58     0    58
# ncRNA-Seq                   5     0     5
# All                      3529   573  4102

# %%
ncbi.find_one()
# Out:
# {'_cls': 'Ncbi',
#  '_id': 'SRX2581987',
#  'bioproject': {'bioproject_accn': 'PRJNA357269',
#   'bioproject_id': '357269',
#   'description': "RNA molecules can attach to chromatin and thus provide a type of epigenomic information. It remains difficult to know what RNAs are associated with chromatin and where are the genomic target loci of these RNAs. Here, we present MARGI (Mapping RNA-genome interactions), a technology to massively reveal native RNA-chromatin interactions from unperturbed cells. The gist of this technology is to ligate chromatin-associated RNA (caRNA) with their target genomic sequence by proximity ligation, forming RNA-DNA chimeric sequences, which are converted to sequencing library for paired-end sequencing. Using MARGI, we produced RNA-genome interaction maps for human embryonic stem (ES) cells and HEK cells. MARGI revealed hundreds of chromatin-associated RNAs (caRNA), including previously known XIST, SNHG1, NEAT1, and MALAT1, as well as each caRNA's genomic interaction loci. Using a cross-species experiment, we estimated that approximately 2.2% of MARGI identified interactions are false positives. MARGI data suggested that 80-95% of interactions are proximal, where a caRNA is connected to its nearby genomic regions, 1-2% are distal, and 5-15% are inter-chromosomal. The majority of TSSs are associated with distal or inter-chromosomal caRNAs. ChIP-seq reported H3K27ac and H3K4me3 levels are positively correlated while H3K9me is negatively correlated with MARGI reported RNA attachment levels. The MARGI technology should facilitate revealing novel RNA functions and epigenomic events. Overall design: Two human cell lines were analysed: H9 and HEK. For each, we used two protocols, pxMARGI and diMARGI, having two replicates for the former and only one for the latter. Two samples from each replicate were sequenced. Whereas pxMARGI is designed to not differentiate passive and direct interactions, diMARGI is aimed to reveal protein tethered interactions. For the former, this was achieved by a combination of formaldehyde crosslinking and complete genome fragmentation, by overnight HaeIII digestion to ensure all genomic regions including heterochromatin were fragmented before the subsequent DNA ligation step. For the second, after crosslinking with formaldehyde and DSG, the chromatin was fragmented by sonication, and only the soluble fraction was passed onto the subsequent ligation steps.",
#   'external_id': [],
#   'last_update': datetime.datetime(2017, 1, 26, 0, 0),
#   'name': 'Systematic mapping of RNA-chromatin interactions in vivo',
#   'submission_date': datetime.datetime(2016, 12, 13, 0, 0),
#   'submission_id': 'SUB2354705',
#   'title': 'Systematic mapping of RNA-chromatin interactions in vivo'},
#  'biosample': [{'GEO': 'GSM2427901',
#    'access': 'public',
#    'attributes': [{'name': 'source_name', 'value': 'HEK and DM cells'},
#     {'name': 'cell_line', 'value': 'HEK'},
#     {'name': 'cell_line', 'value': 'DM'},
#     {'name': 'protocol', 'value': 'pxMARGI'}],
#    'biosample_accn': 'SAMN06140184',
#    'biosample_id': '6140184',
#    'biosample_primary': 'SAMN06140184',
#    'contacts': [{'email': 'marcelorivas@gmail.com',
#      'first_name': 'Marcelo',
#      'last_name': 'Rivas'}],
#    'institute': 'Sheng Zhong, Bioengineering, University of California San Diego',
#    'last_update': '2017-02-22',
#    'models': ['Generic'],
#    'organism_name': 'Drosophila melanogaster',
#    'publication_date': '2017-01-27',
#    'sample_id': 'SRS1996012',
#    'submission_date': '2016-12-13',
#    'tax_id': '7227',
#    'tax_name': 'Drosophila melanogaster',
#    'title': 'HEK-dm_pxMARGI_rep1'}],
#  'sra': {'db_flags': ['RNASeq', 'PE'],
#   'db_imported': datetime.datetime(2017, 3, 1, 11, 59, 41, 213000),
#   'experiment': {'GEO_Dataset': '302427901',
#    'attributes': [{'name': 'GEO Accession', 'value': 'GSM2427901'}],
#    'ddbj_links': [],
#    'ena_links': [],
#    'entrez_links': [],
#    'experiment_id': 'SRX2581987',
#    'external_id': [],
#    'instrument_model': 'Illumina MiniSeq',
#    'library_construction_protocol': 'The major steps of MARGI technologies are: crosslinking, isolation of nuclear material, protein biotinylation, genome fragmentation, RNA fragmentation, stabilization of proteins on streptavidin beads, end modification and RNA ligation, DNA ligation, reverse crosslinking, purification of RNA and DNA, removal of biotin from non-ligated linkers, pulldown of ligation products, reverse transcription, DNA denaturation, circularization and re-linearization, generation of sequencing library, and paired-end sequencing. See Extended Materials and Methods in published paper for details. Sequencing library was generated by amplifying material using NEBnext Hi-fidelity PCR enzyme (New England Biolabs M0541S) with NEBnext multiplex oligos for Illumina sequencing (New England Biolabs E7335S) as the primers. Multiple test PCRs with 1 μL of sample and 10 μL reaction volume were run to identify the correct cycle number for the production run. The production PCR was run in a 50 μL reaction volume with 5 μL sample. After the PCR, size selection was performed using Ampure XP beads (Beckman Coulter A63880). Library between 200-2000 bp was selected. Library was run on a Bioanalyzer to determine the size distribution and then paired-end sequenced for 100 cycles at each end on Illumina HiSeq 2500 (PE100) or MiniSeq sequencers (PE150).',
#    'library_layout': 'PAIRED',
#    'library_selection': 'other',
#    'library_source': 'TRANSCRIPTOMIC',
#    'library_strategy': 'OTHER',
#    'platform': 'ILLUMINA',
#    'secondary_id': [],
#    'study_id': 'SRP100516',
#    'submitter_id': [{'db': 'GEO', 'id': 'GSM2427901'}],
#    'title': 'GSM2427901: HEK-dm_pxMARGI_rep1; Drosophila melanogaster; Homo sapiens; OTHER',
#    'url_links': [],
#    'uuid': [],
#    'xref_links': []},
#   'organization': {'abbreviation': 'GEO',
#    'email': 'geo-group@ncbi.nlm.nih.gov',
#    'first_name': 'Geo',
#    'last_name': 'Curators',
#    'name': 'NCBI',
#    'organization_type': 'center'},
#   'pool': ['SRS1996012'],
#   'run': [{'download_path': 'https://sra-download.ncbi.nlm.nih.gov/srapub/SRR5278103',
#     'experiment_id': 'SRX2581987',
#     'external_id': [],
#     'load_date': '2017-02-22',
#     'nbases': 4996041946,
#     'nreads': 2,
#     'nspots': 17428278,
#     'read_count_r1': 17428278.0,
#     'read_count_r2': 17428278.0,
#     'read_len_r1': 142.97,
#     'read_len_r2': 143.69,
#     'release_date': '2017-02-22',
#     'run_flags': ['PE'],
#     'run_id': 'SRR5278103',
#     'samples': ['SRS1996012'],
#     'secondary_id': [],
#     'size_MB': 1928,
#     'submitter_id': [{'db': 'GEO', 'id': 'GSM2427901_r1'}],
#     'uuid': []}],
#   'sample': {'BioProject': '357269',
#    'BioSample': 'SAMN06140184',
#    'GEO': 'GSM2427901',
#    'attributes': [{'name': 'source_name', 'value': 'HEK and DM cells'},
#     {'name': 'cell line', 'value': 'HEK'},
#     {'name': 'cell line', 'value': 'DM'},
#     {'name': 'protocol', 'value': 'pxMARGI'}],
#    'ddbj_links': [],
#    'ena_links': [],
#    'entrez_links': [],
#    'external_id': [],
#    'sample_id': 'SRS1996012',
#    'scientific_name': 'Drosophila melanogaster',
#    'secondary_id': [],
#    'submitter_id': [],
#    'taxon_id': '7227',
#    'title': 'HEK-dm_pxMARGI_rep1',
#    'url_links': [],
#    'uuid': [],
#    'xref_links': []},
#   'study': {'BioProject': 'PRJNA357269',
#    'GEO': 'GSE92345',
#    'abstract': "RNA molecules can attach to chromatin and thus provide a type of epigenomic information. It remains difficult to know what RNAs are associated with chromatin and where are the genomic target loci of these RNAs. Here, we present MARGI (Mapping RNA-genome interactions), a technology to massively reveal native RNA-chromatin interactions from unperturbed cells. The gist of this technology is to ligate chromatin-associated RNA (caRNA) with their target genomic sequence by proximity ligation, forming RNA-DNA chimeric sequences, which are converted to sequencing library for paired-end sequencing. Using MARGI, we produced RNA-genome interaction maps for human embryonic stem (ES) cells and HEK cells. MARGI revealed hundreds of chromatin-associated RNAs (caRNA), including previously known XIST, SNHG1, NEAT1, and MALAT1, as well as each caRNA's genomic interaction loci. Using a cross-species experiment, we estimated that approximately 2.2% of MARGI identified interactions are false positives. MARGI data suggested that 80-95% of interactions are proximal, where a caRNA is connected to its nearby genomic regions, 1-2% are distal, and 5-15% are inter-chromosomal. The majority of TSSs are associated with distal or inter-chromosomal caRNAs. ChIP-seq reported H3K27ac and H3K4me3 levels are positively correlated while H3K9me is negatively correlated with MARGI reported RNA attachment levels. The MARGI technology should facilitate revealing novel RNA functions and epigenomic events. Overall design: Two human cell lines were analysed: H9 and HEK. For each, we used two protocols, pxMARGI and diMARGI, having two replicates for the former and only one for the latter. Two samples from each replicate were sequenced. Whereas pxMARGI is designed to not differentiate passive and direct interactions, diMARGI is aimed to reveal protein tethered interactions. For the former, this was achieved by a combination of formaldehyde crosslinking and complete genome fragmentation, by overnight HaeIII digestion to ensure all genomic regions including heterochromatin were fragmented before the subsequent DNA ligation step. For the second, after crosslinking with formaldehyde and DSG, the chromatin was fragmented by sonication, and only the soluble fraction was passed onto the subsequent ligation steps.",
#    'center_name': 'GEO',
#    'center_project_name': 'GSE92345',
#    'ddbj_links': [],
#    'ena_links': [],
#    'entrez_links': [],
#    'external_id': [],
#    'related_studies': [],
#    'secondary_id': [],
#    'study_id': 'SRP100516',
#    'study_type': 'Other',
#    'submitter_id': [],
#    'title': 'Systematic mapping of RNA-chromatin interactions in vivo',
#    'url_links': [],
#    'uuid': [],
#    'xref_links': []},
#   'submission': {'broker': 'GEO',
#    'external_id': [],
#    'secondary_id': [],
#    'submission_id': 'SRA539405',
#    'submitter_id': [{'db': 'GEO', 'id': 'GEO: GSE92345'}],
#    'uuid': []}}}
