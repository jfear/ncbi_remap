# %%
import os
import sys
from pathlib import Path

from IPython.display import display, HTML, Markdown
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Project level imports
sys.path.insert(0, '../lib')
from ncbi_remap.notebook import Nb
from ncbi_remap.plotting import make_figs

# %%
# Setup notebook
nbconfig = Nb.setup_notebook()
# Out:
# Please check output/fbgn2chrom.tsv. If it does not exist, run bin/fbgn2chrom.py
# last updated: 2018-10-05
# Git hash: d9f50945fa864956cc17f22a30aafc5244874783

# %%
# Connect to data store
store = pd.HDFStore('../output/sra.h5', mode='r')

# %%
complete_srx = store['aln/complete'].srx.unique().tolist()

# %%
from pymongo import MongoClient
try:
    with open('../output/.mongodb_host', 'r') as fh:
        host = fh.read().strip()
except FileNotFoundError:
    host = 'localhost'

mongoClient = MongoClient(host=host, port=27017)
db = mongoClient['sramongo']
ncbi = db['ncbi']

# %%
libstrat = pd.DataFrame(list(ncbi.aggregate([
    {
        '$match': {
            '_id': {'$in': complete_srx},
        }
    },
    {
        '$unwind': {
            'path': "$runs"
        }
    },
    {
        '$project': {
            '_id': 0,
            'srx': '$srx',
            'srr': '$runs.srr',
            'library_strategy': '$sra.experiment.library_strategy'
        }
    }
]))).set_index(['srx', 'srr'])

# %%
srxs = libstrat.query('library_strategy == "RNA-Seq"').index.get_level_values('srx').unique()
srrs = libstrat.query('library_strategy == "RNA-Seq"').index.get_level_values('srr').unique()

# %%
flag_well_stranded = store.select('prealn/workflow/collectrnaseqmetrics/second', where='srx == srxs', columns=['PCT_CORRECT_STRAND_READS']) >= .99

# %%
stranded_srx = flag_well_stranded[flag_well_stranded.iloc[:, 0]].index.get_level_values('srx').unique()
stranded_srr = flag_well_stranded[flag_well_stranded.iloc[:, 0]].index.get_level_values('srr').unique()

# %%
len(stranded_srr)
# Out:
# 2429

# %%
len(stranded_srx)
# Out:
# 2293

# %%
with open('../data/312_sample_golden_set_2016-06-14.txt') as fh:
    golden = fh.read().split('\n')

# %%
cnt = 0
for srr in golden:
    if srr in srrs:
        cnt += 1

print(f'Number of golden in srrs: {cnt} of {len(golden)}')
# Out:
# Number of golden in srrs: 311 of 313

# %%
cnt = 0
for srr in golden:
    if srr in stranded_srr:
        cnt += 1
        
print(f'Number of golden in super strand: {cnt} of {len(golden)}')
# Out:
# Number of golden in super strand: 236 of 313

# %%
metadata = pd.read_csv('../output/geo-wf/rnaseq_metadata.tsv', sep='\t')

# %%
stranded_meta = metadata.query(f'sample_name == {stranded_srx.tolist()}')
stranded_meta.set_index('sample_name', inplace=True)

# %%
stranded_meta.contact.value_counts()
# Out:
# Brian Oliver <briano@helix.nih.gov>                          1075
# Fiona Ingleby <f.ingleby@sussex.ac.uk>                        178
# Jun Chen <cjnankai@gmail.com>                                  96
# Stein Aerts <Stein.Aerts@med.kuleuven.be>                      45
# Yuheng Huang <yuheng.huang.sysu@gmail.com>                     45
# Michael Antosh <Michael_Antosh@brown.edu>                      32
# Michael Elgart <elgart@gmail.com>                              28
# Jean-Yves Roignant <j.roignant@imb-mainz.de>                   27
# Chris Seidel <seidel@phageT4.org>                              25
# Corbin Jones <cdjones@email.unc.edu>                           24
# Tadeusz Kawecki <tadeusz.kawecki@unil.ch>                      24
# Jin Li <jin.billy.li@stanford.edu>                             24
# Carl Thummel <cthummel@genetics.utah.edu>                      20
# Benoit Biteau <benoit_biteau@urmc.rochester.edu>               19
# Maria Spletter <maria.spletter@gmail.com>                      18
# John Tower <jtower@usc.edu>                                    18
# Jelle Jacobs <jelle.jacobs@kuleuven.be>                        18
# Naren Srinivasan <naren.srinivasan@crick.ac.uk>                18
# Natalie Dye <dye@mpi-cbg.de>                                   17
# Thomas Burkard <thomas.burkard@imba.oeaw.ac.at>                16
# Alexandra Franz <afranz88@googlemail.com>                      15
# Fumiyo Ikeda <fumiyo.ikeda@imba.oeaw.ac.at>                    13
# Wayne Hemphill <hemphiwo@gmail.com>                            12
# Ville Hietakangas <ville.hietakangas@helsinki.fi>              11
# Nigel Mongan <nigel.mongan@nottingham.ac.uk>                   11
# Mikhail Shaposhnikov <mshaposhnikov@mail.ru>                   11
# Jiajia Li <jli.umsl@gmail.com>                                 10
# Konrad Basler <konrad.basler@imls.uzh.ch>                      10
# Cedric Maurange <cedric.maurange@univ-amu.fr>                   9
# Maheva Andriatsilavo <maheandria@gmail.com>                     9
#                                                              ...
# Kohei Shimaji <shimakou24@gmail.com>                            4
# Do Young Hyeon <doyoungh@postech.ac.kr>                         3
# Mirka Uhlirova <mirka.uhlirova@uni-koeln.de>                    3
# Shiqi Luo <sqluo@pku.edu.cn>                                    3
# Wenyan NONG <nongwy@gmail.com>                                  3
# Fabio Lefebvre <fabioalexis.lefebvre@ircm.qc.ca>                3
# Alexey Arkov <aarkov@murraystate.edu>                           2
# Christopher Hemmerich <chemmeri@indiana.edu>                    2
# Santhosh Girirajan <sxg47@psu.edu>                              2
# Sebastian Kittelmann <sebastian.kittelmann@path.ox.ac.uk>       2
# Peter Andersen <peter.andersen@imba.oeaw.ac.at>                 2
# Yu An Lin <llin2@carnegiescience.edu>                           2
# Bin Tian <btian@rutgers.edu>                                    2
# Peter Chang <peterlchang@gmail.com>                             2
# Qi Wang <rubbyqi@sjtu.edu.cn>                                   2
# Pedro Sousa-Victor <pvictor@buckinstitute.org>                  2
# Maria De Luca <mdeluca2@uab.edu>                                2
# Xiaowei Zhuang <zhuang@chemistry.harvard.edu>                   2
# Nikos Karaiskos <nikolaos.karaiskos@mdc-berlin.de>              2
# sanjay khadayate <khadayate@gmail.com>                          2
# Julia Zeitlinger <jbz@stowers.org>                              2
# Mei-Ju Chen <arbula@gmail.com>                                  1
# Frédérique Peronnet <frederique.peronnet@upmc.fr>               1
# Jie Wang <jie.wang@umassmed.edu>                                1
# Travis Thomson <travis.thomson@umassmed.edu>                    1
# Peter Combs <peter.combs@berkeley.edu>                          1
# SEVERINE CHAMBEYRON <severine.chambeyron@igh.cnrs.fr>           1
# Guillaume Filion <guillaume.filion@gmail.com>                   1
# Samuel Lewis <sam.lewis@gen.cam.ac.uk>                          1
# Jun Wei Pek <junwei@tll.org.sg>                                 1
# Name: contact, Length: 85, dtype: int64

# %%
stranded_meta.tissue.value_counts()
# Out:
# whole body                                          998
# head                                                154
# ovary                                               149
# embryo                                               81
# wing disc                                            54
# gut                                                  32
# indirect flight muscle                               23
# testis                                               21
# midgut                                               18
# antenna                                              18
# eye disc                                             18
# fat body                                             17
# brain                                                16
# abdomen without digestive or reproductive system     16
# gonad                                                16
# thorax without digestive system                      16
# digestive system                                     16
# imaginal disc                                        15
# reproductive system without gonad and genitalia      14
# head and thorax                                      14
# genitalia                                            13
# carcass                                              12
# ventral nerve cord                                    9
# fat body and ovary                                    8
# hindgut                                               8
# muscle                                                8
# haltere disc                                          7
# ovariole                                              7
# leg                                                   6
# tubule                                                6
# anal pad                                              4
# eye-antennal disc                                     4
# wing                                                  4
# accessory gland                                       3
# trachea                                               3
# decapitated body                                      3
# salivary gland                                        3
# seminal vesicle                                       2
# CNS                                                   2
# thorax                                                1
# Name: tissue, dtype: int64

# %%
stranded_meta.columns
# Out:
# Index(['title', 'organism', 'study', 'runs', 'GEO Experiment', 'GEO Sample',
#        'BioSample ID', 'BioProject', 'pubmed', 'pubmed_title',
#        'pubmed_citation', 'pubmed_authors', 'contact', 'sex',
#        'developmental stage', 'tissue', 'cell type', 'molecule', 'description',
#        'raw file'],
#       dtype='object')

# %%
stranded_meta['cell type'].value_counts()
# Out:
# S2R+               2013
# S2                   79
# Kc167                21
# OSC                  17
# neuroblast           15
# gut progenitor       13
# OSS                   8
# embryonic             4
# head of fly           3
# blastema              3
# wing disc pouch       3
# D17-c3                2
# Name: cell type, dtype: int64

# %%
stranded_meta['developmental stage'].value_counts()
# Out:
# adult                               909
# adult stage 0-10 days               217
# third instar larval stage           143
# larval stage                         89
# pupal stage                          59
# first instar larval stage            51
# embryonic stage 2 h (ael)            28
# embryonic stage 10-14 h (ael)        16
# embryonic stage                      12
# embryonic stage 2-3 h (ael)           9
# pupal stage 30 h (apf)                8
# pupal stage 72 h (apf)                7
# embryonic stage 4-10 h (ael)          7
# pupal stage 24 h (apf)                7
# pupal stage 8 h (apf)                 6
# pupal stage 96 h (apf)                6
# embryonic stage 2-4 h (ael)           6
# pupal stage 40 h (apf)                6
# embryonic stage 10-11 h (ael)         5
# embryonic stage 3-3.5 h (ael)         4
# embryonic stage 1.5-3 h (ael)         4
# embryonic stage 10-12 h (ael)         4
# embryonic stage 15-21 h (ael)         4
# embryonic stage 6-8 h (ael)           4
# pupal stage 44 h (apf)                3
# embryonic stage 0-4 h (ael)           3
# pupal stage 48 h (apf)                3
# pupal stage 16 h (apf)                3
# pupal stage 18 h (apf)                2
# pupal stage 90 h (apf)                2
# embryonic stage 12-18 h (ael)         1
# embryonic stage 0.75 h (ael)          1
# pupal stage 6 h (apf)                 1
# embryonic stage 1.5-6 h (ael)         1
# embryonic stage 18-24 h (ael)         1
# embryonic stage 0.75-1.5 h (ael)      1
# embryonic stage 6-12 h (ael)          1
# Name: developmental stage, dtype: int64

# %%
stranded_meta.study.value_counts().head(3)
# Out:
# SRP074593    1770
# SRP045429     249
# SRP064744     242
# Name: study, dtype: int64

# %%
stranded_meta.query('study == "SRP069203"')
# Out:
#                                    title                 organism      study  \
# sample_name
# SRX1557614    Sample_f_0_DNifmDNcff_rep1  Drosophila melanogaster  SRP069203
# SRX1557615    Sample_f_0_DNifmDNcff_rep2  Drosophila melanogaster  SRP069203
# SRX1557616    Sample_f_0_DNifmDNcff_rep3  Drosophila melanogaster  SRP069203
# SRX1557617    Sample_f_0_DNifmDNcff_rep4  Drosophila melanogaster  SRP069203
# SRX1557618         Sample_f_0_DNifm_rep1  Drosophila melanogaster  SRP069203
# SRX1557619         Sample_f_0_DNifm_rep2  Drosophila melanogaster  SRP069203
# SRX1557620         Sample_f_0_DNifm_rep3  Drosophila melanogaster  SRP069203
# SRX1557621         Sample_f_0_DNifm_rep4  Drosophila melanogaster  SRP069203
# SRX1557622           Sample_f_0_gpp_rep1  Drosophila melanogaster  SRP069203
# SRX1557623           Sample_f_0_gpp_rep2  Drosophila melanogaster  SRP069203
# SRX1557624           Sample_f_0_gpp_rep3  Drosophila melanogaster  SRP069203
# SRX1557625           Sample_f_0_gpp_rep4  Drosophila melanogaster  SRP069203
# SRX1557626          Sample_f_0_lacZ_rep1  Drosophila melanogaster  SRP069203
# SRX1557627          Sample_f_0_lacZ_rep2  Drosophila melanogaster  SRP069203
# SRX1557628          Sample_f_0_lacZ_rep3  Drosophila melanogaster  SRP069203
# SRX1557629          Sample_f_0_lacZ_rep4  Drosophila melanogaster  SRP069203
# SRX1557630         Sample_f_0_lilli_rep1  Drosophila melanogaster  SRP069203
# SRX1557631         Sample_f_0_lilli_rep2  Drosophila melanogaster  SRP069203
# SRX1557632         Sample_f_0_lilli_rep3  Drosophila melanogaster  SRP069203
# SRX1557633         Sample_f_0_lilli_rep4  Drosophila melanogaster  SRP069203
# SRX1557634         Sample_f_0_SuTpl_rep1  Drosophila melanogaster  SRP069203
# SRX1557635         Sample_f_0_SuTpl_rep2  Drosophila melanogaster  SRP069203
# SRX1557636         Sample_f_0_SuTpl_rep3  Drosophila melanogaster  SRP069203
# SRX1557637         Sample_f_0_SuTpl_rep4  Drosophila melanogaster  SRP069203
# SRX1557638             Sample_f_0_w_rep2  Drosophila melanogaster  SRP069203
# SRX1557639             Sample_f_0_w_rep3  Drosophila melanogaster  SRP069203
# SRX1557640             Sample_f_0_w_rep4  Drosophila melanogaster  SRP069203
# SRX1557641   Sample_f_24_DNifmDNcff_rep1  Drosophila melanogaster  SRP069203
# SRX1557642   Sample_f_24_DNifmDNcff_rep2  Drosophila melanogaster  SRP069203
# SRX1557643        Sample_f_24_DNifm_rep1  Drosophila melanogaster  SRP069203
# ...                                  ...                      ...        ...
# SRX1742656          Sample_ov_0_gpp_rep3  Drosophila melanogaster  SRP069203
# SRX1742657          Sample_ov_0_gpp_rep4  Drosophila melanogaster  SRP069203
# SRX1742658         Sample_ov_0_lacZ_rep1  Drosophila melanogaster  SRP069203
# SRX1742659         Sample_ov_0_lacZ_rep2  Drosophila melanogaster  SRP069203
# SRX1742660         Sample_ov_0_lacZ_rep3  Drosophila melanogaster  SRP069203
# SRX1742661         Sample_ov_0_lacZ_rep4  Drosophila melanogaster  SRP069203
# SRX1742662        Sample_ov_0_lilli_rep1  Drosophila melanogaster  SRP069203
# SRX1742663        Sample_ov_0_lilli_rep2  Drosophila melanogaster  SRP069203
# SRX1742664        Sample_ov_0_lilli_rep3  Drosophila melanogaster  SRP069203
# SRX1742665        Sample_ov_0_lilli_rep4  Drosophila melanogaster  SRP069203
# SRX1742666        Sample_ov_0_SuTpl_rep1  Drosophila melanogaster  SRP069203
# SRX1742667        Sample_ov_0_SuTpl_rep2  Drosophila melanogaster  SRP069203
# SRX1742668        Sample_ov_0_SuTpl_rep3  Drosophila melanogaster  SRP069203
# SRX1742669        Sample_ov_0_SuTpl_rep4  Drosophila melanogaster  SRP069203
# SRX1742670        Sample_test_0_gpp_rep1  Drosophila melanogaster  SRP069203
# SRX1742671        Sample_test_0_gpp_rep2  Drosophila melanogaster  SRP069203
# SRX1742672        Sample_test_0_gpp_rep3  Drosophila melanogaster  SRP069203
# SRX1742673        Sample_test_0_gpp_rep4  Drosophila melanogaster  SRP069203
# SRX1742674       Sample_test_0_lacZ_rep1  Drosophila melanogaster  SRP069203
# SRX1742675       Sample_test_0_lacZ_rep2  Drosophila melanogaster  SRP069203
# SRX1742676       Sample_test_0_lacZ_rep3  Drosophila melanogaster  SRP069203
# SRX1742677       Sample_test_0_lacZ_rep4  Drosophila melanogaster  SRP069203
# SRX1742678      Sample_test_0_lilli_rep1  Drosophila melanogaster  SRP069203
# SRX1742679      Sample_test_0_lilli_rep2  Drosophila melanogaster  SRP069203
# SRX1742680      Sample_test_0_lilli_rep3  Drosophila melanogaster  SRP069203
# SRX1742681      Sample_test_0_lilli_rep4  Drosophila melanogaster  SRP069203
# SRX1742682      Sample_test_0_SuTpl_rep1  Drosophila melanogaster  SRP069203
# SRX1742683      Sample_test_0_SuTpl_rep2  Drosophila melanogaster  SRP069203
# SRX1742684      Sample_test_0_SuTpl_rep3  Drosophila melanogaster  SRP069203
# SRX1742685      Sample_test_0_SuTpl_rep4  Drosophila melanogaster  SRP069203
#
#                    runs GEO Experiment  GEO Sample  BioSample ID   BioProject  \
# sample_name
# SRX1557614   SRR3139779       GSE77492  GSM2053163  SAMN04452925  PRJNA310631
# SRX1557615   SRR3139780       GSE77492  GSM2053164  SAMN04452926  PRJNA310631
# SRX1557616   SRR3139781       GSE77492  GSM2053165  SAMN04452927  PRJNA310631
# SRX1557617   SRR3139782       GSE77492  GSM2053166  SAMN04452928  PRJNA310631
# SRX1557618   SRR3139783       GSE77492  GSM2053167  SAMN04452929  PRJNA310631
# SRX1557619   SRR3139784       GSE77492  GSM2053168  SAMN04452930  PRJNA310631
# SRX1557620   SRR3139785       GSE77492  GSM2053169  SAMN04452931  PRJNA310631
# SRX1557621   SRR3139786       GSE77492  GSM2053170  SAMN04452932  PRJNA310631
# SRX1557622   SRR3139787       GSE77492  GSM2053171  SAMN04452933  PRJNA310631
# SRX1557623   SRR3139788       GSE77492  GSM2053172  SAMN04452934  PRJNA310631
# SRX1557624   SRR3139789       GSE77492  GSM2053173  SAMN04452935  PRJNA310631
# SRX1557625   SRR3139790       GSE77492  GSM2053174  SAMN04452936  PRJNA310631
# SRX1557626   SRR3139791       GSE77492  GSM2053175  SAMN04452937  PRJNA310631
# SRX1557627   SRR3139792       GSE77492  GSM2053176  SAMN04452938  PRJNA310631
# SRX1557628   SRR3139793       GSE77492  GSM2053177  SAMN04452939  PRJNA310631
# SRX1557629   SRR3139794       GSE77492  GSM2053178  SAMN04452940  PRJNA310631
# SRX1557630   SRR3139795       GSE77492  GSM2053179  SAMN04452941  PRJNA310631
# SRX1557631   SRR3139796       GSE77492  GSM2053180  SAMN04452942  PRJNA310631
# SRX1557632   SRR3139797       GSE77492  GSM2053181  SAMN04452943  PRJNA310631
# SRX1557633   SRR3139798       GSE77492  GSM2053182  SAMN04452944  PRJNA310631
# SRX1557634   SRR3139799       GSE77492  GSM2053183  SAMN04452945  PRJNA310631
# SRX1557635   SRR3139800       GSE77492  GSM2053184  SAMN04452946  PRJNA310631
# SRX1557636   SRR3139801       GSE77492  GSM2053185  SAMN04452947  PRJNA310631
# SRX1557637   SRR3139802       GSE77492  GSM2053186  SAMN04452948  PRJNA310631
# SRX1557638   SRR3139803       GSE77492  GSM2053187  SAMN04452949  PRJNA310631
# SRX1557639   SRR3139804       GSE77492  GSM2053188  SAMN04452950  PRJNA310631
# SRX1557640   SRR3139805       GSE77492  GSM2053189  SAMN04452951  PRJNA310631
# SRX1557641   SRR3139806       GSE77492  GSM2053190  SAMN04452952  PRJNA310631
# SRX1557642   SRR3139807       GSE77492  GSM2053191  SAMN04452953  PRJNA310631
# SRX1557643   SRR3139808       GSE77492  GSM2053192  SAMN04452954  PRJNA310631
# ...                 ...            ...         ...           ...          ...
# SRX1742656   SRR3475983       GSE77492  GSM2143081  SAMN04942789  PRJNA310631
# SRX1742657   SRR3475984       GSE77492  GSM2143082  SAMN04942739  PRJNA310631
# SRX1742658   SRR3475985       GSE77492  GSM2143083  SAMN04942740  PRJNA310631
# SRX1742659   SRR3475986       GSE77492  GSM2143084  SAMN04942741  PRJNA310631
# SRX1742660   SRR3475987       GSE77492  GSM2143085  SAMN04942742  PRJNA310631
# SRX1742661   SRR3475988       GSE77492  GSM2143086  SAMN04942743  PRJNA310631
# SRX1742662   SRR3475989       GSE77492  GSM2143087  SAMN04942744  PRJNA310631
# SRX1742663   SRR3475990       GSE77492  GSM2143088  SAMN04942745  PRJNA310631
# SRX1742664   SRR3475991       GSE77492  GSM2143089  SAMN04942746  PRJNA310631
# SRX1742665   SRR3475992       GSE77492  GSM2143090  SAMN04942747  PRJNA310631
# SRX1742666   SRR3475993       GSE77492  GSM2143091  SAMN04942748  PRJNA310631
# SRX1742667   SRR3475994       GSE77492  GSM2143092  SAMN04942749  PRJNA310631
# SRX1742668   SRR3475995       GSE77492  GSM2143093  SAMN04942750  PRJNA310631
# SRX1742669   SRR3475996       GSE77492  GSM2143094  SAMN04942751  PRJNA310631
# SRX1742670   SRR3475997       GSE77492  GSM2143095  SAMN04942752  PRJNA310631
# SRX1742671   SRR3475998       GSE77492  GSM2143096  SAMN04942753  PRJNA310631
# SRX1742672   SRR3475999       GSE77492  GSM2143097  SAMN04942754  PRJNA310631
# SRX1742673   SRR3476000       GSE77492  GSM2143098  SAMN04942755  PRJNA310631
# SRX1742674   SRR3476001       GSE77492  GSM2143099  SAMN04942756  PRJNA310631
# SRX1742675   SRR3476002       GSE77492  GSM2143100  SAMN04942757  PRJNA310631
# SRX1742676   SRR3476003       GSE77492  GSM2143101  SAMN04942758  PRJNA310631
# SRX1742677   SRR3476004       GSE77492  GSM2143102  SAMN04942759  PRJNA310631
# SRX1742678   SRR3476005       GSE77492  GSM2143103  SAMN04942760  PRJNA310631
# SRX1742679   SRR3476006       GSE77492  GSM2143104  SAMN04942761  PRJNA310631
# SRX1742680   SRR3476007       GSE77492  GSM2143105  SAMN04942762  PRJNA310631
# SRX1742681   SRR3476008       GSE77492  GSM2143106  SAMN04942763  PRJNA310631
# SRX1742682   SRR3476009       GSE77492  GSM2143107  SAMN04942764  PRJNA310631
# SRX1742683   SRR3476010       GSE77492  GSM2143108  SAMN04942765  PRJNA310631
# SRX1742684   SRR3476011       GSE77492  GSM2143109  SAMN04942766  PRJNA310631
# SRX1742685   SRR3476012       GSE77492  GSM2143110  SAMN04942767  PRJNA310631
#
#              pubmed pubmed_title pubmed_citation pubmed_authors  \
# sample_name
# SRX1557614      NaN          NaN             NaN            NaN
# SRX1557615      NaN          NaN             NaN            NaN
# SRX1557616      NaN          NaN             NaN            NaN
# SRX1557617      NaN          NaN             NaN            NaN
# SRX1557618      NaN          NaN             NaN            NaN
# SRX1557619      NaN          NaN             NaN            NaN
# SRX1557620      NaN          NaN             NaN            NaN
# SRX1557621      NaN          NaN             NaN            NaN
# SRX1557622      NaN          NaN             NaN            NaN
# SRX1557623      NaN          NaN             NaN            NaN
# SRX1557624      NaN          NaN             NaN            NaN
# SRX1557625      NaN          NaN             NaN            NaN
# SRX1557626      NaN          NaN             NaN            NaN
# SRX1557627      NaN          NaN             NaN            NaN
# SRX1557628      NaN          NaN             NaN            NaN
# SRX1557629      NaN          NaN             NaN            NaN
# SRX1557630      NaN          NaN             NaN            NaN
# SRX1557631      NaN          NaN             NaN            NaN
# SRX1557632      NaN          NaN             NaN            NaN
# SRX1557633      NaN          NaN             NaN            NaN
# SRX1557634      NaN          NaN             NaN            NaN
# SRX1557635      NaN          NaN             NaN            NaN
# SRX1557636      NaN          NaN             NaN            NaN
# SRX1557637      NaN          NaN             NaN            NaN
# SRX1557638      NaN          NaN             NaN            NaN
# SRX1557639      NaN          NaN             NaN            NaN
# SRX1557640      NaN          NaN             NaN            NaN
# SRX1557641      NaN          NaN             NaN            NaN
# SRX1557642      NaN          NaN             NaN            NaN
# SRX1557643      NaN          NaN             NaN            NaN
# ...             ...          ...             ...            ...
# SRX1742656      NaN          NaN             NaN            NaN
# SRX1742657      NaN          NaN             NaN            NaN
# SRX1742658      NaN          NaN             NaN            NaN
# SRX1742659      NaN          NaN             NaN            NaN
# SRX1742660      NaN          NaN             NaN            NaN
# SRX1742661      NaN          NaN             NaN            NaN
# SRX1742662      NaN          NaN             NaN            NaN
# SRX1742663      NaN          NaN             NaN            NaN
# SRX1742664      NaN          NaN             NaN            NaN
# SRX1742665      NaN          NaN             NaN            NaN
# SRX1742666      NaN          NaN             NaN            NaN
# SRX1742667      NaN          NaN             NaN            NaN
# SRX1742668      NaN          NaN             NaN            NaN
# SRX1742669      NaN          NaN             NaN            NaN
# SRX1742670      NaN          NaN             NaN            NaN
# SRX1742671      NaN          NaN             NaN            NaN
# SRX1742672      NaN          NaN             NaN            NaN
# SRX1742673      NaN          NaN             NaN            NaN
# SRX1742674      NaN          NaN             NaN            NaN
# SRX1742675      NaN          NaN             NaN            NaN
# SRX1742676      NaN          NaN             NaN            NaN
# SRX1742677      NaN          NaN             NaN            NaN
# SRX1742678      NaN          NaN             NaN            NaN
# SRX1742679      NaN          NaN             NaN            NaN
# SRX1742680      NaN          NaN             NaN            NaN
# SRX1742681      NaN          NaN             NaN            NaN
# SRX1742682      NaN          NaN             NaN            NaN
# SRX1742683      NaN          NaN             NaN            NaN
# SRX1742684      NaN          NaN             NaN            NaN
# SRX1742685      NaN          NaN             NaN            NaN
#
#                                          contact     sex developmental stage  \
# sample_name
# SRX1557614   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557615   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557616   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557617   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557618   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557619   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557620   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557621   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557622   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557623   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557624   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557625   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557626   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557627   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557628   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557629   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557630   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557631   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557632   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557633   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557634   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557635   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557636   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557637   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557638   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557639   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557640   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557641   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557642   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1557643   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# ...                                          ...     ...                 ...
# SRX1742656   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742657   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742658   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742659   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742660   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742661   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742662   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742663   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742664   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742665   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742666   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742667   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742668   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742669   Brian Oliver <briano@helix.nih.gov>  female                 NaN
# SRX1742670   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742671   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742672   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742673   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742674   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742675   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742676   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742677   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742678   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742679   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742680   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742681   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742682   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742683   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742684   Brian Oliver <briano@helix.nih.gov>    male                 NaN
# SRX1742685   Brian Oliver <briano@helix.nih.gov>    male                 NaN
#
#             tissue cell type molecule                            description  \
# sample_name
# SRX1557614     NaN       NaN     cDNA            cff1|ifm1|ll7|gonad|without
# SRX1557615     NaN       NaN     cDNA            cff1|ifm1|ll7|gonad|without
# SRX1557616     NaN       NaN     cDNA            cff1|ifm1|ll7|gonad|without
# SRX1557617     NaN       NaN     cDNA            cff1|ifm1|ll7|gonad|without
# SRX1557618     NaN       NaN     cDNA                 ifm1|ll7|gonad|without
# SRX1557619     NaN       NaN     cDNA                 ifm1|ll7|gonad|without
# SRX1557620     NaN       NaN     cDNA                 ifm1|ll7|gonad|without
# SRX1557621     NaN       NaN     cDNA                 ifm1|ll7|gonad|without
# SRX1557622     NaN       NaN     cDNA  hms00160|trip|attp2|ll7|gonad|without
# SRX1557623     NaN       NaN     cDNA  hms00160|trip|attp2|ll7|gonad|without
# SRX1557624     NaN       NaN     cDNA  hms00160|trip|attp2|ll7|gonad|without
# SRX1557625     NaN       NaN     cDNA  hms00160|trip|attp2|ll7|gonad|without
# SRX1557626     NaN       NaN     cDNA                      ll7|gonad|without
# SRX1557627     NaN       NaN     cDNA                      ll7|gonad|without
# SRX1557628     NaN       NaN     cDNA                      ll7|gonad|without
# SRX1557629     NaN       NaN     cDNA                      ll7|gonad|without
# SRX1557630     NaN       NaN     cDNA  hms01066|trip|attp2|ll7|gonad|without
# SRX1557631     NaN       NaN     cDNA  hms01066|trip|attp2|ll7|gonad|without
# SRX1557632     NaN       NaN     cDNA  hms01066|trip|attp2|ll7|gonad|without
# SRX1557633     NaN       NaN     cDNA  hms01066|trip|attp2|ll7|gonad|without
# SRX1557634     NaN       NaN     cDNA  hms00277|trip|attp2|ll7|gonad|without
# SRX1557635     NaN       NaN     cDNA  hms00277|trip|attp2|ll7|gonad|without
# SRX1557636     NaN       NaN     cDNA  hms00277|trip|attp2|ll7|gonad|without
# SRX1557637     NaN       NaN     cDNA  hms00277|trip|attp2|ll7|gonad|without
# SRX1557638     NaN       NaN     cDNA                      ll7|gonad|without
# SRX1557639     NaN       NaN     cDNA                      ll7|gonad|without
# SRX1557640     NaN       NaN     cDNA                      ll7|gonad|without
# SRX1557641     NaN       NaN     cDNA            cff1|ifm1|ll7|gonad|without
# SRX1557642     NaN       NaN     cDNA            cff1|ifm1|ll7|gonad|without
# SRX1557643     NaN       NaN     cDNA                 ifm1|ll7|gonad|without
# ...            ...       ...      ...                                    ...
# SRX1742656     NaN       NaN     cDNA          hms00160|trip|attp2|ll7|ovary
# SRX1742657     NaN       NaN     cDNA          hms00160|trip|attp2|ll7|ovary
# SRX1742658     NaN       NaN     cDNA                              ll7|ovary
# SRX1742659     NaN       NaN     cDNA                              ll7|ovary
# SRX1742660     NaN       NaN     cDNA                              ll7|ovary
# SRX1742661     NaN       NaN     cDNA                              ll7|ovary
# SRX1742662     NaN       NaN     cDNA          hms01066|trip|attp2|ll7|ovary
# SRX1742663     NaN       NaN     cDNA          hms01066|trip|attp2|ll7|ovary
# SRX1742664     NaN       NaN     cDNA          hms01066|trip|attp2|ll7|ovary
# SRX1742665     NaN       NaN     cDNA          hms01066|trip|attp2|ll7|ovary
# SRX1742666     NaN       NaN     cDNA          hms00277|trip|attp2|ll7|ovary
# SRX1742667     NaN       NaN     cDNA          hms00277|trip|attp2|ll7|ovary
# SRX1742668     NaN       NaN     cDNA          hms00277|trip|attp2|ll7|ovary
# SRX1742669     NaN       NaN     cDNA          hms00277|trip|attp2|ll7|ovary
# SRX1742670     NaN       NaN     cDNA         hms00160|trip|attp2|testis|ll7
# SRX1742671     NaN       NaN     cDNA         hms00160|trip|attp2|testis|ll7
# SRX1742672     NaN       NaN     cDNA         hms00160|trip|attp2|testis|ll7
# SRX1742673     NaN       NaN     cDNA         hms00160|trip|attp2|testis|ll7
# SRX1742674     NaN       NaN     cDNA                        testis|ll7|male
# SRX1742675     NaN       NaN     cDNA                        testis|ll7|male
# SRX1742676     NaN       NaN     cDNA                        testis|ll7|male
# SRX1742677     NaN       NaN     cDNA                        testis|ll7|male
# SRX1742678     NaN       NaN     cDNA         hms01066|trip|attp2|testis|ll7
# SRX1742679     NaN       NaN     cDNA         hms01066|trip|attp2|testis|ll7
# SRX1742680     NaN       NaN     cDNA         hms01066|trip|attp2|testis|ll7
# SRX1742681     NaN       NaN     cDNA         hms01066|trip|attp2|testis|ll7
# SRX1742682     NaN       NaN     cDNA         hms00277|trip|attp2|testis|ll7
# SRX1742683     NaN       NaN     cDNA         hms00277|trip|attp2|testis|ll7
# SRX1742684     NaN       NaN     cDNA         hms00277|trip|attp2|testis|ll7
# SRX1742685     NaN       NaN     cDNA         hms00277|trip|attp2|testis|ll7
#
#                raw file
# sample_name
# SRX1557614   SRX1557614
# SRX1557615   SRX1557615
# SRX1557616   SRX1557616
# SRX1557617   SRX1557617
# SRX1557618   SRX1557618
# SRX1557619   SRX1557619
# SRX1557620   SRX1557620
# SRX1557621   SRX1557621
# SRX1557622   SRX1557622
# SRX1557623   SRX1557623
# SRX1557624   SRX1557624
# SRX1557625   SRX1557625
# SRX1557626   SRX1557626
# SRX1557627   SRX1557627
# SRX1557628   SRX1557628
# SRX1557629   SRX1557629
# SRX1557630   SRX1557630
# SRX1557631   SRX1557631
# SRX1557632   SRX1557632
# SRX1557633   SRX1557633
# SRX1557634   SRX1557634
# SRX1557635   SRX1557635
# SRX1557636   SRX1557636
# SRX1557637   SRX1557637
# SRX1557638   SRX1557638
# SRX1557639   SRX1557639
# SRX1557640   SRX1557640
# SRX1557641   SRX1557641
# SRX1557642   SRX1557642
# SRX1557643   SRX1557643
# ...                 ...
# SRX1742656   SRX1742656
# SRX1742657   SRX1742657
# SRX1742658   SRX1742658
# SRX1742659   SRX1742659
# SRX1742660   SRX1742660
# SRX1742661   SRX1742661
# SRX1742662   SRX1742662
# SRX1742663   SRX1742663
# SRX1742664   SRX1742664
# SRX1742665   SRX1742665
# SRX1742666   SRX1742666
# SRX1742667   SRX1742667
# SRX1742668   SRX1742668
# SRX1742669   SRX1742669
# SRX1742670   SRX1742670
# SRX1742671   SRX1742671
# SRX1742672   SRX1742672
# SRX1742673   SRX1742673
# SRX1742674   SRX1742674
# SRX1742675   SRX1742675
# SRX1742676   SRX1742676
# SRX1742677   SRX1742677
# SRX1742678   SRX1742678
# SRX1742679   SRX1742679
# SRX1742680   SRX1742680
# SRX1742681   SRX1742681
# SRX1742682   SRX1742682
# SRX1742683   SRX1742683
# SRX1742684   SRX1742684
# SRX1742685   SRX1742685
#
# [189 rows x 20 columns]
