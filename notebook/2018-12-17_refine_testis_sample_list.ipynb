# %%
import os
import sys
from pathlib import Path

from IPython.display import display, HTML, Markdown
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Project level imports
sys.path.insert(0, '../lib')
from ncbi_remap.notebook import Nb
from ncbi_remap.plotting import make_figs

# Setup notebook
nbconfig = Nb.setup_notebook()

# Connect to data store
store = pd.HDFStore('../output/sra.h5', mode='r')
# Out:
# Please check output/fbgn2chrom.tsv. If it does not exist, run bin/fbgn2chrom.py
# last updated: 2018-12-17
# Git hash: f01d62feb710e26559e101e98d266e8e00f2b91f

# %%
# Get a list of Testis Libraries
metadata = pd.read_csv('../output/geo-wf/rnaseq_metadata.tsv', sep='\t', index_col=0).query('tissue == "testis"')
testis_srxs = metadata.index.unique().tolist()
metadata.head()
# Out:
#                                 title                 organism      study  \
# sample_name
# ERX2162339   Male_Testis_1; FlyAtlas2  Drosophila melanogaster  ERP024551
# ERX2162340              Male_Testis_2  Drosophila melanogaster  ERP024551
# ERX2162341              Male_Testis_3  Drosophila melanogaster  ERP024551
# SRX014984           Bam mutant testes  Drosophila melanogaster  SRP001566
# SRX014985            Wild type testes  Drosophila melanogaster  SRP001566
#
#                                                 runs GEO Experiment  \
# sample_name
# ERX2162339                                ERR2105061            NaN
# ERX2162340                                ERR2105062            NaN
# ERX2162341                                ERR2105063            NaN
# SRX014984    SRR032300|SRR032301|SRR032302|SRR032303       GSE16960
# SRX014985    SRR032304|SRR032305|SRR032306|SRR032307       GSE16960
#
#             GEO Sample    BioSample ID   BioProject      pubmed  \
# sample_name
# ERX2162339         NaN  SAMEA104226667   PRJEB22205         NaN
# ERX2162340         NaN  SAMEA104226668   PRJEB22205         NaN
# ERX2162341         NaN  SAMEA104226669   PRJEB22205         NaN
# SRX014984    GSM424748    SAMN00007104  PRJNA117723  22019781.0
# SRX014985    GSM424749    SAMN00007105  PRJNA117723  22019781.0
#
#                                                   pubmed_title  \
# sample_name
# ERX2162339                                                 NaN
# ERX2162340                                                 NaN
# ERX2162341                                                 NaN
# SRX014984    Evidence for compensatory upregulation of expr...
# SRX014985    Evidence for compensatory upregulation of expr...
#
#                            pubmed_citation  \
# sample_name
# ERX2162339                             NaN
# ERX2162340                             NaN
# ERX2162341                             NaN
# SRX014984    1546-1718 43 Nat. Genet. 2011
# SRX014985    1546-1718 43 Nat. Genet. 2011
#
#                                                 pubmed_authors contact   sex  \
# sample_name
# ERX2162339                                                 NaN     NaN  male
# ERX2162340                                                 NaN     NaN  male
# ERX2162341                                                 NaN     NaN  male
# SRX014984    DengX|HiattJ|NguyenD|ErcanS|SturgillD|HillierL...     NaN   NaN
# SRX014985    DengX|HiattJ|NguyenD|ErcanS|SturgillD|HillierL...     NaN  male
#
#             developmental stage  tissue cell type molecule  \
# sample_name
# ERX2162339                  NaN  testis       NaN   RANDOM
# ERX2162340                  NaN  testis       NaN   RANDOM
# ERX2162341                  NaN  testis       NaN   RANDOM
# SRX014984                   NaN  testis       NaN     cDNA
# SRX014985                   NaN  testis       NaN     cDNA
#
#                         description    raw file
# sample_name
# ERX2162339         flyatlas2|testis  ERX2162339
# ERX2162340              testis|male  ERX2162340
# ERX2162341              testis|male  ERX2162341
# SRX014984    testis|mutant|bam|mrna   SRX014984
# SRX014985               testis|mrna   SRX014985

# %%
# Get a list of srxs that have 75% of reads well stranded
stranded = store.select('prealn/workflow/collectrnaseqmetrics/second', where='srx == testis_srxs & PCT_CORRECT_STRAND_READS >= .75').index.get_level_values('srx').unique().tolist()
with open('../output/notebook/2018-12-17_testis_stranded_libraries.txt', 'w') as fh:
    fh.write('\n'.join(stranded))

# %%
# Get list of PE testis libraries
pe = store.select('layout', 'srx == testis_srxs & layout == "PE"').index.get_level_values('srx').unique().tolist()
with open('../output/notebook/2018-12-17_testis_pe_libraries.txt', 'w') as fh:
    fh.write('\n'.join(pe))
