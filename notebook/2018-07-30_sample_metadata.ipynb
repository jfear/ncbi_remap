# %% [markdown]
# # Sample Metadata

# %% [markdown]
# I have done my first submission of RNA-Seq data to GEO, but they really want sample biological metadata to add for indexing purposes. This is not an easy problem solved for everything, but if I can get most things sorted out then that will be good enough. I want to focus on the categroies:
#
# * Sex
# * Developmental stage
# * strain
# * tissue
# * cell type
#
# I am not sure if I will be able to get a reasonable parsing of strain, but at least I can try the others.

# %%
import os
import sys
from pathlib import Path
import re
from collections import defaultdict
from yaml import load

from IPython.display import display, HTML, Markdown
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Project level imports
sys.path.insert(0, '../lib')
from ncbi_remap.notebook import Nb
from ncbi_remap.plotting import make_figs

# %%
# Setup notebook
nbconfig = Nb.setup_notebook()
# Out:
# Please check output/fbgn2chrom.tsv. If it does not exist, run bin/fbgn2chrom.py
# last updated: 2018-07-31
# Git hash: 8506138704bf2e17010368949820110db52a4599

# %%
from pymongo import MongoClient
try:
    with open('../output/.mongodb_host', 'r') as fh:
        host = fh.read().strip()
except FileNotFoundError:
    host = 'localhost'

mongoClient = MongoClient(host=host, port=27017)
db = mongoClient['sra']
ncbi = db['ncbi']

# %% [markdown]
# ## Get list of uploaded samples

# %%
sample_list = pd.read_csv('/media/psf/Promise_Pegasus/fearjm/ncbi_remap/geo-wf/justin.fear@nih.gov/sample_section.tsv', sep='\t', usecols=[0]).sample_name.unique().tolist()

# %%
metadata = pd.DataFrame([], index=sample_list, columns=['sex', 'developmental stage', 'tissue', 'strain', 'cell type'])
metadata.head()
# Out:
#            sex developmental stage tissue strain cell type
# DRX013093  NaN                 NaN    NaN    NaN       NaN
# DRX013094  NaN                 NaN    NaN    NaN       NaN
# DRX014765  NaN                 NaN    NaN    NaN       NaN
# DRX014766  NaN                 NaN    NaN    NaN       NaN
# DRX014767  NaN                 NaN    NaN    NaN       NaN

# %% [markdown]
# ## Attribute dump

# %%
attrs = pd.DataFrame(list(ncbi.aggregate([
    {
        '$match': {
            '_id': {'$in': sample_list}
        }
    },
    {
        '$unwind': {
            'path': '$sra.sample.attributes'
        }
    },
    {
        '$project': {
            '_id': 0,
            'srx': '$_id',
            'name': '$sra.sample.attributes.name',
            'value': '$sra.sample.attributes.value'
        }
    },
])))

# %%
attrs.shape
# Out:
# (70753, 3)

# %%
# Initial normalization
replace_dict = {
    '_': ' ', 
    '; ': ';', 
    ' / ': '/',
    'dev stage': 'developmental stage', 
    'dev-stage': 'developmental stage',
    'developemntal stage': 'developmental stage', 
    'development stage': 'developmental stage', 
    'developmental stage': 'developmental stage', 
    'develpomental stage': 'developmental stage', 
    'cell/tissue type': 'tissue',
    'tissue lib': 'tissue', 
    'tissue source': 'tissue',
    'tissue type': 'tissue', 
    'tissue/cell type': 'tissue',
}
regex = re.compile('|'.join(replace_dict.keys()))

attrs['name'] = attrs['name'].str.lower().apply(lambda s: regex.sub(lambda x: replace_dict[x.group()], s))
attrs['value'] = attrs['value'].str.lower().apply(lambda s: regex.sub(lambda x: replace_dict[x.group()], s))

# %%
attrsp = attrs.pivot_table(values='value', index='srx', columns='name', aggfunc='first').copy()

# %%
bow = {}
for srx, row in attrsp.iterrows():
    bow[srx] = ' '.join(row.dropna().values.tolist())

# %%
print(sorted(attrsp.columns.tolist()))
# Out:
# ['adapter', 'adapter barcode', 'affinity purification', 'age', 'age of flies', 'age of fly in days post eclosion', 'agent', 'ages', 'alternate taxon id 1', 'alternate taxon id 2', 'amplification', 'antibody', 'assay', 'background strain', 'barcode', 'barcode-kit', 'batch', 'biological replicate', 'biological replicate number', 'biological replicates', 'biomarker', 'biomaterial provider', 'bioproject id', 'bioprojectid', 'biorep', 'biosamplemodel', 'birth date', 'birth location', 'bloomington stock center id', 'body site', 'breed', 'breeding history', 'breeding method', 'cage', 'cell class', 'cell line', 'cell line background', 'cell passages', 'cell subtype', 'cell type', 'cell type marker', 'cells', 'cells derived from', 'checksum', 'chip antibody', 'chip or ip antibody', 'clip antibody', 'colection date', 'collected by', 'collection date', 'compound', 'condition', 'crosses', 'cultivar', 'culture collection', 'custom name', 'days after eclosion', 'days after treatment', 'days at 29 c', 'days post infection', 'death date', 'dev stage', 'developmental stage', 'developmental temperature', 'developmental time', 'developmental time point', 'dgrp line', 'diet', 'directional', 'disease', 'disease stage', 'dissection', 'dmso', 'dose', 'drosdel deficiency', 'drosdel id', 'drug for synchronization', 'dstim knockdown status', 'ecotype', 'embryonic stage', 'embryonic temperature', 'ena-first-public', 'ena-last-update', 'environment (biome)', 'environment (feature)', 'environment (material)', 'ercc infomation', 'ercc pool', 'evolutionary regime', 'experiment', 'experimental condition', 'experimental population', 'experimental procedure', 'expression', 'expression vector', 'exptgroup', 'external rna control', 'extraction method', 'extraction protocol', 'facs-sorted cells', 'fastqs from', 'fed on', 'fed with', 'feeding type', 'female genotype', 'file no.', 'fixation', 'flag', 'flow cell', 'fluorescent cell marker', 'fly knockdown gene', 'fly knockdown vdrc line', 'fly line', 'fly/stock id', 'flybase species id', 'food', 'fraction', 'full genotype', 'gal4 line', 'gender', 'gender type', 'gender/age', 'generation', 'genetic background', 'genetic cross', 'genetic modification', 'genotype', 'genotype of male the female mated with', 'genotype/variaion', 'genotype/variation', 'geo loc name', 'geographic location', 'geographic location (country and/or sea)', 'germline knock-down', 'germline knockdown and other transgenes', 'grandparental obesity', 'group', 'growth condition', 'growth conditions', 'growth protocol', 'guide rna', 'health state', 'heat hours', 'hormone for culture', 'host', 'host-associated environmental package', 'hours at restrictive temperature', 'human knockdown gene', 'iclip barcode', 'illumina barcode', 'incubation time', 'index', 'infection', 'infection status', 'initial time point', 'injected with', 'injury', 'input rna volume', 'investigation type', 'ip antibody', 'isolate', 'isolation source', 'knockdown', 'label', 'lane', 'lat lon', 'latitude', 'length of culture', 'library prep protocol', 'library preparation method', 'library selection', 'library source', 'library strategy', 'library-kit', 'line', 'line source', 'longitude', 'lysis buffer ion concentrations', 'lysis strategy', 'machine', 'marker', 'maternal genotype', 'mating status', 'mating system', 'mean insert size', 'microbiome status', 'midgut part', 'midgut region', 'molecule subtype', 'monosome enrichment strategy', 'muscle type', 'normalization', 'notes', 'number cells', 'oleic acid', 'organism', 'organism part', 'original pipeline', 'paired or single-end', 'parental heterozygosity', 'parental obesity', 'passage', 'passages', 'pe read length (bp)', 'phenotype', 'plasmid', 'plate and well id', 'platform', 'population', 'population diet', 'population replicate', 'project name', 'protocol', 'pull-down tag', 'purified length', 'quality', 'qualscores', 'quantity', 'radiation dose', 'random barcode', 'reared on', 'repeat', 'replicate', 'replicate no.', 'replicates', ' ...

# %%
#print(sorted(attrs.value.unique().tolist()))

# %%
def parse_sex(attrsp, metadata):
    dat = attrsp['sex']

    with open('../geo-wf/config/sex.yaml') as fh:
        sex_norm = load(fh)

    for k, v in sex_norm.items():
        if v == 'None':
            sex_norm[k] = np.nan

    dat.replace(sex_norm, inplace=True)
    metadata.update(dat.dropna())
        
    missing = metadata.sex.isna().index.tolist()
    for srx in missing:
        try:
            string = bow[srx]
        except KeyError:
            continue

        mf = re.search(r'\bfemale\b', string)
        mm = re.search(r'\bmale\b', string)
        if (mf is not None) & (mm is not None):
            metadata.loc[srx, 'sex'] = 'mixed'
        elif mf:
            metadata.loc[srx, 'sex'] = 'female'
        elif mm:
            metadata.loc[srx, 'sex'] = 'male'
            
parse_sex(attrsp, metadata)

# %%
def parse_dev(attrsp, metadata):
    dat = attrsp['developmental stage']

    with open('../geo-wf/config/dev_stage.yaml') as fh:
        dev_norm = load(fh)

    for k, v in dev_norm.items():
        if v == 'None':
            dev_norm[k] = np.nan

    dat.replace(dev_norm, inplace=True)
    metadata.update(dat.dropna())
            
parse_dev(attrsp, metadata)

# %%
def parse_tissue(attrsp, metadata):
    dat = attrsp['tissue']

    with open('../geo-wf/config/tissue.yaml') as fh:
        tissue_norm = load(fh)

    for k, v in tissue_norm.items():
        if v == 'None':
            tissue_norm[k] = np.nan

    dat.replace(tissue_norm, inplace=True)
    metadata.update(dat.dropna())
            
parse_tissue(attrsp, metadata)

# %%
attrs = pd.DataFrame(list(ncbi.aggregate([
    {
        '$match': {
            '_id': {'$in': sample_list}
        }
    },
    {
        '$unwind': {
            'path': '$sra.sample.attributes'
        }
    },
    {
        '$project': {
            '_id': 0,
            'srx': '$_id',
            'name': '$sra.sample.attributes.name',
            'value': '$sra.sample.attributes.value'
        }
    },
])))

# %%
attrs.shape
# Out:
# (70753, 3)

# %%
# Initial normalization
replace_dict = {
    '_': ' ', 
    '; ': ';', 
    ' / ': '/',
    'cell/tissue type': 'cell type',
    'tissue/cell type': 'cell type',
    'cell class': 'cell type', 
    'cell line': 'cell type', 
    'cell line background': 'cell type', 
    'cell subtype': 'cell type', 
    'cell type': 'cell type', 
    'cells': 'cell type', 
    'cells derived from': 'cell type',
}
regex = re.compile('|'.join(replace_dict.keys()))

attrs['name'] = attrs['name'].str.lower().apply(lambda s: regex.sub(lambda x: replace_dict[x.group()], s))
attrs['value'] = attrs['value'].str.lower().apply(lambda s: regex.sub(lambda x: replace_dict[x.group()], s))

# %%
attrsp = attrs.pivot_table(values='value', index='srx', columns='name', aggfunc='first').copy()

# %%
bow = {}
for srx, row in attrsp.iterrows():
    bow[srx] = ' '.join(row.d.opna().values.tolist())

# %%
def parse_cell_type(attrsp, metadata):
    dat = attrsp['cell type']

    with open('../geo-wf/config/cell_type.yaml') as fh:
        norm = load(fh)

    for k, v in norm.items():
        if v == 'None':
            norm[k] = np.nan

    dat.replace(norm, inplace=True)
    metadata.update(dat.dropna())
            
parse_cell_type(attrsp, metadata)

# %%
metadata['cell type'].dropna()
# Out:
# ERX173563    S2
# ERX173565    S2
# ERX173570    S2
# ERX173571    S2
# ERX173572    S2
# ERX173578    S2
# ERX173581    S2
# ERX173588    S2
# ERX173594    S2
# ERX173597    S2
# ERX173598    S2
# ERX173601    S2
# ERX173605    S2
# ERX173607    S2
# ERX173611    S2
# ERX173614    S2
# ERX173615    S2
# ERX173617    S2
# ERX173618    S2
# ERX173625    S2
# ERX173631    S2
# ERX173640    S2
# ERX173642    S2
# ERX173647    S2
# ERX173651    S2
# ERX173658    S2
# ERX173659    S2
# ERX173661    S2
# ERX173664    S2
# ERX173668    S2
#              ..
# SRX976314    S3
# SRX976315    S3
# SRX976316    S3
# SRX976317    S3
# SRX976318    S3
# SRX976319    S3
# SRX976320    S3
# SRX976321    S3
# SRX976322    S3
# SRX976323    S3
# SRX976324    S3
# SRX976325    S3
# SRX976326    S3
# SRX981410    S2
# SRX981411    S2
# SRX981412    S2
# SRX981413    S2
# SRX981414    S2
# SRX981415    S2
# SRX982548    S2
# SRX982550    S2
# SRX982551    S2
# SRX982552    S2
# SRX982553    S2
# SRX984881    S2
# SRX984882    S2
# SRX984883    S2
# SRX984887    S2
# SRX984888    S2
# SRX984889    S2
# Name: cell type, Length: 3560, dtype: object

# %%
metadata
# Out:
#               sex developmental stage tissue strain cell type
# DRX013093     NaN                 NaN    NaN    NaN       NaN
# DRX013094     NaN                 NaN    NaN    NaN       NaN
# DRX014765  female                 NaN    NaN    NaN       NaN
# DRX014766  female                 NaN    NaN    NaN       NaN
# DRX014767    male                 NaN    NaN    NaN       NaN
# DRX014768    male                 NaN    NaN    NaN       NaN
# DRX014769  female                 NaN    NaN    NaN       NaN
# DRX014770  female                 NaN    NaN    NaN       NaN
# DRX014771    male                 NaN    NaN    NaN       NaN
# DRX014772    male                 NaN    NaN    NaN       NaN
# DRX014773  female                 NaN    NaN    NaN       NaN
# DRX014774  female                 NaN    NaN    NaN       NaN
# DRX014775    male                 NaN    NaN    NaN       NaN
# DRX014776    male                 NaN    NaN    NaN       NaN
# DRX014777  female                 NaN    NaN    NaN       NaN
# DRX014778  female                 NaN    NaN    NaN       NaN
# DRX014779    male                 NaN    NaN    NaN       NaN
# DRX014780    male                 NaN    NaN    NaN       NaN
# DRX014781  female                 NaN    NaN    NaN       NaN
# DRX014782  female                 NaN    NaN    NaN       NaN
# DRX014783    male                 NaN    NaN    NaN       NaN
# DRX014784    male                 NaN    NaN    NaN       NaN
# DRX014785  female                 NaN    NaN    NaN       NaN
# DRX014786  female                 NaN    NaN    NaN       NaN
# DRX014787    male                 NaN    NaN    NaN       NaN
# DRX014788    male                 NaN    NaN    NaN       NaN
# DRX014789  female                 NaN    NaN    NaN       NaN
# DRX014790  female                 NaN    NaN    NaN       NaN
# DRX014791    male                 NaN    NaN    NaN       NaN
# DRX014792    male                 NaN    NaN    NaN       NaN
# ...           ...                 ...    ...    ...       ...
# SRX982552  female                 NaN    NaN    NaN        S2
# SRX982553  female                 NaN    NaN    NaN        S2
# SRX984881     NaN                 NaN    NaN    NaN        S2
# SRX984882     NaN                 NaN    NaN    NaN        S2
# SRX984883     NaN                 NaN    NaN    NaN        S2
# SRX984887     NaN                 NaN    NaN    NaN        S2
# SRX984888     NaN                 NaN    NaN    NaN        S2
# SRX984889     NaN                 NaN    NaN    NaN        S2
# SRX986397  female               adult    NaN    NaN       NaN
# SRX986398  female               adult    NaN    NaN       NaN
# SRX986399  female               adult    NaN    NaN       NaN
# SRX986400  female               adult    NaN    NaN       NaN
# SRX986401  female               adult    NaN    NaN       NaN
# SRX986402    male               adult    NaN    NaN       NaN
# SRX986403    male               adult    NaN    NaN       NaN
# SRX986404    male               adult    NaN    NaN       NaN
# SRX986405    male               adult    NaN    NaN       NaN
# SRX986406    male               adult    NaN    NaN       NaN
# SRX986407    male               adult    NaN    NaN       NaN
# SRX986408  female               adult    NaN    NaN       NaN
# SRX986409  female               adult    NaN    NaN       NaN
# SRX986410  female               adult    NaN    NaN       NaN
# SRX986411  female               adult    NaN    NaN       NaN
# SRX986412  female               adult    NaN    NaN       NaN
# SRX986413    male               adult    NaN    NaN       NaN
# SRX986414    male               adult    NaN    NaN       NaN
# SRX986415    male               adult    NaN    NaN       NaN
# SRX986416    male               adult    NaN    NaN       NaN
# SRX986417    male               adult    NaN    NaN       NaN
# SRX986418    male               adult    NaN    NaN       NaN
#
# [14423 rows x 5 columns]

# %%
bowS = pd.Series(bow)
bowS.name = 'bow'

# %%
helper = ''
for dv, bb in devs.join(bowS, how='left').groupby('developmental stage'):
    mylist = ' '.join(bb.bow.unique().tolist())
    helper += f'{dv}\t{mylist}\n'

# %%
with open('/tmp/helper.tsv', 'w') as fo:
    fo.write(helper)
