# %% [markdown]
# # Build Metadata Table

# %% [markdown]
# I need to build a metadata table for submitting to GEO. We are going to do these submissions in batches, so here I am focusing on the ~5k samples I want to send to FlyBase. The metadata table should include all links to other databases and any other information that I find relevant.

# %%
import os
import sys
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from pymongo import MongoClient

# Project level imports
sys.path.insert(0, '../lib')
from ncbi_remap.notebook import Nb
from ncbi_remap.plotting import make_figs
from ncbi_remap.parser import parse_hisat2

# Setup notebook
nbconfig = Nb.setup_notebook()

# Turn on cache
from joblib import Memory
memory = Memory(cachedir=nbconfig.cache, verbose=0)

# Connect to data store
store = pd.HDFStore('../sra.h5', mode='r')

# Connect to DB
host_pth = Path('../output/.mongodb_host')
if host_pth.exists():
    with host_pht.open() as fh:
        host = fh.read().strip()
else:
    host = 'localhost'

client = MongoClient(host=host, port=27022)
db = client['sra2']
ncbi = db['ncbi']
biometa = db['biometa']
remap = db['remap']
# Out:
# last updated: 2017-12-22
# Git hash: 1b967a52a83923ec9a93b57db9d3dee8b476e63f

# %%
# Get list of SRX
good = pd.read_csv('../output/flybase_samples.tsv', sep='\t') 
srx = good.srx.values.tolist()

# %%
records = list(ncbi.aggregate([
    {
        '$match': {
            '_id': {'$in': srx}
        }
    },
    {
        '$project': {
            '_id': 0,
            'srx': '$_id',
            'bioproject': '$bioproject.bioproject_accn',
            'biosample': { '$arrayElemAt': [ '$biosample.biosample_accn', 0] },
            'srs': '$sra.sample.sample_id',
            'gsm': '$sra.sample.GEO',
            'srp': '$sra.study.study_id',
            'sra': '$sra.submission.submission_id',
            'pubmed': '$pubmed.pubmed_id',
            'contact': {'$arrayElemAt': [{'$arrayElemAt': ['$biosample.contacts', 0]}, 0]},
        }
    },
    {
        '$project': {
            'srx': '$srx',
            'bioproject': '$bioproject',
            'biosample': '$biosample',
            'srs': '$srs',
            'gsm': '$gsm',
            'srp': '$srp',
            'sra': '$sra',
            'pubmed': '$pubmed',
            'first_name': '$contact.first_name',
            'last_name': '$contact.last_name',
            'email': '$contact.email',
        }
    }
]))

# %%
records[0]
# Out:
# {'bioproject': 'PRJDB2557',
#  'biosample': 'SAMD00012584',
#  'pubmed': ['25003736', '25003736'],
#  'sra': 'DRA001188',
#  'srp': 'DRP001250',
#  'srs': 'DRS012553',
#  'srx': 'DRX012753'}

# %%
def cleanup_pubmed(l):
    if not isinstance(l, list):
        return l
    if l == []:
        return np.nan
    return '|'.join(list(set(l)))

df = pd.DataFrame(records)
df.pubmed = df.pubmed.apply(cleanup_pubmed)
df = df.merge(good, on='srx', how='outer')
df.set_index(['srx', 'srr'], inplace=True)

header = ['srs', 'srp', 'gsm', 'bioproject', 'biosample', 'pubmed', 'first_name', 'last_name', 'email',]
df = df[header].copy()

# %%
df.head()
# Out:
#                            srs        srp  gsm bioproject     biosample  \
# srx       srr
# DRX012753 DRR014222  DRS012553  DRP001250  NaN  PRJDB2557  SAMD00012584
# DRX012754 DRR014223  DRS012553  DRP001250  NaN  PRJDB2557  SAMD00012584
# DRX012755 DRR014224  DRS012553  DRP001250  NaN  PRJDB2557  SAMD00012584
# DRX073117 DRR079273  DRS039996  DRP003423  NaN  PRJDB5381  SAMD00069299
# DRX073118 DRR079274  DRS039997  DRP003423  NaN  PRJDB5381  SAMD00069300
#
#                        pubmed first_name last_name email
# srx       srr
# DRX012753 DRR014222  25003736        NaN       NaN   NaN
# DRX012754 DRR014223  25003736        NaN       NaN   NaN
# DRX012755 DRR014224  25003736        NaN       NaN   NaN
# DRX073117 DRR079273       NaN        NaN       NaN   NaN
# DRX073118 DRR079274       NaN        NaN       NaN   NaN

# %%
dfs = []
for _, row in good.iterrows():
    srx = row.to_dict()['srx']
    srr = row.to_dict()['srr']
    fname = f'../aln-wf/output/samples/{srx}/{srr}/{srr}.fq.bam.log'
    dfs.append(parse_hisat2(srx, srr, fname))

hisat2 = pd.concat(dfs)

# %%
first = store['prealn/workflow/collectrnaseqmetrics/first']['PCT_CORRECT_STRAND_READS']
first.name = 'prop_reads_aln_first_strand'

# %%
dat = pd.concat([store['layout'], store['strand'], store['prealn/flags'], store['prealn/workflow/fastq'][['libsize_R1', 'avgLen_R1', 'libsize_R2', 'avgLen_R2']], hisat2.per_alignment, first], axis=1)

# %%
merged = df.join(dat)
merged.head(20)
# Out:
#                             srs        srp  gsm  bioproject     biosample  \
# srx        srr
# DRX012753  DRR014222  DRS012553  DRP001250  NaN   PRJDB2557  SAMD00012584
# DRX012754  DRR014223  DRS012553  DRP001250  NaN   PRJDB2557  SAMD00012584
# DRX012755  DRR014224  DRS012553  DRP001250  NaN   PRJDB2557  SAMD00012584
# DRX073117  DRR079273  DRS039996  DRP003423  NaN   PRJDB5381  SAMD00069299
# DRX073118  DRR079274  DRS039997  DRP003423  NaN   PRJDB5381  SAMD00069300
# DRX073119  DRR079275  DRS039998  DRP003423  NaN   PRJDB5381  SAMD00069301
# DRX073120  DRR079276  DRS039999  DRP003423  NaN   PRJDB5381  SAMD00069302
# DRX073121  DRR079277  DRS040000  DRP003423  NaN   PRJDB5381  SAMD00069303
# DRX073122  DRR079278  DRS040001  DRP003423  NaN   PRJDB5381  SAMD00069304
# DRX073123  DRR079279  DRS040002  DRP003423  NaN   PRJDB5381  SAMD00069305
# DRX073124  DRR079280  DRS040003  DRP003423  NaN   PRJDB5381  SAMD00069306
# DRX073125  DRR079281  DRS039996  DRP003423  NaN   PRJDB5381  SAMD00069299
# DRX073126  DRR079282  DRS039997  DRP003423  NaN   PRJDB5381  SAMD00069300
# DRX073127  DRR079283  DRS039998  DRP003423  NaN   PRJDB5381  SAMD00069301
# DRX073128  DRR079284  DRS039999  DRP003423  NaN   PRJDB5381  SAMD00069302
# DRX073129  DRR079285  DRS040000  DRP003423  NaN   PRJDB5381  SAMD00069303
# DRX073130  DRR079286  DRS040001  DRP003423  NaN   PRJDB5381  SAMD00069304
# DRX073131  DRR079287  DRS040002  DRP003423  NaN   PRJDB5381  SAMD00069305
# DRX073132  DRR079288  DRS040003  DRP003423  NaN   PRJDB5381  SAMD00069306
# ERX1050469 ERR973488  ERS801124  ERP011215  NaN  PRJEB10035  SAMEA3493975
#
#                         pubmed first_name last_name email   layout  \
# srx        srr
# DRX012753  DRR014222  25003736        NaN       NaN   NaN       SE
# DRX012754  DRR014223  25003736        NaN       NaN   NaN  keep_R2
# DRX012755  DRR014224  25003736        NaN       NaN   NaN       SE
# DRX073117  DRR079273       NaN        NaN       NaN   NaN       PE
# DRX073118  DRR079274       NaN        NaN       NaN   NaN       PE
# DRX073119  DRR079275       NaN        NaN       NaN   NaN       PE
# DRX073120  DRR079276       NaN        NaN       NaN   NaN       PE
# DRX073121  DRR079277       NaN        NaN       NaN   NaN       PE
# DRX073122  DRR079278       NaN        NaN       NaN   NaN       PE
# DRX073123  DRR079279       NaN        NaN       NaN   NaN       PE
# DRX073124  DRR079280       NaN        NaN       NaN   NaN       PE
# DRX073125  DRR079281       NaN        NaN       NaN   NaN       PE
# DRX073126  DRR079282       NaN        NaN       NaN   NaN       PE
# DRX073127  DRR079283       NaN        NaN       NaN   NaN       PE
# DRX073128  DRR079284       NaN        NaN       NaN   NaN       PE
# DRX073129  DRR079285       NaN        NaN       NaN   NaN       PE
# DRX073130  DRR079286       NaN        NaN       NaN   NaN       PE
# DRX073131  DRR079287       NaN        NaN       NaN   NaN       PE
# DRX073132  DRR079288       NaN        NaN       NaN   NaN       PE
# ERX1050469 ERR973488       NaN        NaN       NaN   NaN       PE
#
#                                  ...              flag_download_bad  \
# srx        srr                   ...
# DRX012753  DRR014222             ...                          False
# DRX012754  DRR014223             ...                          False
# DRX012755  DRR014224             ...                          False
# DRX073117  DRR079273             ...                          False
# DRX073118  DRR079274             ...                          False
# DRX073119  DRR079275             ...                          False
# DRX073120  DRR079276             ...                          False
# DRX073121  DRR079277             ...                          False
# DRX073122  DRR079278             ...                          False
# DRX073123  DRR079279             ...                          False
# DRX073124  DRR079280             ...                          False
# DRX073125  DRR079281             ...                          False
# DRX073126  DRR079282             ...                          False
# DRX073127  DRR079283             ...                          False
# DRX073128  DRR079284             ...                          False
# DRX073129  DRR079285             ...                          False
# DRX073130  DRR079286             ...                          False
# DRX073131  DRR079287             ...                          False
# DRX073132  DRR079288             ...                          False
# ERX1050469 ERR973488             ...                          False
#
#                       flag_quality_scores_bad  flag_qc_passed  flag_merge  \
# srx        srr
# DRX012753  DRR014222                    False            True        True
# DRX012754  DRR014223                    False            True        True
# DRX012755  DRR014224                    False            True        True
# DRX073117  DRR079273                    False            True        True
# DRX073118  DRR079274                    False            True        True
# DRX073119  DRR079275                    False            True        True
# DRX073120  DRR079276                    False            True        True
# DRX073121  DRR079277                    False            True        True
# DRX073122  DRR079278                    False            True        True
# DRX073123  DRR079279                    False            True        True
# DRX073124  DRR079280                    False            True        True
# DRX073125  DRR079281                    False            True        True
# DRX073126  DRR079282                    False            True        True
# DRX073127  DRR079283                    False            True        True
# DRX073128  DRR079284                    False            True        True
# DRX073129  DRR079285                    False            True        True
# DRX073130  DRR079286                    False            True        True
# DRX073131  DRR079287                    False            True        True
# DRX073132  DRR079288                    False            True        True
# ERX1050469 ERR973488                    False            True        True
#
#                        libsize_R1  avgLen_R1   libsize_R2  avgLen_R2  \
# srx        srr
# DRX012753  DRR014222  164160619.0      101.0          NaN        NaN
# DRX012754  DRR014223  151593644.0        6.0  151593644.0       95.0
# DRX012755  DRR014224  150847202.0      126.0          NaN        NaN
# DRX073117  DRR079273   22884479.0      100.0   22884479.0      100.0
# DRX073118  DRR079274   27009319.0      100.0   27009319.0      100.0
# DRX073119  DRR079275   39188793.0      100.0   39188793.0      100.0
# DRX073120  DRR079276   34601889.0      100.0   34601889.0      100.0
# DRX073121  DRR079277   25450968.0      100.0   25450968.0      100.0
# DRX073122  DRR079278   24563756.0      100.0   24563756.0      100.0
# DRX073123  DRR079279   34575327.0      100.0   34575327.0      100.0
# DRX073124  DRR079280   34529467.0      100.0   34529467.0      100.0
# DRX073125  DRR079281   23717574.0      100.0   23717574.0      100.0
# DRX073126  DRR079282   24718396.0      100.0   24718396.0      100.0
# DRX073127  DRR079283   36165591.0      100.0   36165591.0      100.0
# DRX073128  DRR079284   39282064.0      100.0   39282064.0      100.0
# DRX073129  DRR079285   27061701.0      100.0   27061701.0      100.0
# DRX073130  DRR079286   24930562.0      100.0   24930562.0      100.0
# DRX073131  DRR079287   36426860.0      100.0   36426860.0      100.0
# DRX073132  DRR079288   37268063.0      100.0   37268063.0      100.0
# ERX1050469 ERR973488   10887366.0      100.0   10887366.0      100.0
#
#                       per_alignment  prop_reads_aln_first_strand
# srx        srr
# DRX012753  DRR014222          89.24                     0.997615
# DRX012754  DRR014223          91.91                     0.998734
# DRX012755  DRR014224          93.61                     0.998618
# DRX073117  DRR079273          98.56                     0.005493
# DRX073118  DRR079274          98.51                     0.013322
# DRX073119  DRR079275          98.65                     0.002504
# DRX073120  DRR079276          98.31                     0.003888
# DRX073121  DRR079277          98.28                     0.007763
# DRX073122  DRR079278          98.56                     0.007232
# DRX073123  DRR079279          98.66                     0.004220
# DRX073124  DRR079280          98.62                     0.002711
# DRX073125  DRR079281          98.59                     0.005666
# DRX073126  DRR079282          98.50                     0.005948
# DRX073127  DRR079283          98.67                     0.003719
# DRX073128  DRR079284          98.62                     0.003606
# DRX073129  DRR079285          98.32                     0.009646
# DRX073130  DRR079286          98.55                     0.011669
# DRX073131  DRR079287          98.69                     0.003058
# DRX073132  DRR079288          98.59                     0.003550
# ERX1050469 ERR973488          97.93                     0.003737
#
# [20 rows x 24 columns]
