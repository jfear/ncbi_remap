# %% [markdown]
# # GEO Template Construction

# %%
import os
import sys
from pathlib import Path

from IPython.display import display, HTML, Markdown
import numpy as np
import pandas as pd

from dask import dataframe as dd
from dask import delayed
from dask.distributed import Client

import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# Project level imports
sys.path.insert(0, '../lib')
from ncbi_remap.plotting import make_figs
from ncbi_remap.normalization import cpm

# Connect to data store
store = pd.HDFStore('../sra.h5', mode='r')
samples = store['aln/complete'].srx.unique().tolist()
store.close()

# %%
from pymongo import MongoClient
try:
    with open('../output/.mongodb_host', 'r') as fh:
        host = fh.read().strip()
except FileNotFoundError:
    host = 'localhost'

mongoClient = MongoClient(host=host, port=27017)
db = mongoClient['sra']
ncbi = db['ncbi']

# %%
labels = pd.DataFrame(list(ncbi.aggregate([
    {
        '$match': {
            '_id': {'$in': samples}
        }
    },
    {
        '$project': {
            '_id': 0,
            'srx': '$_id',
            'library_strategy': '$sra.experiment.library_strategy'
        }
    }
    
])))
labels.set_index('srx', inplace=True)
labels.head()
# Out:
#           library_strategy
# srx
# DRX000774            OTHER
# DRX000775            OTHER
# DRX000998              WGS
# DRX000999              WGS
# DRX001000              WGS

# %%
labels.library_strategy.value_counts()
# Out:
# RNA-Seq                   13829
# EST                        4546
# ChIP-Seq                   3003
# OTHER                      2572
# WGS                        1970
# miRNA-Seq                   131
# MNase-Seq                   116
# Targeted-Capture             96
# AMPLICON                     86
# ncRNA-Seq                    69
# RIP-Seq                      58
# FAIRE-seq                    19
# DNase-Hypersensitivity       10
# POOLCLONE                     8
# FL-cDNA                       7
# CLONEEND                      7
# WGA                           6
# MeDIP-Seq                     6
# Bisulfite-Seq                 5
# CLONE                         1
# Name: library_strategy, dtype: int64

# %% [markdown]
# ## Focus on RNA-Seq

# %%
rnaseq = labels.query('library_strategy == "RNA-Seq"').index.tolist()

# %%
len(rnaseq)
# Out:
# 13829

# %%
wide = pd.read_parquet('../aln-wf/output/gene_counts_wide.parquet')

# %%
rnaseq_wide = wide.reindex(columns=rnaseq)

# %%
rnaseq_wide.to_csv('/media/psf/Promise_Pegasus/fearjm/ncbi_remap/geo-wf/justin.fear@nih.gov/gene_counts.tsv', sep='\t')

# %%
def munge_contact(values):
    res = []
    for v in values:
        if v in [np.nan, [], {}, [[]], [{}], [[{}]]]:
            res.append(np.nan)
            continue
            
        contact = v[0][0]
        if contact:
            first = contact.get('first_name', '')
            last = contact.get('last_name', '')
            email = contact.get('email', '')
            res.append(f'{first} {last} <{email}>')
            continue
        print(v)
            
        
    return res

# %%
def munge_authors(values):
    res = []
    for v in values:
        if v in [np.nan, [], {}, [[]], [{}], [[{}]]]:
            res.append(np.nan)
            continue
            
        authors = v[0]
        if authors:
            auts = []
            for author in authors:
                first = author.get('first_name', '')[0]
                last = author.get('last_name', '')
                auts.append(last + first)
            res.append('|'.join(auts))
            continue
        
    return res

# %%
def munge_source(values):
    res = []
    for v in values:
        if v in [np.nan, [], {}, [[]], [{}], [[{}]]]:
            res.append(np.nan)
            continue
            
        attrs = v
        for attr in attrs:
            if attr['name'] == 'source_name':
                res.append(attr['value'])
                break
        else:
            res.append(np.nan)
        
    return res

# %%
def merge_lists(df, columns):
    for col in columns:
        if col == 'contact':
            res = munge_contact(df[col].values)
        elif col == 'pubmed_authors':
            res = munge_authors(df[col].values)
        elif col == 'source name':
            res = munge_source(df[col].values)
        else:
            res = []
            for i in df[col].values:
                if isinstance(i, list):
                    res.append('|'.join(i))
                else:
                    res.append(i)
                
        df[col] = res

    return df

# %%
sample_sheet = pd.DataFrame(list(ncbi.aggregate([
    {
        '$match': {
            '_id': {'$in': rnaseq}
        }
    },
    {
        '$project': {
            '_id': 0,
            'sample_name': '$_id',
            'title': '$sra.sample.title',
            'organism': '$sra.sample.scientific_name',
            'raw file': '$_id',
            'study': '$sra.study.study_id',
            'BioProject': '$sra.study.BioProject',
            'BioSample': '$sra.sample.BioSample',
            'GEO': '$sra.study.GEO',
            'runs': '$sra.run.run_id',
            'pubmed': '$pubmed.pubmed_id',
            'pubmed_title': '$pubmed.title',
            'pubmed_citation': '$pubmed.citation',
            'pubmed_authors': '$pubmed.authors',
            'contact': '$biosample.contacts',
            'molecule': '$sra.experiment.library_selection',
        }
    }
    
])))
sample_sheet.set_index('sample_name', inplace=True)

header = [
    'title', 'organism', 'study', 'runs', 'GEO', 'BioSample', 'BioProject', 
    'pubmed', 'pubmed_title', 'pubmed_citation', 'pubmed_authors', 'contact', 
    'molecule', 'description',
    'raw file',
]

sample_sheet = merge_lists(sample_sheet, ['runs', 'pubmed', 'pubmed_title', 'pubmed_citation', 'contact', 'pubmed_authors'])

keywords = pd.read_parquet('../output/2018-06-26_bow_keywords.parquet')
keywords.columns = ['description']
sample_sheet = sample_sheet.join(keywords, how='left')

sample_sheet = sample_sheet[header].fillna('')
sample_sheet.head()
# Out:
#                                                          title  \
# sample_name
# DRX013093    Penicillium-fungus uninfected 3rd instar larva...
# DRX013094    Penicillium-fungus infected 3rd instar larvae ...
# DRX014765    3rd instar female larvae of Drosophila melanog...
# DRX014766    3rd instar female larvae of Drosophila melanog...
# DRX014767    3rd instar male larvae of Drosophila melanogas...
#
#                             organism      study       runs GEO     BioSample  \
# sample_name
# DRX013093    Drosophila melanogaster  DRP001295  DRR014573      SAMD00010225
# DRX013094    Drosophila melanogaster  DRP001295  DRR014574      SAMD00010224
# DRX014765    Drosophila melanogaster  DRP001802  DRR016398      SAMD00013956
# DRX014766    Drosophila melanogaster  DRP001802  DRR016399      SAMD00013956
# DRX014767    Drosophila melanogaster  DRP001802  DRR016400      SAMD00013950
#
#             BioProject    pubmed  \
# sample_name
# DRX013093    PRJDB2332  24151578
# DRX013094    PRJDB2332  24151578
# DRX014765    PRJDB2720
# DRX014766    PRJDB2720
# DRX014767    PRJDB2720
#
#                                                   pubmed_title  \
# sample_name
# DRX013093    Extensive differences in antifungal immune res...
# DRX013094    Extensive differences in antifungal immune res...
# DRX014765
# DRX014766
# DRX014767
#
#                                 pubmed_citation pubmed_authors contact  \
# sample_name
# DRX013093    2314-436X 2013 Int J Genomics 2013  SetoY|TamuraK
# DRX013094    2314-436X 2013 Int J Genomics 2013  SetoY|TamuraK
# DRX014765
# DRX014766
# DRX014767
#
#             molecule                                        description  \
# sample_name
# DRX013093       cDNA  dextrose|sabouraud|twenty|agar|3rd|uninfected|...
# DRX013094       cDNA  dextrose|sabouraud|twenty|agar|3rd|medium|inst...
# DRX014765     RANDOM                                drs014299|larva|3rd
# DRX014766     RANDOM                                drs014299|larva|3rd
# DRX014767     RANDOM                                drs014300|larva|3rd
#
#               raw file
# sample_name
# DRX013093    DRX013093
# DRX013094    DRX013094
# DRX014765    DRX014765
# DRX014766    DRX014766
# DRX014767    DRX014767

# %%
geo = sample_sheet[['title', 'organism', 'BioSample', 'raw file']].copy()
# Out:
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget.  Restarting
# distributed.nanny - WARNING - Worker process 25029 was killed by unknown signal
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget.  Restarting
# distributed.nanny - WARNING - Worker process 25032 was killed by unknown signal
# distributed.nanny - WARNING - Restarting worker

# %%
bow = pd.read_parquet('../output/2018-06-26_bow_keywords.parquet')
bow.columns = ['source name']

# %%
geo = geo.join(bow)

# %%
geo['molecule'] = 'total RNA'

# %%
md5s = pd.read_csv('/media/psf/Promise_Pegasus/fearjm/ncbi_remap/geo-wf/justin.fear@nih.gov/md5sum.tsv', sep='\t')
md5s['sample_name'] = [x.split('.')[0] for x in md5s['file name'].tolist()]
md5s['sample_type'] = ['.'.join(x.split('.')[1:]) for x in md5s['file name'].tolist()]
md5s = md5s.query('sample_type != ["first.bw", "second.bw"]').copy()
md5s.set_index(['sample_name', 'sample_type'], inplace=True)

# %%
processed = md5s['file name'].unstack()

# %%
processed.columns = [
    'processed data file', 
    'processed data file', 
    'processed data file', 
    'processed data file', 
    'processed data file', 
    'processed data file', 
]

# %%
geo = geo.join(processed)

# %%
cols = [
    'title',
    'source name',
    'organism',
    'molecule', 
    'processed data file',
    'raw file'
]

# %%
geo[cols].to_csv('/media/psf/Promise_Pegasus/fearjm/ncbi_remap/geo-wf/justin.fear@nih.gov/sample_section.tsv', sep='\t')

# %%
md5s.reset_index().set_index('file name')[['file type', 'file checksum']].to_csv('/media/psf/Promise_Pegasus/fearjm/ncbi_remap/geo-wf/justin.fear@nih.gov/processed_data_section.tsv')

# %%
sample_sheet.to_csv('../output/2018-06-28_example_sample_sheet.tsv', sep='\t')

# %%
sample_sheet[sample_sheet.contact.str.contains('Oliver') | sample_sheet.pubmed_authors.str.contains('LeeH')]
# Out:
#                                                          title   source name  \
# sample_name
# SRX1329122                            ED1004_25163_FEMALE_rep1  whole animal
# SRX1329123                            ED1004_25163_FEMALE_rep2  whole animal
# SRX1329124                            ED1004_25163_FEMALE_rep3  whole animal
# SRX1329125                              ED1004_25163_MALE_rep1  whole animal
# SRX1329126                              ED1004_25163_MALE_rep2  whole animal
# SRX1329127                              ED1004_25163_MALE_rep3  whole animal
# SRX1329128                             ED1050_8946_FEMALE_rep1  whole animal
# SRX1329129                             ED1050_8946_FEMALE_rep2  whole animal
# SRX1329130                             ED1050_8946_FEMALE_rep3  whole animal
# SRX1329131                               ED1050_8946_MALE_rep1  whole animal
# SRX1329132                               ED1050_8946_MALE_rep2  whole animal
# SRX1329133                               ED1050_8946_MALE_rep3  whole animal
# SRX1329134                             ED105_24118_FEMALE_rep1  whole animal
# SRX1329135                             ED105_24118_FEMALE_rep2  whole animal
# SRX1329136                             ED105_24118_FEMALE_rep3  whole animal
# SRX1329137                               ED105_24118_MALE_rep1  whole animal
# SRX1329138                               ED105_24118_MALE_rep2  whole animal
# SRX1329139                               ED105_24118_MALE_rep3  whole animal
# SRX1329140                            ED1054_24112_FEMALE_rep1  whole animal
# SRX1329141                            ED1054_24112_FEMALE_rep2  whole animal
# SRX1329142                            ED1054_24112_FEMALE_rep3  whole animal
# SRX1329143                              ED1054_24112_MALE_rep1  whole animal
# SRX1329144                              ED1054_24112_MALE_rep2  whole animal
# SRX1329145                              ED1054_24112_MALE_rep3  whole animal
# SRX1329146                             ED108_24629_FEMALE_rep1  whole animal
# SRX1329147                             ED108_24629_FEMALE_rep2  whole animal
# SRX1329148                             ED108_24629_FEMALE_rep3  whole animal
# SRX1329149                               ED108_24629_MALE_rep1  whole animal
# SRX1329150                               ED108_24629_MALE_rep2  whole animal
# SRX1329151                               ED108_24629_MALE_rep3  whole animal
# ...                                                        ...           ...
# SRX976297                             S3 oleic acid 4hrs rep 1     cell line
# SRX976298                             S3 oleic acid 4hrs rep 2     cell line
# SRX976299                             S3 oleic acid 4hrs rep 3     cell line
# SRX976300                             S3 oleic acid 4hrs rep 4     cell line
# SRX976301                             S3 oleic acid 4hrs rep 5     cell line
# SRX976302                             S3 oleic acid 4hrs rep 6     cell line
# SRX976303                                   S3 DMSO 4hrs rep 1     cell line
# SRX976304                                   S3 DMSO 4hrs rep 2     cell line
# SRX976305                                   S3 DMSO 4hrs rep 3     cell line
# SRX976306                    S3 DMSO and oleic acid 4hrs rep 1     cell line
# SRX976307                    S3 DMSO and oleic acid 4hrs rep 2     cell line
# SRX976308                    S3 DMSO and oleic acid 4hrs rep 3     cell line
# SRX976309    S3 active Chemotype 1 with DMSO and oleic acid...     cell line
# SRX976310    S3 active Chemotype 1 with DMSO and oleic acid...     cell line
# SRX976311    S3 active Chemotype 1 with DMSO and oleic acid...     cell line
# SRX976312    S3 inactive Chemotype 1 with DMSO and oleic ac...     cell line
# SRX976313    S3 inactive Chemotype 1 with DMSO and oleic ac...     cell line
# SRX976314    S3 inactive Chemotype 1 with DMSO and oleic ac...     cell line
# SRX976315    S3 active Chemotype 2 with DMSO and oleic acid...     cell line
# SRX976316    S3 active Chemotype 2 with DMSO and oleic acid...     cell line
# SRX976317    S3 active Chemotype 2 with DMSO and oleic acid...     cell line
# SRX976318    S3 inactive Chemotype 2 with DMSO and oleic ac...     cell line
# SRX976319    S3 inactive Chemotype 2 with DMSO and oleic ac...     cell line
# SRX976320    S3 inactive Chemotype 2 with DMSO and oleic ac...     cell line
# SRX976321    S3 active Chemotype 3 with DMSO and oleic acid...     cell line
# SRX976322    S3 active Chemotype 3 with DMSO and oleic acid...     cell line
# SRX976323    S3 active Chemotype 3 with DMSO and oleic acid...     cell line
# SRX976324    S3 inactive Chemotype 3 with DMSO and oleic ac...     cell line
# SRX976325    S3 inactive Chemotype 3 with DMSO and oleic ac...     cell line
# SRX976326    S3 inactive Chemotype 3 with DMSO and oleic ac...     cell line
#
#                             organism      study        runs       GEO  \
# sample_name
# SRX1329122   Drosophila melanogaster  SRP064744  SRR2627812  GSE73920
# SRX1329123   Drosophila melanogaster  SRP064744  SRR2627813  GSE73920
# SRX1329124   Drosophila melanogaster  SRP064744  SRR2627814  GSE73920
# SRX1329125   Drosophila melanogaster  SRP064744  SRR2627815  GSE73920
# SRX1329126   Drosophila melanogaster  SRP064744  SRR2627816  GSE73920
# SRX1329127   Drosophila melanogaster  SRP064744  SRR2627817  GSE73920
# SRX1329128   Drosophila melanogaster  SRP064744  SRR2627818  GSE73920
# SRX1329129   Drosophila melanogaster  SRP064744  SRR2627819  GSE73920
# SRX1329130   Drosophila melanogaster  SRP064744  SRR2627820  GSE73920
# SRX1329131   Drosophila melanogaster  SRP064744  SRR2627821  GSE73920
# SRX1329132   Drosophila melanogaster  SRP064744  SRR2627822  GSE73920
# SRX1329133   Drosophila melanogaster  SRP064744  SRR2627823  GSE73920
# SRX1329134   Drosophila melanogaster  SRP064744  SRR2627824  GSE73920
# SRX1329135   Drosophila melanogaster  SRP064744  SRR2627825  GSE73920
# SRX1329136   Drosophila melanogaster  SRP064744  SRR2627826  GSE73920
# SRX1329137   Drosophila melanogaster  SRP064744  SRR2627827  GSE73920
# SRX1329138   Drosophila melanogaster  SRP064744  SRR2627828  GSE73920
# SRX1329139   Drosophila melanogaster  SRP064744  SRR2627829  GSE73920
# SRX1329140   Drosophila melanogaster  SRP064744  SRR2627830  GSE73920
# SRX1329141   Drosophila melanogaster  SRP064744  SRR2627831  GSE73920
# SRX1329142   Drosophila melanogaster  SRP064744  SRR2627832  GSE73920
# SRX1329143   Drosophila melanogaster  SRP064744  SRR2627833  GSE73920
# SRX1329144   Drosophila melanogaster  SRP064744  SRR2627834  GSE73920
# SRX1329145   Drosophila melanogaster  SRP064744  SRR2627835  GSE73920
# SRX1329146   Drosophila melanogaster  SRP064744  SRR2627836  GSE73920
# SRX1329147   Drosophila melanogaster  SRP064744  SRR2627837  GSE73920
# SRX1329148   Drosophila melanogaster  SRP064744  SRR2627838  GSE73920
# SRX1329149   Drosophila melanogaster  SRP064744  SRR2627839  GSE73920
# SRX1329150   Drosophila melanogaster  SRP064744  SRR2627840  GSE73920
# SRX1329151   Drosophila melanogaster  SRP064744  SRR2627841  GSE73920
# ...                              ...        ...         ...       ...
# SRX976297    Drosophila melanogaster  SRP056789  SRR1949944  GSE67503
# SRX976298    Drosophila melanogaster  SRP056789  SRR1949945  GSE67503
# SRX976299    Drosophila melanogaster  SRP056789  SRR1949946  GSE67503
# SRX976300    Drosophila melanogaster  SRP056789  SRR1949947  GSE67503
# SRX976301    Drosophila melanogaster  SRP056789  SRR1949948  GSE67503
# SRX1329150                 male|whole|adult|animal  SRX1329150
# SRX1329151                 male|whole|adult|animal  SRX1329151
# ...                                            ...         ...
# SRX976297                  4hrs|s3|oleic|null|acid   SRX976297
# SRX976298                  4hrs|s3|oleic|null|acid   SRX976298
# SRX976299                  4hrs|s3|oleic|null|acid   SRX976299
# SRX976300                  4hrs|s3|oleic|null|acid   SRX976300
# SRX976301                  4hrs|s3|oleic|null|acid   SRX976301
# SRX976302                  4hrs|s3|oleic|null|acid   SRX976302
# SRX976303                        4hrs|s3|dmso|null   SRX976303
# SRX976304                        4hrs|s3|dmso|null   SRX976304
# SRX976305                        4hrs|s3|dmso|null   SRX976305
# SRX976306             4hrs|s3|dmso|oleic|null|acid   SRX976306
# SRX976307             4hrs|s3|dmso|oleic|null|acid   SRX976307
# SRX976308             4hrs|s3|dmso|oleic|null|acid   SRX976308
# SRX976309      4hrs|s3|chemotype|dmso|oleic|active   SRX976309
# SRX976310      4hrs|s3|chemotype|dmso|oleic|active   SRX976310
# SRX976311      4hrs|s3|chemotype|dmso|oleic|active   SRX976311
# SRX976312    4hrs|s3|inactive|chemotype|dmso|oleic   SRX976312
# SRX976313    4hrs|s3|inactive|chemotype|dmso|oleic   SRX976313
# SRX976314    4hrs|s3|inactive|chemotype|dmso|oleic   SRX976314
# SRX976315      4hrs|s3|chemotype|dmso|oleic|active   SRX976315
# SRX976316      4hrs|s3|chemotype|dmso|oleic|active   SRX976316
# SRX976317      4hrs|s3|chemotype|dmso|oleic|active   SRX976317
# SRX976318    4hrs|s3|inactive|chemotype|dmso|oleic   SRX976318
# SRX976319    4hrs|s3|inactive|chemotype|dmso|oleic   SRX976319
# SRX976320    4hrs|s3|inactive|chemotype|dmso|oleic   SRX976320
# SRX976321      4hrs|s3|chemotype|dmso|oleic|active   SRX976321
# SRX976322      4hrs|s3|chemotype|dmso|oleic|active   SRX976322
# SRX976323      4hrs|s3|chemotype|dmso|oleic|active   SRX976323
# SRX976324    4hrs|s3|inactive|chemotype|dmso|oleic   SRX976324
# SRX976325    4hrs|s3|inactive|chemotype|dmso|oleic   SRX976325
# SRX976326    4hrs|s3|inactive|chemotype|dmso|oleic   SRX976326
#
# [4712 rows x 16 columns]

# %%
sample_sheet.groupby().size().sort_values(ascending=False)
# Out:
# contact
# Brian Oliver <briano@helix.nih.gov>                     4705
#                                                         2424
# Peter Chang <peterlchang@gmail.com>                      921
# Peter Combs <peter.combs@berkeley.edu>                   403
# Amanda Crocker <acrocker@middlebury.edu>                 185
# Fiona Ingleby <f.ingleby@sussex.ac.uk>                   179
# Jin Li <jin.billy.li@stanford.edu>                       167
# Wen Qu <er7989@wayne.edu>                                158
# Stein Aerts <Stein.Aerts@med.kuleuven.be>                138
# Sebastian Kadener <skadener@mail.huji.ac.il>             103
# Peter Cherbas <cherbas@indiana.edu>                      102
# Stephan Hutter <hutter@bio.lmu.de>                        99
# Jun Chen <cjnankai@gmail.com>                             96
# Devanjali Dutta <d.dutta@zmbh.uni-heidelberg.de>          95
# Itai Yanai <yanai@technion.ac.il>                         91
# Stefanie Gerstberger <sgerstberg@rockefeller.edu>         90
# Xiao Chen <chxiao@brandeis.edu>                           85
# Joo Hyun Im <joohyun.im@gmail.com>                        82
# Christopher Benner <cbenner@salk.edu>                     72
# Francis Jiggins <fmj1001@cam.ac.uk>                       71
# Andrew Clark <ac347@cornell.edu>                          64
# Alexander Louie <alexlouie@stanford.edu>                  63
# Tamas Schauer <tamas.schauer@med.uni-muenchen.de>         61
# Ken Sugino <suginok@janelia.hhmi.org>                     57
# Laura Musselman <palankl@hotmail.com>                     56
# Dale Dorsett <dorsettd@slu.edu>                           55
# Michael Antosh <Michael_Antosh@brown.edu>                 53
# Carolyn Elya <elyac@berkeley.edu>                         49
# Katharine Abruzzi <katea@brandeis.edu>                    48
# Jean-Yves Roignant <j.roignant@imb-mainz.de>              47
#                                                         ...
# Alfredo Ghezzi <aghezzi@utexas.edu>                        2
# Wen Huang <wen.huang@ncsu.edu>                             2
# Hao Hu <hao.letters@gmail.com>                             2
# Yirong Wang <cherrywang10@gmail.com>                       2
# Ravinder Singh <rsingh@colorado.edu>                       2
# Wei Gu <weigu@snnu.edu.cn>                                 2
# Daniel Enderle <daniel.enderle@bsse.ethz.ch>               2
# Qiaoping Wang <qiaoping.wang@sydney.edu.au>                2
# Ilka Reichardt-Gomez <ilka.reichardt@gmi.oeaw.ac.at>       2
# Xiangfeng Jing <xj43@cornell.edu>                          2
# Jahnavi Suresh <jahnavi.suresh@gmail.com>                  2
# Fabiana Duarte <fdd7@cornell.edu>                          2
# Nick Kamps-Hughes <nkamps@molbio.uoregon.edu>              2
# Matthias Schaefer <m.schaefer@dkfz.de>                     1
# Jiannan Lin <9linj14@tongji.edu.cn>                        1
# Lin Sun <sunlin@missouri.edu>                              1
# Punita Juneja <pjuneja@gmail.com>                          1
# Phineas Hamilton <phin.hamilton@gmail.com>                 1
# Samuel Lewis <sam.lewis@gen.cam.ac.uk>                     1
# Mia Levine <mlevine@fhcrc.org>                             1
# Alexandra Franz <afranz88@googlemail.com>                  1
# Asifa Akhtar <akhtarlab_data@ie-freiburg.mpg.de>           1
# Mei-Ju Chen <arbula@gmail.com>                             1
# Guillaume Filion <guillaume.filion@gmail.com>              1
# Mia Levine <miatauna@gmail.com>                            1
# Katarina Pankova <pankova@neuro.mpg.de>                    1
# Dustin Schones <dschones@coh.org>                          1
# Siming Ma <siming4819@googlemail.com>                      1
# Andrew Adrian <Andrew-Adrian@uiowa.edu>                    1
# Tarik Hadzic <tarik.hadzic@gmail.com>                      1
# Length: 312, dtype: int64

# %% [markdown]
# ## Tech Flags

# %%
layout = store['layout'].to_frame().reset_index().groupby('srx').layout.first().to_frame()

# %%
strand = store['strand'].reset_index().groupby('srx').strand.first().to_frame()

# %%
tech_flags = pd.concat([layout, strand], axis=1, sort=True)
tech_flags.index.name = 'srx'

# %% [markdown]
# ## Prealn flags

# %%
abi = store['prealn/abi_solid']
abi = store['prealn/abi_solid'].groupby('srx').srr.apply(lambda x: '|'.join(x))
abi.name = 'abi_solid'
abi = abi.to_frame()

# %%
download = store['prealn/download_bad'].groupby('srx').srr.apply(lambda x: '|'.join(x))
download.name = 'download_problems'
download = download.to_frame()

# %%
alignment = store['prealn/alignment_bad'].groupby('srx').srr.apply(lambda x: '|'.join(x))
alignment.name = 'alignment_problems'
alignment = alignment.to_frame()

# %%
quality_score = store['prealn/quality_scores_bad'].groupby('srx').srr.apply(lambda x: '|'.join(x))
quality_score.name = 'quality_score_problems'
quality_score = quality_score.to_frame()

# %%
prealn_flags = pd.concat([abi, download, alignment, quality_score], axis=1, sort=True)
prealn_flags.index.name = 'srx'

# %% [markdown]
# ## Prealn Metrics

# %%
same_strand = tech_flags.query('strand == "same_strand"').index.tolist()
opposite_strand = tech_flags.query('strand == "opposite_strand"').index.tolist()
df_same_strand = store['prealn/workflow/collectrnaseqmetrics/first']['PCT_CORRECT_STRAND_READS'].loc[same_strand].groupby('srx').mean().to_frame()
df_opposite_strand = store['prealn/workflow/collectrnaseqmetrics/second']['PCT_CORRECT_STRAND_READS'].loc[opposite_strand].groupby('srx').mean().to_frame()

# %%
prop_correct = pd.concat([df_same_strand, df_opposite_strand])
prop_correct.columns = ['prop_reads_correct_strand']

# %%
pd.concat([store['prealn/workflow/collectrnaseqmetrics/unstranded']['MEDIAN_CV_COVERAGE'].groupby('srx').median(),
           store['prealn/workflow/collectrnaseqmetrics/unstranded']['MEDIAN_3PRIME_BIAS'].groupby('srx').median(),
           store['prealn/workflow/collectrnaseqmetrics/unstranded']['MEDIAN_5PRIME_BIAS'].groupby('srx').median(),
           prop_correct,
          ], axis=1, sort=True)
# Out:
#            MEDIAN_CV_COVERAGE  MEDIAN_3PRIME_BIAS  MEDIAN_5PRIME_BIAS  \
# DRX000774            3.555362            0.377767            0.000000
# DRX000775            3.709965            0.187335            0.027636
# DRX000998            0.322389            0.707143            0.914538
# DRX000999            0.599668            0.977702            0.961241
# DRX001000            0.304633            0.992605            0.999818
# DRX001001            0.388005            1.014340            1.006289
# DRX012753            2.010122            0.421529            4.258460
# DRX012754            2.547789            0.019605            5.997537
# DRX012755            1.728321            0.434926            3.203696
# DRX013093            0.798182            0.140887            0.292469
# DRX013094            0.780190            0.200367            0.278511
# DRX014765            0.486708            0.658414            0.461210
# DRX014766            0.472969            0.665778            0.433452
# DRX014767            0.486677            0.445746            0.348734
# DRX014768            0.561446            0.666142            0.460192
# DRX014769            0.506213            0.543450            0.202196
# DRX014770            0.498480            0.481313            0.265327
# DRX014771            0.471538            0.466206            0.255928
# DRX014772            0.500533            0.467963            0.247979
# DRX014773            0.490671            0.746142            0.345645
# DRX014774            0.504514            0.463226            0.332720
# DRX014775            0.547153            0.861592            0.338110
# DRX014776            0.598114            0.921988            0.274416
# DRX014777            0.464501            0.583572            0.483240
# DRX014778            0.509584            0.437146            0.487384
# DRX014779            0.487301            0.536396            0.459099
# DRX014780            0.510298            0.465823            0.477276
# DRX014781            0.551631            0.550947            0.188296
# DRX014782            0.511088            0.572749            0.229056
# DRX014783            0.532710            0.572308            0.223429
# ...                       ...                 ...                 ...
# SRX986400            0.879598            0.530289            0.108163
# SRX986401            1.011417            0.904900            0.073125
# SRX986402            0.838449            0.488518            0.125159
# SRX986403            0.931886            0.456615            0.097371
# SRX986404            0.880669            0.519051            0.100448
# SRX986405            0.867292            0.534097            0.103858
# SRX986406            1.042819            1.024418            0.061088
# SRX986407            0.863688            0.652010            0.121163
# SRX986408            1.077968            0.764299            0.056036
# SRX986409            1.109670            0.719234            0.034274
# SRX986410            1.038115            0.775196            0.063398
# SRX986411            1.057673            0.826260            0.048430
# SRX986412            1.226252            0.945800            0.032333
# SRX986413            1.000724            0.575562            0.069921
# SRX986414            1.037718            0.526734            0.062542
# SRX986415            1.100914            0.882894            0.042559
# SRX986416            1.094841            0.880357            0.044424
# SRX986417            1.185108            1.243575            0.035054
# SRX986418            1.103638            1.098091            0.041911
# SRX986553            0.170654            1.024321            0.965146
# SRX986554            0.177614            1.035329            0.982971
# SRX986555            0.199224            1.046994            0.973925
# SRX986556            0.180920            1.005401            0.980970
# SRX992688            0.323759            0.648707            0.734786
# SRX992689            0.354187            0.669390            0.800504
# SRX992690            0.384758            0.547072            0.758459
# SRX998011            1.117525            1.199185            0.579033
# SRX998315            0.972491            0.985761            0.585357
# SRX998316            1.298266            1.186539            0.443359
# SRX998317            0.881973            0.769376            0.517661
#
#            prop_reads_correct_strand
# DRX000774                   0.500596
# DRX000775                   0.503179
# DRX000998                        NaN
# DRX000999                        NaN
# DRX001000                        NaN
# DRX001001                        NaN
# DRX012753                   0.997615
# DRX012754                   0.998734
# DRX012755                   0.998618
# DRX013093                        NaN
# DRX013094                        NaN
# DRX014765                        NaN
# DRX014766                        NaN
# DRX014767                        NaN
# DRX014768                        NaN
# DRX014769                        NaN
# DRX014770                        NaN
# DRX014771                        NaN
# DRX014772                        NaN
# DRX014773                        NaN
# DRX014774                        NaN
# DRX014775                        NaN
# DRX014776                        NaN
# DRX014777                        NaN
# DRX014778                        NaN
# DRX014779                        NaN
# DRX014780                        NaN
# DRX014781                        NaN
# DRX014782                        NaN
# DRX014783                        NaN
# ...                              ...
# SRX986400                        NaN
# SRX986401                        NaN
# SRX986402                        NaN
# SRX986403                        NaN
# SRX986404                        NaN
# SRX986405                        NaN
# SRX986406                        NaN
# SRX986407                        NaN
# SRX986408                        NaN
# SRX986409                        NaN
# SRX986410                        NaN
# SRX986411                        NaN
# SRX986412                        NaN
# SRX986413                        NaN
# SRX986414                        NaN
# SRX986415                        NaN
# SRX986416                        NaN
# SRX986417                        NaN
# SRX986418                        NaN
# SRX986553                        NaN
# SRX986554                        NaN
# SRX986555                        NaN
# SRX986556                        NaN
# SRX992688                        NaN
# SRX992689                        NaN
# SRX992690                        NaN
# SRX998011                        NaN
# SRX998315                        NaN
# SRX998316                        NaN
# SRX998317                        NaN
#
# [26608 rows x 4 columns]

# %%
store['prealn/workflow/collectrnaseqmetrics/unstranded'].columns
# Out:
# Index(['PF_BASES', 'PF_ALIGNED_BASES', 'RIBOSOMAL_BASES', 'CODING_BASES',
#        'UTR_BASES', 'INTRONIC_BASES', 'INTERGENIC_BASES', 'IGNORED_READS',
#        'CORRECT_STRAND_READS', 'INCORRECT_STRAND_READS',
#        'NUM_R1_TRANSCRIPT_STRAND_READS', 'NUM_R2_TRANSCRIPT_STRAND_READS',
#        'NUM_UNEXPLAINED_READS', 'PCT_R1_TRANSCRIPT_STRAND_READS',
#        'PCT_R2_TRANSCRIPT_STRAND_READS', 'PCT_RIBOSOMAL_BASES',
#        'PCT_CODING_BASES', 'PCT_UTR_BASES', 'PCT_INTRONIC_BASES',
#        'PCT_INTERGENIC_BASES', 'PCT_MRNA_BASES', 'PCT_USABLE_BASES',
#        'PCT_CORRECT_STRAND_READS', 'MEDIAN_CV_COVERAGE', 'MEDIAN_5PRIME_BIAS',
#        'MEDIAN_3PRIME_BIAS', 'MEDIAN_5PRIME_TO_3PRIME_BIAS', 'SAMPLE',
#        'LIBRARY', 'READ_GROUP'],
#       dtype='object')

# %%
store.root.prealn.workflow.fastq
# Out:
# /prealn/workflow/fastq (Group) ''
#   children := ['table' (Table)]

# %%
store['prealn/workflow/fastq']
# Out:
#                                                  md5_R1  libsize_R1  \
# srx        srr
# SRX2255268 SRR4436103  99b2dc0b6fae0d9b2e852125c8a732cf  28323003.0
# SRX2255267 SRR4436102  96915306e0241d97986a4f175339c474  25391086.0
# SRX2255266 SRR4436101  b910b4f2e62ac1859d36fd63e415271d  30323489.0
# SRX2255265 SRR4436100  60b3c2cf354b3c57b5c5223cfa17b49a  31947756.0
# SRX2255264 SRR4436099  8cd9d6ccb0a88041e1b3083c0c0bbea6  28410556.0
# SRX2255263 SRR4436098  82a9470a17fb2ebf16ec753a42ec456c  28983795.0
# SRX2255262 SRR4436097  de00406cf644c964d66eeebad63c548e  26405309.0
# SRX2255261 SRR4436096  6e9f4db67b1bdd12b467087690443963  24325089.0
# SRX2255260 SRR4436095  2c8a2f11179df2c0bfecbcfc8267e836  41441486.0
# SRX2255259 SRR4436094  cdcff6ecda60c07a186de2afc94c2a52  36181325.0
# SRX2255258 SRR4436093  d7c84c384d28466646ca5f8f19845755  38570048.0
# SRX2255257 SRR4436092  d0df7a5c02e17625cdf89de0a0bba7ea  37941227.0
# SRX2255256 SRR4436091  43a9855122d511490fdec89c006f9faa  32816976.0
# SRX2255255 SRR4436090  5dd1b1d311cb7da4c9e5e156e23ce287  31127481.0
# SRX2250461 SRR4428936  189f3bbb509e76e998f83cfe35197100   7190308.0
# SRX2250459 SRR4428934  e40e03ca5b3d1c80d7c50b79a461ceba   7178308.0
# SRX2250458 SRR4428933  25f121571d880fa232f600ce91cae39c   7392797.0
# SRX2250457 SRR4428932  34f95e5670b39ebefe98a9d30b0c944f   7558040.0
# SRX2250384 SRR4428860  74c3789abe60b8d5f091eefa1116287b  11402856.0
# SRX2250383 SRR4428859  3deddaa9a32fb19a47e1e45d5b279882  12183357.0
# SRX2250381 SRR4428858  d4a66994f78a0bdf4d4a19050e814bf1  12618560.0
# SRX2250459 SRR4428934   7178308.0    0.000000
# SRX2250458 SRR4428933   7392797.0    0.000000
# SRX2250457 SRR4428932   7558040.0    0.000000
# SRX2250384 SRR4428860  11402856.0  175.770702
# SRX2250383 SRR4428859  12183357.0  164.353755
# SRX2250381 SRR4428858  12618560.0  177.623272
# SRX2250380 SRR4428857  11770006.0  187.491361
# SRX2250379 SRR4428856  12221121.0  177.535310
# SRX2250378 SRR4428855  12280975.0  177.568734
# SRX2250377 SRR4428854  11360528.0  178.103600
# SRX2250376 SRR4428853  11239172.0  173.806406
# SRX2250375 SRR4428852  14185519.0  189.142359
# SRX2250374 SRR4428851  10464847.0  180.048458
# SRX2243443 SRR4421119         NaN         NaN
# SRX2243442 SRR4421118         NaN         NaN
# ...                           ...         ...
# SRX2256365 SRR4437557      8124.0    0.000000
# SRX2256364 SRR4437556      9555.0    0.000000
# SRX2256363 SRR4437555      7913.0    0.000000
# SRX2256362 SRR4437554      5193.0    0.000000
# SRX2256361 SRR4437553      2795.0    0.000000
# SRX2256360 SRR4437552      8707.0    0.000000
# SRX2256359 SRR4437551      7797.0    0.000000
# SRX2256358 SRR4437550      8172.0    0.000000
# SRX2256357 SRR4437549     10365.0    0.000000
# SRX2256356 SRR4437548      8254.0    0.000000
# SRX2256355 SRR4437547      4522.0    0.000000
# SRX2256354 SRR4437546      9431.0    0.000000
# SRX2256353 SRR4437545      7387.0    0.000000
# SRX2256352 SRR4437544      4928.0    0.000000
# SRX2256351 SRR4437543      1900.0    0.000000
# SRX2256350 SRR4437542      6753.0    0.000000
# SRX2256349 SRR4437541      6169.0    0.000000
# SRX2256348 SRR4437540      8073.0    0.000000
# SRX2256347 SRR4437539      8889.0    0.000000
# SRX2256346 SRR4437538      3998.0    0.000000
# SRX2256345 SRR4437537      5381.0    0.000000
# SRX2256344 SRR4437536      5453.0    0.000000
# SRX2256343 SRR4437535      5624.0    0.000000
# SRX2256342 SRR4437534      4715.0    0.000000
# SRX2256341 SRR4437533      8198.0    0.000000
# SRX2256340 SRR4437532      8051.0    0.000000
# SRX2256338 SRR4437530      5536.0    0.000000
# SRX2256337 SRR4437529      4441.0    0.000000
# SRX2256336 SRR4437528      3580.0    0.000000
# SRX2256335 SRR4437527      1084.0    0.000000
#
# [33635 rows x 6 columns]

# %%
_sheet = pd.DataFrame(list(ncbi.aggregate([
    {
        '$match': {
            '_id': {'$exists': 'sra.study.GEO'}
        }
    },
    {
        '$project': {
            '_id': 0,
            'srx': '$_id',
            'GEO': '$sra.study.GEO',
        }
    }
    
])))

# %%
_sheet = _sheet.set_index('srx').dropna()

# %%
labels.join(_sheet, how='inner').library_strategy.value_counts()
# Out:
# RNA-Seq                   10314
# ChIP-Seq                   2504
# OTHER                      1096
# MNase-Seq                   108
# ncRNA-Seq                    69
# RIP-Seq                      52
# EST                          27
# FAIRE-seq                    19
# miRNA-Seq                    13
# DNase-Hypersensitivity       10
# WGS                          10
# CLONEEND                      7
# MeDIP-Seq                     3
# Bisulfite-Seq                 2
# Name: library_strategy, dtype: int64
