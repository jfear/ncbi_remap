# %% [markdown]
# # Build Example Metadata Table

# %%
import os
import sys
from pathlib import Path

from IPython.display import display, HTML, Markdown
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Project level imports
sys.path.insert(0, '../lib')
from ncbi_remap.notebook import Nb
from ncbi_remap.plotting import make_figs

# Setup notebook
nbconfig = Nb.setup_notebook()

# Connect to data store
store = pd.HDFStore('../sra_new.h5', mode='r')
# Out:
# Please check output/fbgn2chrom.tsv. If it does not exist, run bin/fbgn2chrom.py
# last updated: 2018-02-23
# Git hash: f4aaace3e5b64fd8cddf3bc02a6b2c7d196089d7

# %%
from pymongo import MongoClient
try:
    with open('../output/.mongodb_host', 'r') as fh:
        host = fh.read().strip()
except FileNotFoundError:
    host = 'localhost'

mongoClient = MongoClient(host=host, port=27022)
db = mongoClient['sramongo']
ncbi = db['ncbi']

# %%
# get list of complete

srxs = store['prealn/complete'].srx.unique().tolist()

# %%
col_mapper = {
    'tissue': [
        'OrganismPart',
        'midgut part',
        'midgut region',
        'tissue',
        'tissue age',
        'tissue source',
        'tissue subtype',
        'tissue type',
        'tissue-type',
        'tissue/cell type',
        'tissue/development stage',
        'tissue_type',
        
    ],
    'dev_stage': [
        'DevelopmentalStage',
        'Stage',
        'dev-stage',
        'dev_stage',
        'developemntal stage',
        'development point',
        'development stage',
        'developmental stage',
        'developmental time point',
        'embryonic stage',
        'stage',
        
    ],
    'sex': [
        'Sex',
        'gender',
        'gender type',
        'gender/age',
        'sex',
        'sex type',
        'sex/age',
        
    ],
    'cell_type': [
        'CellLine',
        'CellType',
        'cell line', 
        'cell line background',
        'cell line source',
        'cell type',
        'cell-type',
        'cell_line',
        'cell_type',
        'celll line',
        'cells derived from',
        
        
    ]
}

col_mapper_rev = {}
for k, values in col_mapper.items():
    for value in values:
        col_mapper_rev[value] = k

# %%
res = list(ncbi.aggregate([
    {
        '$match': {
            '_id': {'$in': srxs}
        }
    },
    {
        '$project': {
            '_id': 0,
            'SRX': '$srx',
            'SRR': '$runs.srr',
            'SRP': "$sra.experiment.study_id",
            'BioProject': '$bioproject.bioproject_accn',
            'BioSample': '$biosample.biosample_accn',
            'GEO': "$biosample.GEO",
            'Pubmed': '$pubmed.pubmed_id',
            'title': '$pubmed.title',

            'library_strategy': '$sra.experiment.library_strategy',
            'attributes': '$biosample.attributes',
            'attributes2': '$sra.sample.attributes',
        }
    },
]))

def flatten(x, key):
    try:
        if x[key] == np.nan:
            x[key] = ''
        
        elif isinstance(x[key], str):
            return
            
        elif x[key] == []:
             x[key] = ''
                
        elif len(x[key]) == 1:
             x[key] = x[key][0]
                
    except KeyError:
        x[key] = ''

def map_attrs(x):
    defaults = {
        'tissue': '',
        'dev_stage': '',
        'sex': '',
        'cell_type': '',
    }
    
    try:
        for _attr in x['attributes'][0]:
            name = _attr['name']
            value = _attr['value']
            normName = col_mapper_rev.get(name, name)
            if normName in defaults.keys():
                defaults[normName] = value
    except KeyError:
        pass
            
    try:
        for _attr in x['attributes2']:
            name = _attr['name']
            value = _attr['value']
            normName = col_mapper_rev.get(name, name)
            if normName in defaults.keys():
                defaults[normName] = value
    except KeyError:
        pass

    x.update(defaults)
    
    
for _res in res:
    flatten(_res, 'GEO')
    flatten(_res, 'BioSample')
    flatten(_res, 'Pubmed')
    flatten(_res, 'title')
    map_attrs(_res)

# %%
df = pd.DataFrame(res).drop(['attributes', 'attributes2'], axis=1)

# %%
df[df.cell_type.str.contains('S2')]
# Out:
#         BioProject     BioSample         GEO    Pubmed        SRP  \
# 220      PRJEB2754  SAMEA1464075                        ERP001006
# 264      PRJEB3031  SAMEA1487331                        ERP001439
# 265      PRJEB3031  SAMEA1487332                        ERP001439
# 267      PRJEB3031  SAMEA1487319                        ERP001439
# 279      PRJEB3031  SAMEA1487330                        ERP001439
# 430     PRJEB13075  SAMEA3903388                        ERP014611
# 431     PRJEB13075  SAMEA3903389                        ERP014611
# 432     PRJEB13075  SAMEA3903390                        ERP014611
# 433     PRJEB13075  SAMEA3903391                        ERP014611
# 1102      PRJEB670  SAMEA1573979                        ERP001982
# 1103      PRJEB670  SAMEA1573966                        ERP001982
# 1104      PRJEB670  SAMEA1573947                        ERP001982
# 1105      PRJEB670  SAMEA1573913                        ERP001982
# 1106      PRJEB670  SAMEA1573887                        ERP001982
# 1107      PRJEB670  SAMEA1573863                        ERP001982
# 1108      PRJEB670  SAMEA1573883                        ERP001982
# 1109      PRJEB670  SAMEA1574018                        ERP001982
# 1110      PRJEB670  SAMEA1573999                        ERP001982
# 1111      PRJEB670  SAMEA1573901                        ERP001982
# 1112      PRJEB670  SAMEA1573885                        ERP001982
# 1113      PRJEB670  SAMEA1573867                        ERP001982
# 1114      PRJEB670  SAMEA1573941                        ERP001982
# 1115      PRJEB670  SAMEA1573914                        ERP001982
# 1116      PRJEB670  SAMEA1573973                        ERP001982
# 1117      PRJEB670  SAMEA1573954                        ERP001982
# 1118      PRJEB670  SAMEA1574004                        ERP001982
# 1119      PRJEB670  SAMEA1573886                        ERP001982
# 1120      PRJEB670  SAMEA1573889                        ERP001982
# 1121      PRJEB670  SAMEA1573910                        ERP001982
# 1122      PRJEB670  SAMEA1573937                        ERP001982
# ...            ...           ...         ...       ...        ...
# 18887  PRJNA275858  SAMN03354198  GSM1614138  26816380  SRP055172
# 18904  PRJNA276109  SAMN03366546  GSM1617057  26894919  SRP055433
# 18905  PRJNA276109  SAMN03366545  GSM1617058  26894919  SRP055433
# 18906  PRJNA276109  SAMN03366544  GSM1617059  26894919  SRP055433
# 19002  PRJNA276670  SAMN03379586  GSM1621071            SRP055572
# 19003  PRJNA276670  SAMN03379592  GSM1621072            SRP055572
# 19004  PRJNA276670  SAMN03379591  GSM1621073            SRP055572
# 19005  PRJNA276670  SAMN03379587  GSM1621074            SRP055572
# 19006  PRJNA276670  SAMN03379589  GSM1621075            SRP055572
# 19007  PRJNA276670  SAMN03379588  GSM1621076            SRP055572
# 19008  PRJNA276670  SAMN03379585  GSM1621077            SRP055572
# 19009  PRJNA276670  SAMN03379590  GSM1621078            SRP055572
# 19010  PRJNA276670  SAMN03379595  GSM1621079            SRP055572
# 19011  PRJNA276670  SAMN03379599  GSM1621080            SRP055572
# 19012  PRJNA276670  SAMN03379596  GSM1621081            SRP055572
# 19013  PRJNA276670  SAMN03379598  GSM1621082            SRP055572
# 19014  PRJNA276670  SAMN03379597  GSM1621083            SRP055572
# 19015  PRJNA276670  SAMN03379593  GSM1621084            SRP055572
# 19016  PRJNA276670  SAMN03379594  GSM1621085            SRP055572
# 19017  PRJNA276670  SAMN03379600  GSM1621086            SRP055572
# 19018  PRJNA277529  SAMN03393377  GSM1626770  26389589  SRP055933
# 19019  PRJNA277529  SAMN03393375  GSM1626771  26389589  SRP055933
# 19020  PRJNA277529  SAMN03393376  GSM1626772  26389589  SRP055933
# 19021  PRJNA277529  SAMN03393374  GSM1626773  26389589  SRP055933
# 19400  PRJNA279984  SAMN03453193  GSM1647362  26079792  SRP056749
# 19554  PRJNA280592  SAMN03465362                        SRP056965
# 19555  PRJNA280592  SAMN03465363                        SRP056965
# 19556  PRJNA280592  SAMN03465364                        SRP056965
# 19557  PRJNA280592  SAMN03465369                        SRP056965
# 19558  PRJNA280592  SAMN03465371                        SRP056965
#
#                 SRR         SRX            cell_type dev_stage  \
# 220     [ERR055260]   ERX032305                   S2
# 264     [ERR126230]   ERX102366                   S2
# 265     [ERR126231]   ERX102367                   S2
# 267     [ERR126232]   ERX102369                   S2
# 279     [ERR126229]   ERX102381                   S2
# 430    [ERR1331728]  ERX1403348                   S2
# 431    [ERR1331729]  ERX1403349                   S2
# 432    [ERR1331730]  ERX1403350                   S2
# 433    [ERR1331731]  ERX1403351                   S2
# 1102    [ERR198935]   ERX173561                   S2
# 1103    [ERR198976]   ERX173562                   S2
# 1104    [ERR198863]   ERX173563                   S2
# 1105    [ERR198926]   ERX173564                   S2
# 1106    [ERR198870]   ERX173565                   S2
# 1107    [ERR198864]   ERX173566                   S2
# 1108    [ERR199004]   ERX173567                   S2
# 1109    [ERR198981]   ERX173568                   S2
# 1110    [ERR198905]   ERX173569                   S2
# 1111    [ERR198908]   ERX173570                   S2
# 1112    [ERR198865]   ERX173571                   S2
# 1113    [ERR198971]   ERX173572                   S2
# 1114    [ERR198932]   ERX173573                   S2
# 1115    [ERR199000]   ERX173574                   S2
# 1116    [ERR198868]   ERX173575                   S2
# 1117    [ERR198875]   ERX173576                   S2
# 1118    [ERR198928]   ERX173577                   S2
# 1119    [ERR198982]   ERX173578                   S2
# 1120    [ERR198913]   ERX173579                   S2
# 1121    [ERR199008]   ERX173580                   S2
# 1122    [ERR198923]   ERX173581                   S2
# ...             ...         ...                  ...       ...
# 18887  [SRR1810947]   SRX883605                   S2
# 18904  [SRR1813779]   SRX886165                   S2
# 18905  [SRR1813780]   SRX886166                   S2
# 18906  [SRR1813781]   SRX886167                   S2
# 19002  [SRR1821767]   SRX893368                   S2
# 19003  [SRR1821768]   SRX893369                   S2
# 19004  [SRR1821769]   SRX893370                   S2
# 19005  [SRR1821770]   SRX893371                   S2
# 19006  [SRR1821771]   SRX893372                   S2
# 19007  [SRR1821772]   SRX893373                   S2
# 19008  [SRR1821773]   SRX893374                   S2
# 19009  [SRR1821774]   SRX893375                   S2
# 19010  [SRR1821775]   SRX893376                   S2
# 19011  [SRR1821776]   SRX893377                   S2
# 19012  [SRR1821777]   SRX893378                   S2
# 19013  [SRR1821778]   SRX893379                   S2
# 19014  [SRR1821779]   SRX893380                   S2
# 19015  [SRR1821780]   SRX893381                   S2
# 19016  [SRR1821781]   SRX893382                   S2
# 19017  [SRR1821782]   SRX893383                   S2
# 19018  [SRR1853006]   SRX907134                   S2
# 19019  [SRR1853007]   SRX907135                   S2
# 19020  [SRR1853008]   SRX907136                   S2
# 19021  [SRR1853009]   SRX907137                   S2
# 19400  [SRR1947849]   SRX974394  Drosophila S2 cells
# 19554  [SRR1957059]   SRX982548                   S2    embryo
# 19555  [SRR1957063]   SRX982550                   S2    embryo
# 19556  [SRR1957065]   SRX982551                   S2    embryo
# 19557  [SRR1957068]   SRX982552                   S2    embryo
# 19558  [SRR1957070]   SRX982553                   S2    embryo
#
#       library_strategy     sex     tissue  \
# 220           ChIP-Seq
# 264           ChIP-Seq
# 265           ChIP-Seq
# 267           ChIP-Seq
# 279           ChIP-Seq
# 430           ChIP-Seq
# 431           ChIP-Seq
# 432           ChIP-Seq
# 433           ChIP-Seq
# 1102           RNA-Seq
# 1103           RNA-Seq
# 1104           RNA-Seq
# 1105           RNA-Seq
# 1106           RNA-Seq
# 1107           RNA-Seq
# 1108           RNA-Seq
# 1109           RNA-Seq
# 1110           RNA-Seq
# 1111           RNA-Seq
# 1112           RNA-Seq
# 1113           RNA-Seq
# 1114           RNA-Seq
# 1115           RNA-Seq
# 1116           RNA-Seq
# 1117           RNA-Seq
# 1118           RNA-Seq
# 1119           RNA-Seq
# 1120           RNA-Seq
# 1121           RNA-Seq
# 1122           RNA-Seq
# ...                ...     ...        ...
# 18887         ChIP-Seq
# 18904         ChIP-Seq
# 18905         ChIP-Seq
# 18906         ChIP-Seq
# 19002        MNase-Seq
# 19003        MNase-Seq
# 19004        MNase-Seq
# 19005        MNase-Seq
# 19006        MNase-Seq
# 19007        MNase-Seq
# 19008        MNase-Seq
# 19009        MNase-Seq
# 19010        MNase-Seq
# 19011        MNase-Seq
# 19012        MNase-Seq
# 19013        MNase-Seq
# 19014        MNase-Seq
# 19015        MNase-Seq
# 19016        MNase-Seq
# 19017        MNase-Seq
# 19018         ChIP-Seq
# 19019         ChIP-Seq
# 19020         ChIP-Seq
# 19021         ChIP-Seq
# 19400         ChIP-Seq
# 19554          RNA-Seq  female  cell line
# 19555          RNA-Seq  female  cell line
# 19556          RNA-Seq  female  cell line
# 19557          RNA-Seq  female  cell line
# 19558          RNA-Seq  female  cell line
#
#                                                    title
# 220
# 264
# 265
# 267
# 279
# 430
# 431
# 432
# 433
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# ...                                                  ...
# 18887  RNA biochemistry. Transcriptome-wide distribut...
# 18904  Widespread colocalization of the Drosophila hi...
# 18905  Widespread colocalization of the Drosophila hi...
# 18906  Widespread colocalization of the Drosophila hi...
# 19002
# 19003
# 19004
# 19005
# 19006
# 19007
# 19008
# 19009
# 19010
# 19011
# 19012
# 19013
# 19014
# 19015
# 19016
# 19017
# 19018  An Interaction between RRP6 and SU(VAR)3-9 Tar...
# 19019  An Interaction between RRP6 and SU(VAR)3-9 Tar...
# 19020  An Interaction between RRP6 and SU(VAR)3-9 Tar...
# 19021  An Interaction between RRP6 and SU(VAR)3-9 Tar...
# 19400  A simple method for generating high-resolution...
# 19554
# 19555
# 19556
# 19557
# 19558
#
# [3227 rows x 13 columns]

# %%
names = []
for _res in res:
    try:
        for _attr in _res['attributes'][0]:
            names.append(_attr['name'])
    except KeyError:
        pass
        
    try:
        for _attr in _res['attributes2']:
            names.append(_attr['name'])
    except KeyError:
        pass

# %%
def get_vals(names):
    vals = []
    for _res in res:
        try:
            for _attr in _res['attributes'][0]:
                if _attr['name'] in names:
                    vals.append(_attr['value'])
        except KeyError:
            pass

        try:
            for _attr in _res['attributes2']:
                if _attr['name'] in names:
                    vals.append(_attr['value'])
        except KeyError:
            pass
    return set(vals)

# %%
dev = get_vals(col_mapper['tissue'])

# %%
dev
# Out:
# {'0-16h embryos',
#  '0.5-2.5hr embryo',
#  '12 hours larva',
#  '24hr embryo',
#  '3rd instar larvae',
#  '3rd instar larvae wing discs',
#  '4C_Growth_Protocol',
#  'Accessory Gland',
#  'Adult abdominal fatbody with associated abdominal cuticle, oenocytes and cuticular muscles',
#  'Adult female ovary, no treatment, no GAL4 activation',
#  'Adult fly heads',
#  'Adult ovaries',
#  'AdultFemale',
#  'AdultMale',
#  'BRAINS',
#  'Body',
#  'Body (head removed)',
#  'Body tissue',
#  'Brain',
#  'CNS-derived cell-line',
#  'Carcass',
#  'Central Nervous System',
#  'Developmental Stage Embryo 12-24h',
#  'Digestive System',
#  'Dorsal Organ Ganglia',
#  'E12-16',
#  'E4-8',
#  'Early glial cells',
#  'Embryo',
#  'Embryo 20-24h',
#  'Embryo-derived cell-line',
#  'Embryos',
#  'Eye-Antennal disc',
#  'Eye/antennal imaginal discs',
#  'FACS Sorted midgut cells',
#  'Fat',
#  'Fly Heads',
#  'Full heads',
#  'Head',
#  'Head and Thorax',
#  'Head-less body',
#  'Heads',
#  'Imaginal Disc',
#  'Imaginal discs',
#  'Imaginal discs and salivary glands',
#  'Immortalized cells',
#  'Intestinal enterocytes',
#  'Intestine',
#  'L1',
#  'L2',
#  'L3',
#  'L3 Wing imaginal disc-3rd instar',
#  'Late glial cells',
#  'M1',
#  'M10-11',
#  'M12-13',
#  'M2',
#  'M3-4-5',
#  'M6',
#  'M7-8',
#  'M9',
#  'Malpighian tubules',
#  'Neural stem cells',
#  'Newly eclosed (>6hr old)',
#  'Not Applicable',
#  'Ovarian Somatic Cells (OSC)',
#  'Ovarian somatic cell',
#  'Ovarian somatic sheet cell',
#  'Ovaries',
#  'Ovary',
#  'Ovary Germarium to stage 7',
#  'Ovary stage 11 + Egg chambers',
#  'Ovary stage 9 to 10',
#  'Ovary, stage 10',
#  'Ovary, stage 12',
#  'Ovary, stages 1-8',
#  'Periphery (entire body except head)',
#  'Pupae',
#  'S2 Cells',
#  'S2 cell',
#  'S2 cells',
#  'S2 cells (late embryo cell line)',
#  'Salivary Gland',
#  'Salivary glands',
#  'Spermatozoa',
#  'T3 leg disc',
#  'T3 pharate leg',
#  'Terminal Organ Ganglia',
#  'Testes',
#  'Testis',
#  'Total DNA',
#  'VNC containing tumorigenic neuroblasts',
#  'VNC containing tumorigenic neuroblasts over-expressing Chinmo',
#  'VNC containing tumorigenic neuroblasts with decreased Chinmo',
#  'Whole Body',
#  'Whole Body DNA Extraction',
#  'Whole Individual',
#  'Whole Organism',
#  'Whole Organisms',
#  'Whole animal',
#  'Whole body',
#  'Whole embryo',
#  'Whole flies',
#  'Whole organism',
#  'WholeBody',
#  'Wing imaginal disc',
#  'Wing imaginal discs',
#  'acidic',
#  'activated eggs',
#  'adult',
#  'adult fly ovaries',
#  'adult head',
#  'adult midgut',
#  'alkaline',
#  'antennae',
#  'antennal disc',
#  'anterior midgut',
#  'anterior ovariole',
#  'body',
#  'brain',
#  'brain without ventral nerve cord',
#  'brian',
#  'caeca',
#  'cell line',
#  'cell_line-1',
#  'central nervous system',
#  'circulatory system',
#  'dissected midgut (30x)',
#  'dissected testis',
#  'dissociated embryo',
#  'dorsal ectoderm',
#  'dorsal mesothoracic disc',
#  'early spermatocytes',
#  'egg',
#  'egg chamber',
#  'embryo',
#  'embryo cell lines',
#  'embryo, macrophage-like',
#  'embryo-derived cell line',
#  'embryo-derived cell-line',
#  'embryonic cardiac cells',
#  'embryos',
#  'eviscerated abdomen',
#  'eye disc',
#  'eye imaginal discs',
#  'eye-antanna imaginal discs',
#  'eye-antennal disc',
#  'eye-antennal discs',
#  'eye-antennal imaginal disc',
#  'eye/antennal imaginal discs',
#  'fat bodies',
#  'fat body',
#  'female whole body',
#  'fly',
#  'fly Heads',
#  'fly heads',
#  'follicle',
#  'foregut',
#  'gut',
#  'haltere disc',
#  'head',
#  'head (fat body)',
#  'head (glia)',
#  'head (neurons)',
#  'head and thorax',
#  'head/thorax',
#  'heads',
#  'heart',
#  'hindgut',
#  'imaginal disc',
#  'imaginal wing disc',
#  'intestine',
#  'intestines',
#  'larval brain',
#  'larval midgut',
#  'late embryo-derived cell line',
#  'late spermatocytes',
#  'left salivary gland',
#  'male whole body',
#  'mesodermal',
#  'midgut',
#  'mix',
#  'mixed imaginal discs',
#  'mixed-stage embryos',
#  'multi-dendritic sensory neurons',
#  'muscle',
#  'mushroom bodies',
#  'neuron',
#  'neurons',
#  'neutral',
#  'not applicable',
#  'oocyte',
#  'oocytes',
#  'optical lobe',
#  'ovarian follicle',
#  'ovarian tissues',
#  'ovaries',
#  'ovary',
#  'parasegment 4',
#  'parasegment 5',
#  'parasegment 6',
#  'parasegment 7',
#  'pharate haltere',
#  'pharate wing',
#  'posterior midgut',
#  'prothoracic leg disc',
#  'retina',
#  'right salivary gland',
#  'ring gland',
#  'salivary gland',
#  'salivary_glands',
#  'sorted midline cells',
#  'spermatids',
#  'stages 5-14 egg chambers',
#  'testes',
#  'testis',
#  'testis specifically expressing E(z) shmiR RNAi in germ cells',
#  'third instar larval brain and wing/haltere/third leg imaginal discs',
#  'third instar larval wing imaginal discs',
#  'third instar salivary gland',
#  'thoracic muscle',
#  'thorax',
#  'thorax plus abdomen',
#  'transition',
#  'tubule',
#  'unfertilized egg',
#  'ventral nerve cord',
#  'virgin female carcass',
#  'virgin female ovary',
#  'virgin male carcass',
#  'virgin testes',
#  'whole',
#  'whole 0-2 hour embryo',
#  'whole Toll10b embryos',
#  'whole adult',
#  'whole adult flie',
#  'whole animal',
#  'whole body',
#  'whole body without testis',
#  'whole brains',
#  'whole brown pre-pupae (n ≈ 30)',
#  'whole dechorionated embryos',
#  'whole embryo',
#  'whole embryo lysate',
#  'whole embryos',
#  'whole first-instar larvae',
#  'whole flies',
#  'whole fly',
#  'whole gd7 embryos',
#  'whole heads',
#  'whole larva',
#  'whole larvae',
#  'whole larvae (n ≈ 30)',
#  'whole organism',
#  'whole ovary',
#  'whole tissue',
#  'whole-animal',
#  'whole-embryo',
#  'whole_animal',
#  'wing',
#  'wing disc',
#  'wing discs',
#  'wing imaginal disc',
#  'wing imaginal discs',
#  'wings imaginal disk',
#  'wings imaginal disks'}
