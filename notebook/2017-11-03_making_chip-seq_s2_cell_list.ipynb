# %%
# %load ../start.py
# Load useful extensions

# Activate the autoreload extension for easy reloading of external packages
# %reload_ext autoreload
# %autoreload 2

# Trun on the water mark
# %reload_ext watermark
# %watermark -u -d -g

# Load ipycache extension
# %reload_ext ipycache
from ipycache import CacheMagics
CacheMagics.cachedir = '../cachedir'

# Add project library to path
import sys
sys.path.insert(0, '../../lib/python')

# The usual suspects
import os
import re
import numpy as np
import pandas as pd

# plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_context('poster')

# Turn off scientific notation
np.set_printoptions(precision=5, suppress=True)
# Out:
# last updated: 2017-11-03
# Git hash: 658176c5bd52d20a209ce689557b33c7f562447e

# %%
# %load ../../bin/load.py
from pymongo import MongoClient
with open('/home/fearjm/Projects/ncbi_remap/output/.mongodb_host', 'r') as fh:
    host = fh.read().strip()
client = MongoClient(host=host, port=27022)
db = client['sra2']
remap = db['remap']
ncbi = db['ncbi']
biometa = db['biometa']

# %%
biometa.find_one()

# %%
ncbi.find_one({'pubmed': {'$exists': 1}}, {'pubmed.pubmed_id': 1})
# Out:
# {'_id': 'SRX2551010',
#  'pubmed': [{'pubmed_id': '28007888'}, {'pubmed_id': '28007888'}]}

# %%
regex = re.compile(r'^(\s*|.*\s)(s2|Schneider)(R\+\s|,\s|\s|\s*).*$', re.IGNORECASE)

s2 = pd.DataFrame(list(ncbi.aggregate([
    {'$unwind': '$sra.sample.attributes'},
    {
        '$match': {
            'sra.sample.attributes.value': {'$regex': regex},
            'sra.experiment.library_strategy': 'ChIP-Seq',
        }
    },
    {
        '$project': {
            '_id': 0,
            'srx': "$_id",
            'cell_line': '$sra.sample.attributes.value',
            'geo': '$sra.sample.GEO',
            'strategy': '$sra.experiment.library_strategy',
            'paper': '$pubmed.pubmed_id'
        }
    },
]))).set_index('srx')

# %%
regex2 = re.compile(r'.*antibody.*', re.IGNORECASE)

ab = pd.DataFrame(list(ncbi.aggregate([
    {'$unwind': '$sra.sample.attributes'},
    {
        '$match': {
            'sra.sample.attributes.name': {'$regex': regex2},
        }
    },
    {
        '$project': {
            '_id': 0,
            'srx': "$_id",
            'attribute': '$sra.sample.attributes.value',
        }
    },
])))

# %%
ab.shape
# Out:
# (2891, 2)

# %%
ab2 = ab.groupby('srx').apply(lambda x: '|'.join(x.attribute.values)).to_frame()
ab2.columns = ['antibody']

# %%
df = s2.join(ab2, how='left')

# %%
df
# Out:
#                                                     cell_line         geo  \
# srx
# ERX012710                                        Schneider S2         NaN
# ERX012711                                        Schneider S2         NaN
# ERX032305                                                  S2         NaN
# ERX088857                                                  S2         NaN
# ERX088858                                                  S2         NaN
# ERX088859                                                  S2         NaN
# ERX088868                                                  S2         NaN
# ERX088869                                                  S2         NaN
# ERX088870                                                  S2         NaN
# ERX088871                                                  S2         NaN
# ERX088872                                                  S2         NaN
# ERX088873                                                  S2         NaN
# ERX088874                                                  S2         NaN
# ERX088875                                                  S2         NaN
# ERX102366                                                  S2         NaN
# ERX102367                                                  S2         NaN
# ERX102369                                                  S2         NaN
# ERX102381                                                  S2         NaN
# ERX1403348                                                 S2         NaN
# ERX1403349                                                 S2         NaN
# ERX1403350                                                 S2         NaN
# ERX1403351                                                 S2         NaN
# ERX242704                                                  S2         NaN
# ERX242705                                                  S2         NaN
# ERX242706                                                  S2         NaN
# ERX242707                                                  S2         NaN
# ERX242708                                                  S2         NaN
# ERX242709                                                  S2         NaN
# ERX242710                                                  S2         NaN
# ERX242711                                                  S2         NaN
# ...                                                       ...         ...
# SRX885699            S2 cells (male embryo-derived cell line)  GSM1616473
# SRX885699                                             S2-DRSC  GSM1616473
# SRX885699   wildtype S2 cells, co-transfected with pFly-Bi...  GSM1616473
# SRX885700            S2 cells (male embryo-derived cell line)  GSM1616474
# SRX885700                                             S2-DRSC  GSM1616474
# SRX885700   wildtype S2 cells, co-transfected with pFly-Bi...  GSM1616474
# SRX885701            S2 cells (male embryo-derived cell line)  GSM1616475
# SRX885701                                             S2-DRSC  GSM1616475
# SRX885701   wildtype S2 cells, co-transfected with pFly-Bi...  GSM1616475
# SRX885702            S2 cells (male embryo-derived cell line)  GSM1616476
# SRX885702                                             S2-DRSC  GSM1616476
# SRX885702   wildtype S2 cells, co-transfected with pFly-Pc...  GSM1616476
# SRX885703            S2 cells (male embryo-derived cell line)  GSM1616477
# SRX885703                                             S2-DRSC  GSM1616477
# SRX885703   wildtype S2 cells, co-transfected with pFly-Pc...  GSM1616477
# SRX886165                                            S2 cells  GSM1617057
# SRX886165                                                  S2  GSM1617057
# SRX886166                                            S2 cells  GSM1617058
# SRX886166                                                  S2  GSM1617058
# SRX886167                                            S2 cells  GSM1617059
# SRX886167                                                  S2  GSM1617059
# SRX907134   Drosophila S2-RRP6-V5 cells grown in Schneider...  GSM1626770
# SRX907134                                                  S2  GSM1626770
# SRX907135   Drosophila S2-RRP6-V5 cells grown in Schneider...  GSM1626771
# SRX907135                                                  S2  GSM1626771
# SRX907136   Drosophila S2-RRP6-V5 cells grown in Schneider...  GSM1626772
# SRX907136                                                  S2  GSM1626772
# SRX907137   Drosophila S2-RRP6-V5 cells grown in Schneider...  GSM1626773
# SRX907137                                                  S2  GSM1626773
# SRX974394                                 Drosophila S2 cells  GSM1647362
#
#                            paper  strategy                          antibody
# srx
# ERX012710                    NaN  ChIP-Seq                               NaN
# ERX012711                    NaN  ChIP-Seq                               NaN
# ERX032305                    NaN  ChIP-Seq                               NaN
# ERX088857                    NaN  ChIP-Seq                               NaN
# ERX088858                    NaN  ChIP-Seq                               NaN
# ERX088859                    NaN  ChIP-Seq                               NaN
# ERX088868                    NaN  ChIP-Seq                               NaN
# ERX088869                    NaN  ChIP-Seq                               NaN
# ERX088870                    NaN  ChIP-Seq                               NaN
# ERX088871                    NaN  ChIP-Seq                               NaN
# ERX088872                    NaN  ChIP-Seq                               NaN
# ERX088873                    NaN  ChIP-Seq                               NaN
# ERX088874                    NaN  ChIP-Seq                               NaN
# ERX088875                    NaN  ChIP-Seq                               NaN
# ERX102366                    NaN  ChIP-Seq                               NaN
# ERX102367                    NaN  ChIP-Seq                               NaN
# ERX102369                    NaN  ChIP-Seq                               NaN
# ERX102381                    NaN  ChIP-Seq                               NaN
# ERX1403348                   NaN  ChIP-Seq                               NaN
# ERX1403349                   NaN  ChIP-Seq                               NaN
# ERX1403350                   NaN  ChIP-Seq                               NaN
# ERX1403351                   NaN  ChIP-Seq                               NaN
# ERX242704   [23316440, 23316440]  ChIP-Seq                               NaN
# ERX242705   [23316440, 23316440]  ChIP-Seq                               NaN
# ERX242706   [23316440, 23316440]  ChIP-Seq                               NaN
# ERX242707   [23316440, 23316440]  ChIP-Seq                               NaN
# ERX242708   [23316440, 23316440]  ChIP-Seq                               NaN
# ERX242709   [23316440, 23316440]  ChIP-Seq                               NaN
# ERX242710   [23316440, 23316440]  ChIP-Seq                               NaN
# ERX242711   [23316440, 23316440]  ChIP-Seq                               NaN
# ...                          ...       ...                               ...
# SRX885699   [26063573, 26063573]  ChIP-Seq                              none
# SRX885699   [26063573, 26063573]  ChIP-Seq                              none
# SRX885699   [26063573, 26063573]  ChIP-Seq                              none
# SRX885700   [26063573, 26063573]  ChIP-Seq                      BioTAP-N-Scm
# SRX885700   [26063573, 26063573]  ChIP-Seq                      BioTAP-N-Scm
# SRX885700   [26063573, 26063573]  ChIP-Seq                      BioTAP-N-Scm
# SRX885701   [26063573, 26063573]  ChIP-Seq                              none
# SRX885701   [26063573, 26063573]  ChIP-Seq                              none
# SRX885701   [26063573, 26063573]  ChIP-Seq                              none
# SRX885702   [26063573, 26063573]  ChIP-Seq                       Pc-C-BioTAP
# SRX885702   [26063573, 26063573]  ChIP-Seq                       Pc-C-BioTAP
# SRX885702   [26063573, 26063573]  ChIP-Seq                       Pc-C-BioTAP
# SRX885703   [26063573, 26063573]  ChIP-Seq                              none
# SRX885703   [26063573, 26063573]  ChIP-Seq                              none
# SRX885703   [26063573, 26063573]  ChIP-Seq                              none
# SRX886165   [26894919, 26894919]  ChIP-Seq             rabbit anti MYST5 (1)
# SRX886165   [26894919, 26894919]  ChIP-Seq             rabbit anti MYST5 (1)
# SRX886166   [26894919, 26894919]  ChIP-Seq             rabbit anti MYST5 (2)
# SRX886166   [26894919, 26894919]  ChIP-Seq             rabbit anti MYST5 (2)
# SRX886167   [26894919, 26894919]  ChIP-Seq                               NaN
# SRX886167   [26894919, 26894919]  ChIP-Seq                               NaN
# SRX907134   [26389589, 26389589]  ChIP-Seq                               NaN
# SRX907134   [26389589, 26389589]  ChIP-Seq                               NaN
# SRX907135   [26389589, 26389589]  ChIP-Seq                               NaN
# SRX907135   [26389589, 26389589]  ChIP-Seq                               NaN
# SRX907136   [26389589, 26389589]  ChIP-Seq  Anti-V5 antibody (Abcam; ab9116)
# SRX907136   [26389589, 26389589]  ChIP-Seq  Anti-V5 antibody (Abcam; ab9116)
# SRX907137   [26389589, 26389589]  ChIP-Seq  Anti-V5 antibody (Abcam; ab9116)
# SRX907137   [26389589, 26389589]  ChIP-Seq  Anti-V5 antibody (Abcam; ab9116)
# SRX974394   [26079792, 26079792]  ChIP-Seq             Rpb3 (PMID: 15629721)
#
# [967 rows x 5 columns]

# %%
store = pd.HDFStore('../../sra.h5')

# %%
qc = store['prealn/qc_passed'].srx

# %%
df_clean = df[df.index.isin(qc)]

# %%
df_clean.shape
# Out:
# (618, 5)

# %%
df_clean.to_csv('../../output/20171103_s2cell_chip-seq.tsv', sep='\t')
