# %% [markdown]
# This notebook is looking at metadata from SRA. I am wanting to develop a programmatic approach to download metadata information, but needs to be consistent with Zhenxia and Miegs analysis. I am also wanting to figure exactly how Zhenxia and the Miegs did this.
#
# There are two programmatic approaches:
# * SRAdb
# * Biopython

# %%
try:
    # %load_ext autoreload
except:
    pass
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import re
from xml.etree import ElementTree as ET

import pandas as pd
from Bio import Entrez

# Import my libraries
sys.path.insert(0, '../../lib/python/')
import Sra

pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 999)
Entrez.email = 'justin.fear@nih.gov'

# %% [markdown]
# # Biopyton
#
# Biopython's counts match what I expect, but the results are in raw XML and need a parser.

# %% [markdown]
# ## Get List of Records

# %%
handle = Entrez.esearch(db='sra', term='"Drosophila melanogaster"[Orgn]', retmax=99999, usehistory='y')
records = Entrez.read(handle)
print(records['Count'])

# Save history from eSearch, this will be used in eFetch
webenv = records['WebEnv']
query_key = records['QueryKey']
# Out:
# 22350

# %% [markdown]
# ## Get Full XML

# %%
# Check if I have already dumped the sra records. If 
# you want to update, simply delete the file and re-run.
fname = '../../output/sra_dump.xml'
if not os.path.exists(fname):
    Sra.downloadSRA(count=records['Count'], webenv=webenv, 
                query_key=query_key, fname=fname)

tree = ET.parse(fname)
root = tree.getroot()
ep = root.getchildren()
len(ep)
# Out:
# 22344

# %%
bob = ep[0]

# %%
list(bob)
# Out:
# [<Element 'EXPERIMENT' at 0x16d5644f8>,
#  <Element 'SUBMISSION' at 0x16d5809a8>,
#  <Element 'Organization' at 0x16d580b38>,
#  <Element 'STUDY' at 0x16d9b92c8>,
#  <Element 'SAMPLE' at 0x16d9b9728>,
#  <Element 'Pool' at 0x16d9ba1d8>,
#  <Element 'RUN_SET' at 0x16d9ba3b8>]

# %%
s = bob.find('RUN_SET')

# %%
for e in ep:
    try:
        if e.find('.//RUN').get('accession') == 'DRR001444':
            break
    except:
        pass

# %%
e.findall('.//EXTERNAL_ID')
# Out:
# [<Element 'EXTERNAL_ID' at 0x1a3847278>,
#  <Element 'EXTERNAL_ID' at 0x1a38474a8>,
#  <Element 'EXTERNAL_ID' at 0x1a384a2c8>,
#  <Element 'EXTERNAL_ID' at 0x1a384a728>,
#  <Element 'EXTERNAL_ID' at 0x1a384ac28>,
#  <Element 'EXTERNAL_ID' at 0x1a384d0e8>]

# %%
for i in e.iter():
    print("""
    {tag}
    \t{attrib}
    \t{text}
    """.format(tag=i.tag, attrib=i.attrib, text=i.text))
# Out:
#     EXPERIMENT_PACKAGE
#     	{}
#     	None
#
#
#     EXPERIMENT
#     	{'accession': 'DRX000998', 'center_name': 'KYOTO_SC', 'alias': 'DRX000998'}
#     	None
#
#
#     IDENTIFIERS
#     	{}
#     	None
#
#
#     PRIMARY_ID
#     	{}
#     	DRX000998
#
#
#     SUBMITTER_ID
#     	{'namespace': 'KYOTO_SC'}
#     	DRX000998
#
#
#     TITLE
#     	{}
#     	Whole genome sequencing of Drosophila melanogaster strain DM, series DM01
#
#
#     STUDY_REF
#     	{'accession': 'DRP000460', 'refname': 'DRP000460', 'refcenter': 'KYOTO_SC'}
#     	None
#
#
#     IDENTIFIERS
#     	{}
#     	None
#
#
#     PRIMARY_ID
#     	{}
#     	DRP000460
#
#
#     EXTERNAL_ID
#     	{'namespace': 'BioProject', 'label': 'BioProject ID'}
#     	PRJDA72881
#
#
#     SUBMITTER_ID
#     	{'namespace': 'KYOTO_SC'}
#     	DRP000460
#
#
#     DESIGN
#     	{}
#     	None
#
#
#     DESIGN_DESCRIPTION
#     	{}
#     	none provided
#
#
#     SAMPLE_DESCRIPTOR
#     	{'accession': 'DRS000998', 'refname': 'DRS000998', 'refcenter': 'KYOTO_SC'}
#     	None
#
#
#     IDENTIFIERS
#     	{}
#     	None
#
#
#     PRIMARY_ID
#     	{}
#     	DRS000998
#
#
#     EXTERNAL_ID
#     	{'namespace': 'BioSample', 'label': 'BioSample ID'}
#     	SAMD00000814
#
#
#     SUBMITTER_ID
#     	{'namespace': 'KYOTO_SC'}
#     	DRS000998
#
#
#     LIBRARY_DESCRIPTOR
#     	{}
#     	None
#
#
#     LIBRARY_NAME
#     	{}
#     	Drosophila melanogaster strain DM
#
#
#     LIBRARY_STRATEGY
#     	{}
#     	WGS
#
#
#     LIBRARY_SOURCE
#     	{}
#     	GENOMIC
#
#
#     LIBRARY_SELECTION
#     	{}
#     	RANDOM
#
#
#     LIBRARY_LAYOUT
#     	{}
#     	None
#
#
#     PAIRED
#     	{'NOMINAL_LENGTH': '250'}
#     	None
#
#
#     LIBRARY_CONSTRUCTION_PROTOCOL
#     	{}
#     	none provided
#
#
#     SPOT_DESCRIPTOR
#     	{}
#     	None
#
#
#     SPOT_DECODE_SPEC
#     	{}
#     	None
#
#
#     SPOT_LENGTH
#     	{}
#     	72
#
#
#     READ_SPEC
#     	{}
#     	None
#
#
#     READ_INDEX
#     	{}
#     	0
#
#
#     READ_CLASS
#     	{}
#     	Application Read
#
#
#     READ_TYPE
#     	{}
#     	Forward
#
#
#     BASE_COORD
#     	{}
#     	1
#
#
#     READ_SPEC
#     	{}
#     	None
#
#
#     READ_INDEX
#     	{}
#     	1
#
#
#     READ_CLASS
#     	{}
#     	Application Read
#
#
#     READ_TYPE
#     	{}
#     	Reverse
#
#
#     BASE_COORD
#     	{}
#     	37
#
#
#     PLATFORM
#     	{}
#     	None
#
#
#     ILLUMINA
#     	{}
#     	None
#
#
#     INSTRUMENT_MODEL
#     	{}
#     	Illumina Genome Analyzer II
#
#
#     PROCESSING
#     	{}
#     	None
#
#
#     PIPELINE
#     	{}
#     	None
#
#
#     PIPE_SECTION
#     	{}
#     	None
#
#
#     STEP_INDEX
#     	{}
#     	1
#
#
#     PREV_STEP_INDEX
#     	{}
#     	NIL
#
#
#     PROGRAM
#     	{}
#     	Bustard1.9.5
#
#
#     VERSION
#     	{}
#     	None
#
#
#     SUBMISSION
#     	{'accession': 'DRA000451', 'center_name': 'KYOTO_SC', 'lab_name': 'Laboratory for Biodiversity, Global COE Program, Division of Biological Sciences, Graduate School of Science, Kyoto University', 'alias': 'DRA000451'}
#     	None
#
#
#     IDENTIFIERS
#     	{}
#     	None
#
#
#     PRIMARY_ID
#     	{}
#     	DRA000451
#
#
#     SUBMITTER_ID
#     	{'namespace': 'KYOTO_SC'}
#     	DRA000451
#
#
#     TITLE
#     	{}
#     	whole genome sequencing for Dark-fly
#
#
#     Organization
#     	{'type': 'center'}
#     	None
#
#
#     Name
#     	{'abbr': 'KYOTO_SC'}
#     	KYOTO_SC
#
#
#     STUDY
#     	{'accession': 'DRP000460', 'center_name': 'KYOTO_SC', 'alias': 'DRP000460'}
#     	None
#
#
#     IDENTIFIERS
#     	{}
#     	None
#
#
#     PRIMARY_ID
#     	{}
#     	DRP000460
#
#
#     EXTERNAL_ID
#     	{'namespace': 'BioProject', 'label': 'primary'}
#     	PRJDA72881
#
#
#     SUBMITTER_ID
#     	{'namespace': 'KYOTO_SC'}
#     	DRP000460
#
#
#     DESCRIPTOR
#     	{}
#     	None
#
#
#     STUDY_TITLE
#     	{}
#     	Drosophila melanogaster strain:Dark-fly Genome sequencing
#
#
#     STUDY_TYPE
#     	{'existing_study_type': 'Whole Genome Sequencing'}
#     	None
#
#
#     CENTER_PROJECT_NAME
#     	{}
#     	Drosophila melanogaster strain:Dark-fly
#
#
#     STUDY_LINKS
#     	{}
#     	None
#
#
#     STUDY_LINK
#     	{}
#     	None
#
#
#     XREF_LINK
#     	{}
#     	None
#
#
#     DB
#     	{}
#     	pubmed
#
#
#     ID
#     	{}
#     	22432011
#
#
#     SAMPLE
#     	{'accession': 'DRS000998', 'center_name': 'BioSample', 'alias': 'SAMD00000814'}
#     	None
#
#
#     IDENTIFIERS
#     	{}
#     	None
#
#
#     PRIMARY_ID
#     	{}
#     	DRS000998
#
#
#     EXTERNAL_ID
#     	{'namespace': 'BioSample'}
#     	SAMD00000814
#
#
#     TITLE
#     	{}
#     	Drosophila melanogaster strain DM
#
#
#     SAMPLE_NAME
#     	{}
#     	None
#
#
#     TAXON_ID
#     	{}
#     	7227
#
#
#     SCIENTIFIC_NAME
#     	{}
#     	Drosophila melanogaster
#
#
#     SAMPLE_ATTRIBUTES
#     	{}
#     	None
#
#
#     SAMPLE_ATTRIBUTE
#     	{}
#     	None
#
#
#     TAG
#     	{}
#     	sample_name
#
#
#     VALUE
#     	{}
#     	DRS000998
#
#
#     SAMPLE_ATTRIBUTE
#     	{}
#     	None
#
#
#     TAG
#     	{}
#     	sample comment
#
#
#     VALUE
#     	{}
#     	Drosophila melanogaster strain DM
#
#
#     Pool
#     	{}
#     	None
#
#
#     Member
#     	{'member_name': '', 'bases': '2406801384', 'organism': 'Drosophila melanogaster', 'sample_title': 'Drosophila melanogaster strain DM', 'tax_id': '7227', 'accession': 'DRS000998', 'sample_name': 'SAMD00000814', 'spots': '33427797'}
#     	None
#
#
#     IDENTIFIERS
#     	{}
#     	None
#
#
#     PRIMARY_ID
#     	{}
#     	DRS000998
#
#
#     EXTERNAL_ID
#     	{'namespace': 'BioSample'}
#     	SAMD00000814
#
#
#     RUN_SET
#     	{}
#     	None
#
#
#     RUN
#     	{'static_data_available': '1', 'total_spots': '33427797', 'center_name': 'KYOTO_SC', 'alias': 'DRR001444', 'accession': 'DRR001444', 'published': '2012-03-14 21:54:24', 'run_center': 'NIG', 'load_done': 'true', 'run_date': '2008-11-24T15:00:00Z', 'total_bases': '2406801384', 'size': '936418710', 'cluster_name': 'public', 'is_public': 'true'}
#     	None
#
#
#     IDENTIFIERS
#     	{}
#     	None
#
#
#     PRIMARY_ID
#     	{}
#     	DRR001444
#
#
#     SUBMITTER_ID
#     	{'namespace': 'KYOTO_SC'}
#     	DRR001444
#
#
#     EXPERIMENT_REF
#     	{'accession': 'DRX000998', 'refname': 'DRX000998', 'refcenter': 'KYOTO_SC'}
#     	None
#
#
#     IDENTIFIERS
#     	{}
#     	None
#
#
#     PRIMARY_ID
#     	{}
#     	DRX000998
#
#
#     SUBMITTER_ID
#     	{'namespace': 'KYOTO_SC'}
#     	DRX000998
#
#
#     Pool
#     	{}
#     	None
#
#
#     Member
#     	{'member_name': '', 'bases': '2406801384', 'organism': 'Drosophila melanogaster', 'sample_title': 'Drosophila melanogaster strain DM', 'tax_id': '7227', 'accession': 'DRS000998', 'sample_name': 'SAMD00000814', 'spots': '33427797'}
#     	None
#
#
#     IDENTIFIERS
#     	{}
#     	None
#
#
#     PRIMARY_ID
#     	{}
#     	DRS000998
#
#
#     EXTERNAL_ID
#     	{'namespace': 'BioSample'}
#     	SAMD00000814
#
#
#     QualityCount
#     	{}
#     	None
#
#
#     Quality
#     	{'value': '3', 'count': '94303'}
#     	None
#
#
#     Quality
#     	{'value': '4', 'count': '2961889'}
#     	None
#
#
#     Quality
#     	{'value': '5', 'count': '8168072'}
#     	None
#
#
#     Quality
#     	{'value': '6', 'count': '2348877'}
#     	None
#
#
#     Quality
#     	{'value': '7', 'count': '730075'}
#     	None
#
#
#     Quality
#     	{'value': '8', 'count': '3894049'}
#     	None
#
#
#     Quality
#     	{'value': '9', 'count': '5200233'}
#     	None
#
#
#     Quality
#     	{'value': '10', 'count': '11147203'}
#     	None
#
#
#     Quality
#     	{'value': '11', 'count': '3569371'}
#     	None
#
#
#     Quality
#     	{'value': '12', 'count': '3033640'}
#     	None
#
#
#     Quality
#     	{'value': '13', 'count': '6862461'}
#     	None
#
#
#     Quality
#     	{'value': '14', 'count': '10054659'}
#     	None
#
#
#     Quality
#     	{'value': '15', 'count': '11198664'}
#     	None
#
#
#     Quality
#     	{'value': '16', 'count': '18904749'}
#     	None
#
#
#     Quality
#     	{'value': '17', 'count': '24103216'}
#     	None
#
#
#     Quality
#     	{'value': '18', 'count': '35821120'}
#     	None
#
#
#     Quality
#     	{'value': '19', 'count': '88590410'}
#     	None
#
#
#     Quality
#     	{'value': '20', 'count': '1867789'}
#     	None
#
#
#     Quality
#     	{'value': '21', 'count': '1446245858'}
#     	None
#
#
#     Quality
#     	{'value': '22', 'count': '721768135'}
#     	None
#
#
#     Quality
#     	{'value': '23', 'count': '176646'}
#     	None
#
#
#     Quality
#     	{'value': '24', 'count': '34408'}
#     	None
#
#
#     Quality
#     	{'value': '25', 'count': '7005'}
#     	None
#
#
#     Quality
#     	{'value': '26', 'count': '10972'}
#     	None
#
#
#     Quality
#     	{'value': '27', 'count': '4454'}
#     	None
#
#
#     Quality
#     	{'value': '28', 'count': '3126'}
#     	None
#
#
#     Statistics
#     	{'nreads': '2', 'nspots': '33427797'}
#     	None
#
#
#     Read
#     	{'stdev': '0', 'count': '33427797', 'index': '0', 'average': '36'}
#     	None
#
#
#     Read
#     	{'stdev': '0', 'count': '33427797', 'index': '1', 'average': '36'}
#     	None

# %% [markdown]
# ## Available Sample Attributes:

# %% [markdown]
# Sample attributes are entered as free text. Here is a list of attributes currently in the SRA. Some of these can collapsed into single categories.

# %%
counts = {}
for i in root.findall('.//SAMPLE_ATTRIBUTE/TAG'):
    try:
        text = i.text.lower()
        if text in counts:
            counts[text] += 1
        else:
            counts[text] = 1
    except:
        pass

# %%
pd.Series(counts).to_csv('../../output/tmp.text', sep='\t')

# %%
s = bob.find('SAMPLE')

# %%
for i in s.iter():
    print(i.tag, i.attrib, i.text)
# Out:
# SAMPLE {'accession': 'SRS1532953', 'alias': 'FR198N'} None
# IDENTIFIERS {} None
# PRIMARY_ID {} SRS1532953
# EXTERNAL_ID {'namespace': 'BioSample'} SAMN05330489
# SUBMITTER_ID {'namespace': 'pda|justin.lack@nih.gov', 'label': 'Sample name'} FR198N
# TITLE {} FR198N
# SAMPLE_NAME {} None
# TAXON_ID {} 7227
# SCIENTIFIC_NAME {} Drosophila melanogaster
# COMMON_NAME {} fruit fly
# SAMPLE_LINKS {} None
# SAMPLE_LINK {} None
# XREF_LINK {} None
# DB {} bioproject
# ID {} 327349
# LABEL {} PRJNA327349
# SAMPLE_ATTRIBUTES {} None
# SAMPLE_ATTRIBUTE {} None
# TAG {} strain
# VALUE {} FR198N
# SAMPLE_ATTRIBUTE {} None
# TAG {} dev_stage
# VALUE {} adult
# SAMPLE_ATTRIBUTE {} None
# TAG {} sex
# VALUE {} female
# SAMPLE_ATTRIBUTE {} None
# TAG {} tissue
# VALUE {} Whole organism
# SAMPLE_ATTRIBUTE {} None
# TAG {} BioSampleModel
# VALUE {} Model organism or animal

# %%
for attrib in s.findall('SAMPLE_ATTRIBUTES/SAMPLE_ATTRIBUTE'):
    print(attrib.find('TAG').text)
# Out:
# strain
# dev_stage
# sex
# tissue
# BioSampleModel
